# %% [markdown]
# # Goals
#
# * Check whether Chris' datasets are in the scBaseCount SQL database (STAR results)
# * Also created `prodC` on GCP for Chris' datasets

# %%
import os
from pathlib import Path
import pandas as pd
import plotnine as pn
from pypika import Query, Table, functions as fn

from SRAgent.db.connect import db_connect

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 4)
pn.theme_set(pn.theme_bw())

# %%
# get base of github repo
base_dir = !git rev-parse --show-toplevel
base_dir = Path(base_dir[0])
base_dir
# Out:
# PosixPath('/home/nickyoungblut/dev/python/scBaseCount_analysis')

# %%
# set tenant
os.environ["DYNACONF"] = "prod"

# %%
def get_screcounter_star_results(
    conn, 
    feature="GeneFull_Ex50pAS"
):
    """
    Get the screcounter_star_results table
    
    Args:
        conn: A database connection object (e.g., sqlite3, psycopg2, etc.)
        feature: String of the feature to filter on
    Returns:
        A pandas DataFrame of records
    """
    
    # Define tables
    meta_table = Table('srx_metadata')
    star_table = Table('screcounter_star_results')
    
    # Build the star query with feature filter (case insensitive)
    star_query = (
        Query.from_(star_table)
        .select('*')
        .where(
            fn.Lower(star_table.feature) == feature.lower()
        )
    )

    # Build the main query with join
    # Assuming you want all columns from both tables except feature from star and _at columns from meta
    main_query = (
        Query.from_(meta_table)
        .left_join(star_table)
        .on(meta_table.srx_accession == star_table.sample)
        .select(
            star_table.sample.as_('srx_accession'),
            star_table.feature,
            star_table.estimated_number_of_cells,
            meta_table.lib_prep,
            meta_table.tech_10x,
            meta_table.organism,
            meta_table.tissue,
            meta_table.tissue_ontology_term_id,
            meta_table.czi_collection_id,
            meta_table.czi_collection_name,
            meta_table.notes
        )
        .where(
            meta_table.czi_collection_id != None and meta_table.czi_collection_id != ""
        )
        .where(
            star_table.estimated_number_of_cells.isnull()
        )
    )
    
    # Execute query and return as DataFrame
    return pd.read_sql_query(str(main_query), conn)

with db_connect() as conn:
    df_cells = get_screcounter_star_results(conn, feature="GeneFull_Ex50pAS")
df_cells
# Out:
#      srx_accession feature estimated_number_of_cells lib_prep        tech_10x  \
# 0             None    None                      None    other  not_applicable
# 1             None    None                      None    other  not_applicable
# ...            ...     ...                       ...      ...             ...
# 2380          None    None                      None    other  not_applicable
# 2381          None    None                      None    other  not_applicable
#
#           organism                                   tissue  \
# 0     Homo sapiens                                    brain
# 1     Homo sapiens  acute slice culture of glioma resection
# ...            ...                                      ...
# 2380  Homo sapiens                             tumor tissue
# 2381  Homo sapiens                              H1299 cells
#
#      tissue_ontology_term_id                     czi_collection_id  \
# 0                       None  999f2a15-3d7e-440b-96ae-2c806799c08c
# 1                       None  999f2a15-3d7e-440b-96ae-2c806799c08c
# ...                      ...                                   ...
# 2380                    None  3f50314f-bdc9-40c6-8e4a-b0901ebfbe4c
# 2381                    None  d0e9c47b-4ce7-4f84-b182-eddcfa0b2658
#
#                                     czi_collection_name  \
# 0     Harmonized single-cell landscape, intercellula...
# 1     Harmonized single-cell landscape, intercellula...
# ...                                                 ...
# 2380  Single-cell sequencing links multiregional imm...
# 2381  Single-cell gene expression profiling of SARS-...
#
#                              notes
# 0     Metadata obtained by SRAgent
# 1     Metadata obtained by SRAgent
# ...                            ...
# 2380  Metadata obtained by SRAgent
# 2381  Metadata obtained by SRAgent
#
# [2382 rows x 11 columns]

# %% [markdown]
# # Location of Chris' dataset

# %%
data_dir = Path('/processed_datasets/scRecount/cellxgene/counted_SRXs/')
data_dir
# Out:
# PosixPath('/processed_datasets/scRecount/cellxgene/counted_SRXs')

# %%
# find all matrix files
matrix_info = []
for f in data_dir.rglob("matrix.mtx.gz"):
    accession = f.parts[5]
    feature = f.parts[7]
    processing = f.parent.name
    matrix_info.append([accession, feature, processing, f])

matrix_info = pd.DataFrame(matrix_info, columns=["accession", "feature", "processing", "path"])
matrix_info
# Out:
#          accession                  feature processing  \
# 0       ERX8792024  GeneFull_ExonOverIntron   filtered
# 1       ERX8792024  GeneFull_ExonOverIntron        raw
# ...            ...                      ...        ...
# 22895  ERX11467033         GeneFull_Ex50pAS        raw
# 22896  ERX11467033         GeneFull_Ex50pAS   filtered
#
#                                                     path
# 0      /processed_datasets/scRecount/cellxgene/counte...
# 1      /processed_datasets/scRecount/cellxgene/counte...
# ...                                                  ...
# 22895  /processed_datasets/scRecount/cellxgene/counte...
# 22896  /processed_datasets/scRecount/cellxgene/counte...
#
# [22897 rows x 4 columns]

# %%
# high priority matrix files
matrix_info[(matrix_info["processing"] == "filtered") & (matrix_info["feature"] == "GeneFull_Ex50pAS")]
# Out:
#          accession           feature processing  \
# 4       ERX8792024  GeneFull_Ex50pAS   filtered
# 10     ERX12558782  GeneFull_Ex50pAS   filtered
# ...            ...               ...        ...
# 22868   ERX9138882  GeneFull_Ex50pAS   filtered
# 22896  ERX11467033  GeneFull_Ex50pAS   filtered
#
#                                                     path
# 4      /processed_datasets/scRecount/cellxgene/counte...
# 10     /processed_datasets/scRecount/cellxgene/counte...
# ...                                                  ...
# 22868  /processed_datasets/scRecount/cellxgene/counte...
# 22896  /processed_datasets/scRecount/cellxgene/counte...
#
# [2034 rows x 4 columns]

# %%
# find all summary files
sum_info = []
for f in data_dir.rglob("Summary.csv"):
    feature = f.parent.stem
    accession = f.parent.parent.parent.stem
    sum_info.append([accession, feature, f])

sum_info = pd.DataFrame(sum_info, columns=["accession", "feature", "path"])
sum_info
# Out:
#          accession                  feature  \
# 0       ERX8792024  GeneFull_ExonOverIntron
# 1       ERX8792024                 GeneFull
# ...            ...                      ...
# 14675  ERX11467033                     Gene
# 14676  ERX11467033         GeneFull_Ex50pAS
#
#                                                     path
# 0      /processed_datasets/scRecount/cellxgene/counte...
# 1      /processed_datasets/scRecount/cellxgene/counte...
# ...                                                  ...
# 14675  /processed_datasets/scRecount/cellxgene/counte...
# 14676  /processed_datasets/scRecount/cellxgene/counte...
#
# [14677 rows x 3 columns]

# %%
# filter sum_info to just those with filtered matrix
sum_info_f = sum_info[sum_info["accession"].isin(matrix_info["accession"])]
sum_info_f
# Out:
#          accession                  feature  \
# 0       ERX8792024  GeneFull_ExonOverIntron
# 1       ERX8792024                 GeneFull
# ...            ...                      ...
# 14675  ERX11467033                     Gene
# 14676  ERX11467033         GeneFull_Ex50pAS
#
#                                                     path
# 0      /processed_datasets/scRecount/cellxgene/counte...
# 1      /processed_datasets/scRecount/cellxgene/counte...
# ...                                                  ...
# 14675  /processed_datasets/scRecount/cellxgene/counte...
# 14676  /processed_datasets/scRecount/cellxgene/counte...
#
# [10892 rows x 3 columns]

# %%
# number of unique SRXs
sum_info_f["accession"].nunique()
# Out:
# 2179

# %%
# find duplicates
x = sum_info_f[sum_info_f["feature"] == "GeneFull_Ex50pAS"]
df_dup = x[x["accession"].duplicated()].sort_values("accession")

pd.options.display.max_rows = 100
pd.options.display.max_colwidth = None
df_dup
# Out:
# Empty DataFrame
# Columns: [accession, feature, path]
# Index: []

# %%
# reset display
pd.options.display.max_rows = 4

# %% [markdown]
# ## Filter to those with metadata in the SQL database

# %%
target_srx = sum_info_f["accession"].unique().tolist()

meta_table = Table('srx_metadata')
query = (
    Query
    .from_(meta_table)
    .select(
        meta_table.srx_accession,
        meta_table.lib_prep,
        meta_table.tech_10x,
        meta_table.organism,
        meta_table.tissue,
        meta_table.tissue_ontology_term_id,
        meta_table.czi_collection_id,
        meta_table.czi_collection_name,
        meta_table.notes
    )
    .where(
        meta_table.srx_accession.isin(target_srx)
    )
)
    
with db_connect() as conn:
    df_in_db = pd.read_sql_query(str(query), conn)
df_in_db
# Out:
#      srx_accession        lib_prep        tech_10x      organism  tissue  \
# 0       SRX6640190           other  not_applicable  Homo sapiens  spleen
# 1       SRX6640168           other  not_applicable  Homo sapiens    lung
# ...            ...             ...             ...           ...     ...
# 2170   SRX12677803    10x_Genomics     3_prime_gex  Mus musculus  thymus
# 2171   SRX13549173  not_applicable  not_applicable  Mus musculus   liver
#
#      tissue_ontology_term_id                     czi_collection_id  \
# 0                       None  38833785-fac5-48fd-944a-0f62a4c23ed1
# 1                       None  38833785-fac5-48fd-944a-0f62a4c23ed1
# ...                      ...                                   ...
# 2170          UBERON:0002370                                  None
# 2171          UBERON:0002107                                  None
#
#                                               czi_collection_name  \
# 0     Construction of a human cell landscape at single-cell level
# 1     Construction of a human cell landscape at single-cell level
# ...                                                           ...
# 2170                                                         None
# 2171                                                         None
#
#                              notes
# 0     Metadata obtained by SRAgent
# 1     Metadata obtained by SRAgent
# ...                            ...
# 2170  Metadata obtained by SRAgent
# 2171  Metadata obtained by SRAgent
#
# [2172 rows x 9 columns]

# %%
# filter chris's data to those in the SQL database
x = df_in_db["srx_accession"].unique().tolist()
sum_info_ff = sum_info_f[sum_info_f["accession"].isin(x)]
sum_info_ff["accession"].nunique()
# Out:
# 2172

# %% [markdown]
# ### Accessions with no in metadata table of SQL database

# %%
# filter to those missing database
x = df_in_db["srx_accession"].unique().tolist()
sum_info_f_mis = sum_info_f[~sum_info_f["accession"].isin(x)]
sum_info_f_mis["accession"].nunique()
# Out:
# 7

# %%
# write output
outfile = base_dir /  'data' / 'chris_data' / '2025-07-03_srx-add-meta.csv'
sum_info_f_mis.to_csv(outfile, index=False)
print(f"File written to {outfile}")
# Out:
# File written to /home/nickyoungblut/dev/python/scBaseCount_analysis/data/chris_data/2025-07-03_srx-add-meta.csv

# %% [markdown]
# > Note: the 7 are outliers that will not be added to the database

# %% [markdown]
# #

# %% [markdown]
# ## Filter to just those lacking STAR results in the SQL database

# %%
target_srx = sum_info_ff["accession"].unique().tolist()

star_table = Table('screcounter_star_results')
query = (
    Query
    .from_(star_table)
    .select(
        star_table.sample
    )
    .distinct()
    .where(
        star_table.sample.isin(target_srx)
    )
)
    
with db_connect() as conn:
    df_has_star = pd.read_sql_query(str(query), conn)
df_has_star
# Out:
#           sample
# 0    ERX11467030
# 1    ERX11467031
# ..           ...
# 739   SRX9777398
# 740   SRX9777399
#
# [741 rows x 1 columns]

# %%
# filter to just those lacking an SRA experiment accession; thus, should be added to the STAR results table
x = df_has_star["sample"].unique().tolist()
sum_info_ff = sum_info_ff[~sum_info_f["accession"].isin(x)]
sum_info_ff["accession"].nunique()
# Out:
# /tmp/ipykernel_848383/2693290625.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 1431

# %%
# check for duplidates
x = sum_info_ff.copy()
x = x[x["feature"] == "GeneFull_Ex50pAS"]
x[x["accession"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [accession, feature, path]
# Index: []

# %%
# check for all features per accession
pd.options.display.max_rows = 10
sum_info_ff.groupby("feature").count().reset_index()
# Out:
#                    feature  accession  path
# 0                     Gene       1431  1431
# 1                 GeneFull       1431  1431
# 2         GeneFull_Ex50pAS       1431  1431
# 3  GeneFull_ExonOverIntron       1431  1431
# 4                 Velocyto       1428  1428

# %%
# reset display
pd.options.display.max_rows = 4

# %%
# write output
outfile = base_dir /  'data' / 'chris_data' / '2025-07-03_srx-add-star.csv'
sum_info_ff.to_csv(outfile, index=False)
print(f"File written to {outfile}")
# Out:
# File written to /home/nickyoungblut/dev/python/scBaseCount_analysis/data/chris_data/2025-07-03_srx-add-star.csv

# %% [markdown]
# ### Add to SQL database & `prodC` GCP bucket location

# %%
csv_file = base_dir / 'data' / 'chris_data' / '2025-07-03_srx-add-star.csv'
print(csv_file.exists())

exe = base_dir / 'scripts' / 'ChrisData2SQL-DB.py'
print(exe.exists())
# Out:
# True
# True

# %% [markdown]
# #### Test run

# %%
slurm_job = f"""#!/bin/bash
#SBATCH --job-name=ChrisData2SQLDB  
#SBATCH --output=ChrisData2SQLDB.out
#SBATCH --error=ChrisData2SQLDB.err
#SBATCH --ntasks=1 
#SBATCH --cpus-per-task=1
#SBATCH --mem=8G
#SBATCH --time=72:00:00

{exe} \\
    --tenant test \\
    --max-datasets 2 \\
    --gcp-bucket gs://arc-ctc-screcounter/test/prodC/ \\
    --samples-table {csv_file}
"""

job_file = "ChrisData2SQL-DB.sh"
with open(job_file, "w") as f:
    f.write(slurm_job)

# !chmod +x ChrisData2SQL-DB.sh
# !cat ChrisData2SQL-DB.sh
# Out:
# #!/bin/bash
# #SBATCH --job-name=ChrisData2SQLDB
# #SBATCH --output=ChrisData2SQLDB.out
# #SBATCH --error=ChrisData2SQLDB.err
# #SBATCH --ntasks=1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem=8G
# #SBATCH --time=72:00:00
#
# /home/nickyoungblut/dev/python/scBaseCount_analysis/scripts/ChrisData2SQL-DB.py \
#     --tenant test \
#     --max-datasets 2 \
#     --gcp-bucket gs://arc-ctc-screcounter/test/prodC/ \
#     --samples-table /home/nickyoungblut/dev/python/scBaseCount_analysis/data/chris_data/2025-07-03_srx-add-star.csv

# %%
# submit job
# !sbatch ChrisData2SQL-DB.sh
# Out:
# Submitted batch job 934890

# %%
# !tail ChrisData2SQLDB.err
# Out:
# 2025-07-03 09:23:12,981 - Successfully uploaded matrix files for ERX12558782/Gene/raw
# 2025-07-03 09:23:12,982 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12558782/ERR13187479_resultSolo.out/Gene/filtered -> gs://arc-ctc-screcounter/test/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12558782/Gene/filtered/
# 2025-07-03 09:23:14,845 - Successfully uploaded matrix files for ERX12558782/Gene/filtered
# 2025-07-03 09:23:14,846 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12558782/ERR13187479_resultSolo.out/GeneFull_ExonOverIntron/raw -> gs://arc-ctc-screcounter/test/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12558782/GeneFull_ExonOverIntron/raw/
# 2025-07-03 09:23:16,812 - Successfully uploaded matrix files for ERX12558782/GeneFull_ExonOverIntron/raw
# 2025-07-03 09:23:16,812 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12558782/ERR13187479_resultSolo.out/GeneFull_ExonOverIntron/filtered -> gs://arc-ctc-screcounter/test/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12558782/GeneFull_ExonOverIntron/filtered/
# 2025-07-03 09:23:18,668 - Successfully uploaded matrix files for ERX12558782/GeneFull_ExonOverIntron/filtered
# 2025-07-03 09:23:18,668 - Upload batch SCRECOUNTER_2025-07-03_00-00-00 completed
# 2025-07-03 09:23:18,668 - Upload completed for batch: SCRECOUNTER_2025-07-03_00-00-00
# 2025-07-03 09:23:18,668 - Updating screcounter_star_results...

# %% [markdown]
# #### Full run

# %%
slurm_job = f"""#!/bin/bash
#SBATCH --job-name=ChrisData2SQLDB  
#SBATCH --output=ChrisData2SQLDB.out
#SBATCH --error=ChrisData2SQLDB.err
#SBATCH --ntasks=1 
#SBATCH --cpus-per-task=1
#SBATCH --mem=12G
#SBATCH --time=96:00:00

{exe} \\
    --tenant prod \\
    --ignore-missing \\
    --gcp-bucket gs://arc-ctc-screcounter/prodC/ \\
    --samples-table {csv_file}
"""

job_file = "ChrisData2SQL-DB.sh"
with open(job_file, "w") as f:
    f.write(slurm_job)

# !chmod +x ChrisData2SQL-DB.sh
# !cat ChrisData2SQL-DB.sh
# Out:
# #!/bin/bash
# #SBATCH --job-name=ChrisData2SQLDB
# #SBATCH --output=ChrisData2SQLDB.out
# #SBATCH --error=ChrisData2SQLDB.err
# #SBATCH --ntasks=1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem=12G
# #SBATCH --time=96:00:00
#
# /home/nickyoungblut/dev/python/scBaseCount_analysis/scripts/ChrisData2SQL-DB.py \
#     --tenant prod \
#     --ignore-missing \
#     --gcp-bucket gs://arc-ctc-screcounter/prodC/ \
#     --samples-table /home/nickyoungblut/dev/python/scBaseCount_analysis/data/chris_data/2025-07-03_srx-add-star.csv

# %%
# submit job
# !sbatch ChrisData2SQL-DB.sh
# Out:
# Submitted batch job 935000

# %%
# !tail -n 20 ChrisData2SQLDB.err
# Out:
# 2025-07-03 13:09:09,871 - Successfully uploaded matrix files for ERX12098962/GeneFull_ExonOverIntron/raw
# 2025-07-03 13:09:09,871 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12098962/ERR12724463_resultSolo.out/GeneFull_ExonOverIntron/filtered -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12098962/GeneFull_ExonOverIntron/filtered/
# 2025-07-03 13:09:14,022 - Successfully uploaded matrix files for ERX12098962/GeneFull_ExonOverIntron/filtered
# 2025-07-03 13:09:14,023 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12098962/ERR12724463_resultSolo.out/Gene/raw -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12098962/Gene/raw/
# 2025-07-03 13:09:21,595 - Successfully uploaded matrix files for ERX12098962/Gene/raw
# 2025-07-03 13:09:21,597 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12098962/ERR12724463_resultSolo.out/Gene/filtered -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12098962/Gene/filtered/
# 2025-07-03 13:09:24,086 - Successfully uploaded matrix files for ERX12098962/Gene/filtered
# 2025-07-03 13:09:24,086 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12098962/ERR12724463_resultSolo.out/GeneFull/raw -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12098962/GeneFull/raw/
# 2025-07-03 13:09:30,502 - Successfully uploaded matrix files for ERX12098962/GeneFull/raw
# 2025-07-03 13:09:30,503 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/ERX12098962/ERR12724463_resultSolo.out/GeneFull/filtered -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/ERX12098962/GeneFull/filtered/
# 2025-07-03 13:09:33,336 - Successfully uploaded matrix files for ERX12098962/GeneFull/filtered
# 2025-07-03 13:09:33,337 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/SRX22985533/SRR27308183_resultSolo.out/GeneFull_ExonOverIntron/raw -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/SRX22985533/GeneFull_ExonOverIntron/raw/
# 2025-07-03 13:10:04,806 - Successfully uploaded matrix files for SRX22985533/GeneFull_ExonOverIntron/raw
# 2025-07-03 13:10:04,811 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/SRX22985533/SRR27308183_resultSolo.out/GeneFull_ExonOverIntron/filtered -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/SRX22985533/GeneFull_ExonOverIntron/filtered/
# 2025-07-03 13:10:13,760 - Successfully uploaded matrix files for SRX22985533/GeneFull_ExonOverIntron/filtered
# 2025-07-03 13:10:13,761 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/SRX22985533/SRR27308183_resultSolo.out/Gene/raw -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/SRX22985533/Gene/raw/
# 2025-07-03 13:10:21,059 - Successfully uploaded matrix files for SRX22985533/Gene/raw
# 2025-07-03 13:10:21,059 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/SRX22985533/SRR27308183_resultSolo.out/Gene/filtered -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/SRX22985533/Gene/filtered/
# 2025-07-03 13:10:24,928 - Successfully uploaded matrix files for SRX22985533/Gene/filtered
# 2025-07-03 13:10:24,929 - Uploading matrix files: /processed_datasets/scRecount/cellxgene/counted_SRXs/SRX22985533/SRR27308183_resultSolo.out/GeneFull/raw -> gs://arc-ctc-screcounter/prodC/SCRECOUNTER_2025-07-03_00-00-00/STAR/SRX22985533/GeneFull/raw/

# %% [markdown]
# # Sandbox

# %%
os.environ["DYNACONF"] = "test"

# %%
target = 'ERX8792024'


srx_metadata = Table("srx_metadata")
stmt = Query \
    .from_(srx_metadata) \
    .select(
        srx_metadata.srx_accession,
        srx_metadata.database,
        srx_metadata.entrez_id,
    ) \
    .distinct() \
    .where(srx_metadata.srx_accession == target)
        
with db_connect() as conn:
    print(pd.read_sql_query(str(stmt), conn))
# Out:
#   srx_accession database  entrez_id
# 0    ERX8792024      sra   21270500

# %% [markdown]
# # session info

# %%
# !conda list
# Out:
# # packages in environment at /home/nickyoungblut/miniforge3/envs/SRAgent_nb:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# _python_abi3_support      1.0                  hd8ed1ab_2    conda-forge
# aiobotocore               2.23.0             pyhd8ed1ab_0    conda-forge
# aiohappyeyeballs          2.6.1              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.11.14                  pypi_0    pypi
# aioitertools              0.12.0             pyhd8ed1ab_1    conda-forge
# aiosignal                 1.3.2              pyhd8ed1ab_0    conda-forge
# anndata                   0.11.4             pyhd8ed1ab_0    conda-forge
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.9.0                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# array-api-compat          1.12.0             pyhe01879c_0    conda-forge
# asgiref                   3.8.1                    pypi_0    pypi
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# attrs                     25.3.0             pyh71513ae_0    conda-forge
# aws-c-auth                0.8.7                h7743f02_1    conda-forge
# aws-c-cal                 0.8.7                h7d555fd_1    conda-forge
# aws-c-common              0.12.1               hb9d3cd8_0    conda-forge
# aws-c-compression         0.3.1                hcbd9e4e_3    conda-forge
# aws-c-event-stream        0.5.4                h286e7e7_3    conda-forge
# aws-c-http                0.9.5                hbca0721_0    conda-forge
# aws-c-io                  0.17.0               ha855f32_8    conda-forge
# aws-c-mqtt                0.12.2               hffac463_3    conda-forge
# aws-c-s3                  0.7.13               h4c9fe3b_3    conda-forge
# aws-c-sdkutils            0.2.3                hcbd9e4e_3    conda-forge
# aws-checksums             0.2.3                hcbd9e4e_3    conda-forge
# aws-crt-cpp               0.31.1               h46b750d_1    conda-forge
# aws-sdk-cpp               1.11.510             h1fa5cb7_4    conda-forge
# azure-core-cpp            1.14.0               h5cfcd09_0    conda-forge
# azure-identity-cpp        1.10.0               h113e628_0    conda-forge
# azure-storage-blobs-cpp   12.13.0              h3cf044e_1    conda-forge
# azure-storage-common-cpp  12.8.0               h736e048_1    conda-forge
# azure-storage-files-datalake-cpp 12.12.0              ha633028_1    conda-forge
# backoff                   2.2.1                    pypi_0    pypi
# bcrypt                    4.3.0                    pypi_0    pypi
# beautifulsoup4            4.13.3                   pypi_0    pypi
# biopython                 1.85                     pypi_0    pypi
# botocore                  1.38.27         pyge310_1234567_0    conda-forge
# brotli                    1.1.0                hb9d3cd8_2    conda-forge
# brotli-bin                1.1.0                hb9d3cd8_2    conda-forge
# brotli-python             1.1.0           py312h2ec8cdc_2    conda-forge
# build                     1.2.2.post1              pypi_0    pypi
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.34.5               hb9d3cd8_0    conda-forge
# ca-certificates           2025.1.31            hbcca054_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cachetools                5.5.2                    pypi_0    pypi
# capnproto                 1.0.2                h766bdaa_3    conda-forge
# cellxgene-census          1.17.0             pyh29332c3_0    conda-forge
# certifi                   2025.1.31                pypi_0    pypi
# cffi                      1.17.1          py312h06ac9bb_0    conda-forge
# charset-normalizer        3.4.1                    pypi_0    pypi
# chroma-hnswlib            0.7.6                    pypi_0    pypi
# chromadb                  0.6.3                    pypi_0    pypi
# click                     8.1.8                    pypi_0    pypi
# colorama                  0.4.6              pyhd8ed1ab_1    conda-forge
# coloredlogs               15.0.1                   pypi_0    pypi
# comm                      0.2.2              pyhd8ed1ab_1    conda-forge
# contourpy                 1.3.1           py312h68727a3_0    conda-forge
# cpython                   3.12.11         py312hd8ed1ab_0    conda-forge
# cycler                    0.12.1             pyhd8ed1ab_1    conda-forge
# dataclasses-json          0.6.7                    pypi_0    pypi
# db-dtypes                 1.4.2                    pypi_0    pypi
# debugpy                   1.8.13          py312h2ec8cdc_0    conda-forge
# decorator                 5.2.1              pyhd8ed1ab_0    conda-forge
# deprecated                1.2.18                   pypi_0    pypi
# distro                    1.9.0                    pypi_0    pypi
# durationpy                0.9                      pypi_0    pypi
# dynaconf                  3.2.10                   pypi_0    pypi
# exceptiongroup            1.2.2              pyhd8ed1ab_1    conda-forge
# executing                 2.1.0              pyhd8ed1ab_1    conda-forge
# fastapi                   0.115.11                 pypi_0    pypi
# filelock                  3.18.0                   pypi_0    pypi
# flatbuffers               25.2.10                  pypi_0    pypi
# fmt                       11.1.4               h07f6e7f_1    conda-forge
# fonttools                 4.56.0          py312h178313f_0    conda-forge
# freetype                  2.13.3               h48d6fc4_0    conda-forge
# frozenlist                1.5.0                    pypi_0    pypi
# fsspec                    2025.3.0                 pypi_0    pypi
# geos                      3.13.1               h97f6797_0    conda-forge
# gflags                    2.2.2             h5888daf_1005    conda-forge
# glog                      0.7.1                hbabe93e_0    conda-forge
# google-api-core           2.24.2                   pypi_0    pypi
# google-auth               2.38.0                   pypi_0    pypi
# google-cloud-bigquery     3.30.0                   pypi_0    pypi
# google-cloud-bigquery-storage 2.29.1                   pypi_0    pypi
# google-cloud-core         2.4.3                    pypi_0    pypi
# google-cloud-secret-manager 2.23.2                   pypi_0    pypi
# google-crc32c             1.7.0                    pypi_0    pypi
# google-resumable-media    2.7.2                    pypi_0    pypi
# googleapis-common-protos  1.69.2                   pypi_0    pypi
# greenlet                  3.1.1                    pypi_0    pypi
# grpc-google-iam-v1        0.14.2                   pypi_0    pypi
# grpcio                    1.71.0                   pypi_0    pypi
# grpcio-status             1.71.0                   pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# h2                        4.2.0              pyhd8ed1ab_0    conda-forge
# h5py                      3.13.0          nompi_py312hedeef09_100    conda-forge
# hdf5                      1.14.3          nompi_h2d575fe_109    conda-forge
# hpack                     4.1.0              pyhd8ed1ab_0    conda-forge
# httpcore                  1.0.7                    pypi_0    pypi
# httptools                 0.6.4                    pypi_0    pypi
# httpx                     0.28.1                   pypi_0    pypi
# httpx-sse                 0.4.0                    pypi_0    pypi
# huggingface-hub           0.29.3                   pypi_0    pypi
# humanfriendly             10.0                     pypi_0    pypi
# hyperframe                6.1.0              pyhd8ed1ab_0    conda-forge
# idna                      3.10               pyhd8ed1ab_1    conda-forge
# importlib-metadata        8.6.1              pyha770c72_0    conda-forge
# importlib-resources       6.5.2                    pypi_0    pypi
# iniconfig                 2.0.0                    pypi_0    pypi
# ipykernel                 6.29.5             pyh3099207_0    conda-forge
# ipython                   9.0.2              pyhfb0248b_0    conda-forge
# ipython_pygments_lexers   1.1.1              pyhd8ed1ab_0    conda-forge
# jedi                      0.19.2             pyhd8ed1ab_1    conda-forge
# jiter                     0.9.0                    pypi_0    pypi
# jmespath                  1.0.1              pyhd8ed1ab_1    conda-forge
# joblib                    1.5.1              pyhd8ed1ab_0    conda-forge
# jsonpatch                 1.33                     pypi_0    pypi
# jsonpointer               3.0.0                    pypi_0    pypi
# jupyter_client            8.6.3              pyhd8ed1ab_1    conda-forge
# jupyter_core              5.7.2              pyh31011fe_1    conda-forge
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.8           py312h84d6215_0    conda-forge
# krb5                      1.21.3               h659f571_0    conda-forge
# kubernetes                32.0.1                   pypi_0    pypi
# langchain                 0.3.20                   pypi_0    pypi
# langchain-chroma          0.2.2                    pypi_0    pypi
# langchain-community       0.3.19                   pypi_0    pypi
# langchain-core            0.3.45                   pypi_0    pypi
# langchain-openai          0.3.9                    pypi_0    pypi
# langchain-text-splitters  0.3.6                    pypi_0    pypi
# langchainhub              0.1.21                   pypi_0    pypi
# langgraph                 0.3.13                   pypi_0    pypi
# langgraph-checkpoint      2.0.21                   pypi_0    pypi
# langgraph-prebuilt        0.1.3                    pypi_0    pypi
# langgraph-sdk             0.1.57                   pypi_0    pypi
# langsmith                 0.3.15                   pypi_0    pypi
# lcms2                     2.17                 h717163a_0    conda-forge
# ld_impl_linux-64          2.43                 h712a8e2_4    conda-forge
# legacy-api-wrap           1.4.1              pyhd8ed1ab_0    conda-forge
# lerc                      4.0.0                h27087fc_0    conda-forge
# libabseil                 20250127.1      cxx17_hbbce691_0    conda-forge
# libaec                    1.1.4                h3f801dc_0    conda-forge
# libarrow                  19.0.1           hb90904d_7_cpu    conda-forge
# libarrow-acero            19.0.1           hcb10f89_7_cpu    conda-forge
# libarrow-dataset          19.0.1           hcb10f89_7_cpu    conda-forge
# libarrow-substrait        19.0.1           h1bed206_7_cpu    conda-forge
# libblas                   3.9.0           31_h59b9bed_openblas    conda-forge
# libbrotlicommon           1.1.0                hb9d3cd8_2    conda-forge
# libbrotlidec              1.1.0                hb9d3cd8_2    conda-forge
# libbrotlienc              1.1.0                hb9d3cd8_2    conda-forge
# libcblas                  3.9.0           31_he106b2a_openblas    conda-forge
# libcrc32c                 1.1.2                h9c3ff4c_0    conda-forge
# libcurl                   8.13.0               h332b0f4_0    conda-forge
# libdeflate                1.23                 h4ddbbb0_0    conda-forge
# libedit                   3.1.20250104    pl5321h7949ede_0    conda-forge
# libev                     4.33                 hd590300_2    conda-forge
# libevent                  2.1.12               hf998b51_1    conda-forge
# libexpat                  2.6.4                h5888daf_0    conda-forge
# libffi                    3.4.6                h2dba641_0    conda-forge
# libgcc                    14.2.0               h767d61c_2    conda-forge
# libgcc-ng                 14.2.0               h69a702a_2    conda-forge
# libgfortran               14.2.0               h69a702a_2    conda-forge
# libgfortran5              14.2.0               hf1ad2bd_2    conda-forge
# libgomp                   14.2.0               h767d61c_2    conda-forge
# libgoogle-cloud           2.36.0               hc4361e1_1    conda-forge
# libgoogle-cloud-storage   2.36.0               h0121fbd_1    conda-forge
# libgrpc                   1.71.0               he753a82_0    conda-forge
# libhwloc                  2.11.2          default_h0d58e46_1001    conda-forge
# libiconv                  1.18                 h4ce23a2_1    conda-forge
# libjpeg-turbo             3.0.0                hd590300_1    conda-forge
# liblapack                 3.9.0           31_h7ac8fdf_openblas    conda-forge
# liblzma                   5.6.4                hb9d3cd8_0    conda-forge
# libnghttp2                1.64.0               h161d5f1_0    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libopenblas               0.3.29          pthreads_h94d23a6_0    conda-forge
# libopentelemetry-cpp      1.20.0               hd1b1c89_0    conda-forge
# libopentelemetry-cpp-headers 1.20.0               ha770c72_0    conda-forge
# libparquet                19.0.1           h081d1f1_7_cpu    conda-forge
# libpng                    1.6.47               h943b412_0    conda-forge
# libprotobuf               5.29.3               h501fc15_1    conda-forge
# libre2-11                 2025.06.26           hba17884_0    conda-forge
# libsodium                 1.0.20               h4ab18f5_0    conda-forge
# libsqlite                 3.49.1               hee588c1_2    conda-forge
# libssh2                   1.11.1               hf672d98_0    conda-forge
# libstdcxx                 14.2.0               h8f9b012_2    conda-forge
# libstdcxx-ng              14.2.0               h4852527_2    conda-forge
# libthrift                 0.21.0               h0e7cc3e_0    conda-forge
# libtiff                   4.7.0                hd9ff511_3    conda-forge
# libtiledbsoma             1.16.2               h6b394ac_0    conda-forge
# libutf8proc               2.10.0               h202a827_0    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libwebp-base              1.5.0                h851e524_0    conda-forge
# libxcb                    1.17.0               h8a09558_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxml2                   2.13.7               h0d44e9d_0    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# llvmlite                  0.44.0          py312h374181b_1    conda-forge
# lz4-c                     1.10.0               h5888daf_1    conda-forge
# markdown-it-py            3.0.0                    pypi_0    pypi
# marshmallow               3.26.1                   pypi_0    pypi
# matplotlib-base           3.10.1          py312hd3ec401_0    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_1    conda-forge
# mdurl                     0.1.2                    pypi_0    pypi
# mizani                    0.13.1             pyhd8ed1ab_0    conda-forge
# mmh3                      5.1.0                    pypi_0    pypi
# monotonic                 1.6                      pypi_0    pypi
# more-itertools            10.7.0             pyhd8ed1ab_0    conda-forge
# mpmath                    1.3.0                    pypi_0    pypi
# msgpack                   1.1.0                    pypi_0    pypi
# multidict                 6.2.0                    pypi_0    pypi
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mypy-extensions           1.0.0                    pypi_0    pypi
# natsort                   8.4.0              pyh29332c3_1    conda-forge
# ncurses                   6.5                  h2d0b736_3    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_1    conda-forge
# networkx                  3.4.2                    pypi_0    pypi
# nlohmann_json             3.12.0               h3f2d84a_0    conda-forge
# numba                     0.61.2          py312h7bcfee6_1    conda-forge
# numpy                     1.26.4                   pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# obonet                    1.1.0                    pypi_0    pypi
# onnxruntime               1.21.0                   pypi_0    pypi
# openai                    1.66.3                   pypi_0    pypi
# openjpeg                  2.5.3                h5fbd93e_0    conda-forge
# openssl                   3.4.1                h7b32b05_0    conda-forge
# opentelemetry-api         1.31.1                   pypi_0    pypi
# opentelemetry-exporter-otlp-proto-common 1.31.1                   pypi_0    pypi
# opentelemetry-exporter-otlp-proto-grpc 1.31.1                   pypi_0    pypi
# opentelemetry-instrumentation 0.52b1                   pypi_0    pypi
# opentelemetry-instrumentation-asgi 0.52b1                   pypi_0    pypi
# opentelemetry-instrumentation-fastapi 0.52b1                   pypi_0    pypi
# opentelemetry-proto       1.31.1                   pypi_0    pypi
# opentelemetry-sdk         1.31.1                   pypi_0    pypi
# opentelemetry-semantic-conventions 0.52b1                   pypi_0    pypi
# opentelemetry-util-http   0.52b1                   pypi_0    pypi
# orc                       2.1.1                h17f744e_1    conda-forge
# orjson                    3.10.15                  pypi_0    pypi
# overrides                 7.7.0                    pypi_0    pypi
# packaging                 24.2               pyhd8ed1ab_2    conda-forge
# pandas                    2.2.3           py312hf9745cd_1    conda-forge
# parso                     0.8.4              pyhd8ed1ab_1    conda-forge
# patsy                     1.0.1              pyhd8ed1ab_1    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_1    conda-forge
# pickleshare               0.7.5           pyhd8ed1ab_1004    conda-forge
# pillow                    11.1.0          py312h80c1187_0    conda-forge
# pip                       25.0.1             pyh8b19718_0    conda-forge
# platformdirs              4.3.6              pyhd8ed1ab_1    conda-forge
# plotnine                  0.14.5             pyhd8ed1ab_0    conda-forge
# pluggy                    1.5.0                    pypi_0    pypi
# polars                    1.31.0          default_h1650462_0    conda-forge
# polars-default            1.31.0           py39hfac2b71_0    conda-forge
# posthog                   3.21.0                   pypi_0    pypi
# prometheus-cpp            1.3.0                ha5d0236_0    conda-forge
# prompt-toolkit            3.0.50             pyha770c72_0    conda-forge
# propcache                 0.3.0                    pypi_0    pypi
# proto-plus                1.26.1                   pypi_0    pypi
# protobuf                  5.29.3                   pypi_0    pypi
# psutil                    7.0.0           py312h66e93f0_0    conda-forge
# psycopg2-binary           2.9.10                   pypi_0    pypi
# pthread-stubs             0.4               hb9d3cd8_1002    conda-forge
# ptyprocess                0.7.0              pyhd8ed1ab_1    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_1    conda-forge
# pyarrow                   19.0.1                   pypi_0    pypi
# pyarrow-core              19.0.1          py312h01725c0_0_cpu    conda-forge
# pyarrow-hotfix            0.7                pyhd8ed1ab_0    conda-forge
# pyasn1                    0.6.1                    pypi_0    pypi
# pyasn1-modules            0.4.1                    pypi_0    pypi
# pycparser                 2.22               pyh29332c3_1    conda-forge
# pydantic                  2.10.6                   pypi_0    pypi
# pydantic-core             2.27.2                   pypi_0    pypi
# pydantic-settings         2.8.1                    pypi_0    pypi
# pygments                  2.19.1             pyhd8ed1ab_0    conda-forge
# pynndescent               0.5.13             pyhd8ed1ab_1    conda-forge
# pyparsing                 3.2.2              pyhd8ed1ab_0    conda-forge
# pypika                    0.48.9                   pypi_0    pypi
# pyproject-hooks           1.2.0                    pypi_0    pypi
# pysocks                   1.7.1              pyha55dd90_7    conda-forge
# pytest                    8.3.5                    pypi_0    pypi
# pytest-asyncio            0.25.3                   pypi_0    pypi
# python                    3.12.9          h9e4cc4f_1_cpython    conda-forge
# python-dateutil           2.9.0.post0        pyhff2d567_1    conda-forge
# python-dotenv             1.0.1                    pypi_0    pypi
# python-gil                3.12.11              hd8ed1ab_0    conda-forge
# python-tzdata             2025.2             pyhd8ed1ab_0    conda-forge
# python_abi                3.12                    5_cp312    conda-forge
# pytz                      2025.1                   pypi_0    pypi
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     26.3.0          py312hbf22597_0    conda-forge
# qhull                     2020.2               h434a139_5    conda-forge
# re2                       2025.06.26           h9925aae_0    conda-forge
# readline                  8.2                  h8c095d6_2    conda-forge
# regex                     2024.11.6                pypi_0    pypi
# requests                  2.32.3                   pypi_0    pypi
# requests-oauthlib         2.0.0                    pypi_0    pypi
# requests-toolbelt         1.0.0                    pypi_0    pypi
# rich                      13.9.4                   pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# s2n                       1.5.15               hd830067_0    conda-forge
# s3fs                      2025.5.1           pyhd8ed1ab_0    conda-forge
# scanpy                    1.11.2             pyhd8ed1ab_0    conda-forge
# scikit-learn              1.7.0           py312h7a48858_1    conda-forge
# scipy                     1.15.2          py312ha707e6e_0    conda-forge
# seaborn                   0.13.2               hd8ed1ab_3    conda-forge
# seaborn-base              0.13.2             pyhd8ed1ab_3    conda-forge
# session-info2             0.1.2              pyhd8ed1ab_0    conda-forge
# setuptools                75.8.2             pyhff2d567_0    conda-forge
# shapely                   2.1.1           py312h21f5128_0    conda-forge
# shellingham               1.5.4                    pypi_0    pypi
# six                       1.17.0             pyhd8ed1ab_0    conda-forge
# snappy                    1.2.1                h8bd8927_1    conda-forge
# sniffio                   1.3.1                    pypi_0    pypi
# somacore                  1.0.28             pyh29332c3_0    conda-forge
# soupsieve                 2.6                      pypi_0    pypi
# spdlog                    1.15.3               h10b92b3_0    conda-forge
# sqlalchemy                2.0.39                   pypi_0    pypi
# sragent                   0.1.1                    pypi_0    pypi
# stack_data                0.6.3              pyhd8ed1ab_1    conda-forge
# starlette                 0.46.1                   pypi_0    pypi
# statsmodels               0.14.4          py312hc0a28a1_0    conda-forge
# sympy                     1.13.3                   pypi_0    pypi
# tabulate                  0.9.0                    pypi_0    pypi
# tbb                       2022.1.0             h4ce085d_0    conda-forge
# tenacity                  9.0.0                    pypi_0    pypi
# threadpoolctl             3.6.0              pyhecae5ae_0    conda-forge
# tiktoken                  0.9.0                    pypi_0    pypi
# tiledb                    2.27.2               haba8ea6_5    conda-forge
# tiledb-py                 0.34.0          py312h9777f10_0    conda-forge
# tiledbsoma-py             1.16.2          py312h6095420_0    conda-forge
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tokenizers                0.21.1                   pypi_0    pypi
# tornado                   6.4.2           py312h66e93f0_0    conda-forge
# tqdm                      4.67.1             pyhd8ed1ab_1    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_1    conda-forge
# typer                     0.15.2                   pypi_0    pypi
# types-requests            2.32.0.20250306          pypi_0    pypi
# typing-extensions         4.12.2               hd8ed1ab_1    conda-forge
# typing-inspect            0.9.0                    pypi_0    pypi
# typing_extensions         4.12.2             pyha770c72_1    conda-forge
# tzdata                    2025.1                   pypi_0    pypi
# umap-learn                0.5.7           py312h7900ff3_1    conda-forge
# unicodedata2              16.0.0          py312h66e93f0_0    conda-forge
# urllib3                   2.3.0                    pypi_0    pypi
# uvicorn                   0.34.0                   pypi_0    pypi
# uvloop                    0.21.0                   pypi_0    pypi
# watchfiles                1.0.4                    pypi_0    pypi
# wcwidth                   0.2.13             pyhd8ed1ab_1    conda-forge
# websocket-client          1.8.0                    pypi_0    pypi
# websockets                15.0.1                   pypi_0    pypi
# wheel                     0.45.1             pyhd8ed1ab_1    conda-forge
# wrapt                     1.17.2          py312h66e93f0_0    conda-forge
# xmltodict                 0.14.2                   pypi_0    pypi
# xorg-libxau               1.0.12               hb9d3cd8_0    conda-forge
# xorg-libxdmcp             1.1.5                hb9d3cd8_0    conda-forge
# yarl                      1.18.3                   pypi_0    pypi
# zeromq                    4.3.5                h3b0a872_7    conda-forge
# zipp                      3.21.0             pyhd8ed1ab_1    conda-forge
# zlib                      1.3.1                hb9d3cd8_2    conda-forge
# zstandard                 0.23.0                   pypi_0    pypi
# zstd                      1.5.7                hb8e6e7a_2    conda-forge

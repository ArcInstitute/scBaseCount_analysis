# %% [markdown]
# # Goal
#
# * Expand tissue annotations beyond CellxGene's tissue categories
#   * e.g., include plant tissues
#     * for plants, using categories from the [scPlantDB](https://biobigdata.nju.edu.cn/scplantdb/dataset)

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
from pathlib import Path
import pandas as pd
from pypika import Query, Table, Field, Column, Criterion, functions as fn

# %%
from SRAgent.db.connect import db_connect
from SRAgent.db.utils import db_list_tables, db_glimpse_tables, db_get_table, execute_query
from SRAgent.db.get import db_find_srx

# %%
# set to prod database
os.environ['DYNACONF'] = 'prod'

# %%
# get base of github repo
base_dir = !git rev-parse --show-toplevel
base_dir = Path(base_dir[0])

# %%
# list database tables
with db_connect() as conn:
    print("\n".join(db_list_tables(conn)))
# Out:
# screcounter_star_results
# eval
# scbasecamp_metadata
# screcounter_trace
# srx_srr
# srx_metadata
# screcounter_log
# scbasecamp_metadata_tmp
# screcounter_star_params

# %% [markdown]
# # Current tissue categories

# %%
#tissue_cat_file = "data/2025-02-20_tissue_categories.csv"
tissue_cat_file = base_dir / 'data' / 'tissues' / '2025-03-11_tissue_categories.csv.gz'
tissue_cat = pd.read_csv(tissue_cat_file)
print(tissue_cat.shape)
tissue_cat.head()
# Out:
# (5618, 2)
#                                   tissue      category
# 0                       2 layer spheroid         other
# 1  3 layer spheroid channel 1,epithelial         other
# 2             3 layer spheroid channel 2         other
# 3                  3D healthy skin model  skin of body
# 4                             A549 cells          lung

# %% [markdown]
# # Organisms

# %%
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select(tbl.organism) \
    .distinct()

with db_connect() as conn:
    orgs = [str(x) for x in pd.read_sql(str(stmt), conn)["organism"].tolist()]
print("\n".join(sorted(orgs)))
# Out:
# Ambystoma mexicanum
# Anas platyrhynchos
# Anopheles gambiae
# Anser cygnoides
# Arabidopsis thaliana
# Bos taurus
# Caenorhabditis elegans
# Callithrix jacchus
# Canis lupus
# Capra hircus
# Cavia porcellus
# Chlorocebus aethiops
# Danio rerio
# Drosophila melanogaster
# Equus caballus
# Erinaceus europaeus
# Felis catus
# Gallus gallus
# Gasterosteus aculeatus
# Gorilla gorilla
# Heterocephalus glaber
# Homo sapiens
# Macaca mulatta
# Mesocricetus auratus
# Monodelphis domestica
# Mus musculus
# Mustela putorius
# None
# Ornithorhynchus anatinus
# Oryctolagus cuniculus
# Oryza sativa
# Ovis aries
# Pan paniscus
# Pan troglodytes
# Rattus norvegicus
# Salmo salar
# Schistosoma mansoni
# Solanum lycopersicum
# Sus scrofa
# Taeniopygia guttata
# Trachemys scripta
# Tupaia belangeri
# Vicugna pacos
# Xenopus tropicalis
# Zea mays
# metagenome
# other

# %% [markdown]
# # Plant tissue annotations

# %%
plants = ["Arabidopsis thaliana", "Oryza sativa", "Solanum lycopersicum", "Zea mays"]

# %% [markdown]
# ## SRX metadata

# %%
# list all records for a feature in scbasecamp_metadata
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select(tbl.organism, tbl.tissue) \
    .distinct() \
    .where(tbl.organism.isin(plants))

with db_connect() as conn:
    df = pd.read_sql(str(stmt), conn)
print(df.shape)
df.head()
# Out:
# (682, 2)
#                organism                                       tissue
# 0  Arabidopsis thaliana                          10-day-old seedling
# 1  Arabidopsis thaliana                         12-day-old seedlings
# 2  Arabidopsis thaliana  12-day-old seedlings (callus), callus cells
# 3  Arabidopsis thaliana           12-day-old seedlings (whole plant)
# 4  Arabidopsis thaliana                         14-day-old seedlings

# %%
# merge df with tissue_cat on tissue
df_j = df.merge(tissue_cat, on="tissue", how="left")
df_j
# Out:
#                  organism                                       tissue  \
# 0    Arabidopsis thaliana                          10-day-old seedling
# 1    Arabidopsis thaliana                         12-day-old seedlings
# 2    Arabidopsis thaliana  12-day-old seedlings (callus), callus cells
# 3    Arabidopsis thaliana           12-day-old seedlings (whole plant)
# 4    Arabidopsis thaliana                         14-day-old seedlings
# ..                    ...                                          ...
# 677              Zea mays                                 Tassel FM-S3
# 678              Zea mays                                       unsure
# 679              Zea mays               V2 seedling leaf 2, distal 6cm
# 680              Zea mays                              whole seedlings
# 681              Zea mays                            WT 4DAP endosperm
#
#      category
# 0         NaN
# 1    seedling
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 677    flower
# 678     other
# 679       NaN
# 680       NaN
# 681       NaN
#
# [682 rows x 3 columns]

# %%
# summarize the categories
df_j["category"].value_counts()
# Out:
# category
# root              28
# leaf              26
# other             19
# flower            16
# seedling          12
# seed              10
# shoot apex         4
# callus             4
# sensory system     4
# placenta           2
# protoplast         1
# ovary              1
# Name: count, dtype: int64

# %%
# pull out non-other plant tissues
df_j[(df_j["category"] != "other") & (df_j["category"].notnull())]
# Out:
#                  organism                        tissue    category
# 1    Arabidopsis thaliana          12-day-old seedlings    seedling
# 16   Arabidopsis thaliana        Arabidopsis root cells        root
# 17   Arabidopsis thaliana  Arabidopsis Root Protoplasts  protoplast
# 18   Arabidopsis thaliana                        callus      callus
# 19   Arabidopsis thaliana                        Callus      callus
# ..                    ...                           ...         ...
# 663              Zea mays                      Seedling    seedling
# 672              Zea mays           shoot apex (SAM+P6)  shoot apex
# 673              Zea mays           Shoot apex (SAM+P6)  shoot apex
# 676              Zea mays                  Tassel FM-S2      flower
# 677              Zea mays                  Tassel FM-S3      flower
#
# [108 rows x 3 columns]

# %%
# pull out non-other
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select(tbl.organism, tbl.tissue) \
    .distinct() \
    .where(tbl.tissue.isin(["HAE+ FACS", "ear primordia"]))
    

with db_connect() as conn:
    df_check = pd.read_sql(str(stmt), conn)
df_check
# Out:
#                organism         tissue
# 0  Arabidopsis thaliana      HAE+ FACS
# 1              Zea mays  ear primordia

# %%
# list all tissues
print("\n".join([f" - '{x}'" for x in sorted(df["tissue"].unique().tolist())]))
# Out:
#  - '10-day-old seedling'
#  - '10DAP endosperm'
#  - '12 day seedling'
#  - '12-day-old seedlings'
#  - '12-day-old seedlings (callus), callus cells'
#  - '12-day-old seedlings (whole plant)'
#  - '14-day-old seedlings'
#  - '2-week-old seedling'
#  - '2-week-old seedlings'
#  - '2cm root tips'
#  - '4-day-old seedlings'
#  - '4-day-old whole seedlings'
#  - '5-day seedling shoot'
#  - '5mm root tip'
#  - '7-d-old continuous light grown seedlings'
#  - '7-day-old continuous light grown seedlings'
#  - '7-day-old rice seedling'
#  - '7-day-old rice seedlings'
#  - '7-day-old rice seedlings undergoing de-etiolation'
#  - '7-day-old rice seedlings undergoing deetiolation'
#  - '7-day-old seedlings'
#  - 'Adventitious root'
#  - 'Aerial tissue (protoplasts extracted from the whole aerial tissue)'
#  - 'Aerial tissue of 5-day-old Arabidopsis seedlings'
#  - 'Arabidopsis Root Protoplasts'
#  - 'Arabidopsis root cells'
#  - 'Axillary bud'
#  - 'B73, seedling, fresh'
#  - 'Callus'
#  - 'Cotyledon'
#  - 'Detached Arabidopsis leaves'
#  - 'Ear'
#  - 'Ear FM-S2'
#  - 'Ear FM-S3'
#  - 'Ear apex'
#  - 'Ear inflorescence apex (ear primordia)'
#  - 'Ear inflorescence tissue'
#  - 'Ear primordia'
#  - 'Early maize ear'
#  - 'Endosperm'
#  - 'Floral tissue'
#  - 'Flower / Female germline cells in ovule primordia'
#  - 'Flower buds and rosette leaves'
#  - 'Flowers'
#  - 'Flowers (Flowers of Sha)'
#  - 'Flowers (from Col-0), Soil (from Commelle, La Doua)'
#  - 'Flowers and Soil'
#  - 'Flowers and soil'
#  - 'Flowers of Bay-0'
#  - 'Flowers of Cvi-0, Soil from Perouges, La Doua'
#  - 'Flowers of Ws-0 and soil from Perouge, Saint-Etienne'
#  - 'Fruit'
#  - 'Germinating seeds'
#  - 'Ground plant'
#  - 'HAE+ FACS'
#  - 'Hypocotyl'
#  - 'Imbibed seeds'
#  - 'Immature ear tissue'
#  - 'Immature ears'
#  - 'Immature/early maize ear'
#  - 'Inoculated leaves'
#  - 'Kernel'
#  - 'Kernel, filling stage (18 days after pollination)'
#  - 'Lateral root tissue at the bending zone of the main root'
#  - 'Leaf'
#  - 'Leaf (phyllosphere)'
#  - 'Leaf Tissue'
#  - 'Leaf base'
#  - 'Leaf microbiome (phyllosphere)'
#  - 'Leaf primodium'
#  - 'Leaf primordia'
#  - 'Leaf tissue'
#  - 'Leaf tissue (core leaf microbiome / phyllosphere)'
#  - 'Leaf tissue (from Col-0) and soil sample'
#  - 'Leaf tissues'
#  - 'Leaf tissues (NAM founder leaf tissues pooled across replicates)'
#  - 'Leaf tissues (NAM founder leaves)'
#  - 'Leaf tissues from NAM founder'
#  - 'Leaf tissues from NAM founder lines'
#  - 'Leaf tissues from NAM founder plants'
#  - 'Leaf tissues from NAM founders'
#  - 'Leaf-associated tissue (phyllosphere)'
#  - 'Leaves'
#  - 'Leaves and soil'
#  - 'Leaves of Col-0, soil from Commelle, La Doua'
#  - 'Maize leaf tissue'
#  - 'Maize root tips (primary roots)'
#  - 'Maize seedling tissue'
#  - 'Maize seedlings (pool20)'
#  - 'Manually dissected root apices'
#  - 'Mature pollen'
#  - 'Microspores'
#  - 'Mixed-stage male gametophytes'
#  - 'NAM founder leaf tissues'
#  - 'OE-18 4DAF siliques'
#  - 'Ovary'
#  - 'Ovule primordia and associated flower tissue'
#  - 'Panicle (booting, flowering, grain-filling stages)'
#  - 'Panicle (booting-stage, 4-month-old Nipponbare cultivar)'
#  - 'Panicle (unopened florets)'
#  - 'Panicle (young panicles, unopened florets, developing grains)'
#  - 'Perouges soil control, Saint-Etienne'
#  - 'Pistil'
#  - 'Pollen'
#  - 'Pollen (mature pollen)'
#  - 'Pollen, rosette leaves, open flowers, inflorescence'
#  - 'Pollen, unopen flower buds, rosette leaves, open flowers, seedlings'
#  - 'Primary root tips'
#  - 'Primary root tissue'
#  - 'Protoplast cells from whole roots of 7–8‑day‑old seedlings'
#  - 'Protoplasts'
#  - 'Rice anthers (wild-type, stage 7)'
#  - 'Rice leaves'
#  - 'Rice root cells'
#  - 'Rice seedling'
#  - 'Root'
#  - 'Root (phloem poles)'
#  - 'Root cells'
#  - 'Root cells (protoplasts isolated from roots)'
#  - 'Root meristem'
#  - 'Root phloem tissue'
#  - 'Root phloem tissue, root tip, phloem pole cells'
#  - 'Root tip'
#  - 'Root tips'
#  - 'Root tips from 6-day-old seedlings'
#  - 'Root tips of maize seedlings'
#  - 'Root tissue'
#  - 'Root tissue (protoplasted root)'
#  - 'Root-tip protoplast cells'
#  - 'Roots'
#  - 'Roots (nuclei from the root of 7 days-old Arabidopsis seedlings)'
#  - 'Roots of 7 days-old Arabidopsis seedlings'
#  - 'Roots of Col-0, soil from Commelle, La Doua'
#  - 'Rosette'
#  - 'Rosette (21-day-old)'
#  - 'Rosette (30 days old)'
#  - 'Rosette leaf, open flowers, seedlings'
#  - 'Rosette leaf, open flowers, unopen flower buds, inflorescence, seedlings'
#  - 'Rosette leaves'
#  - 'Rosette leaves, open flowers, 10-day-old seedlings'
#  - 'Rosette, 21 days old'
#  - 'Rosette, Age: 30 days old'
#  - 'SAM (Shoot Apical Meristem), plastochrons 1-6'
#  - 'SAM, plastochrons 1 - 6'
#  - 'Seedling'
#  - 'Seedling (12 days old)'
#  - 'Seedling tissue'
#  - 'Seedling, 7 days old'
#  - 'Seedlings'
#  - 'Shoot apex (SAM+P6)'
#  - 'Shoot apical meristem'
#  - 'Shoots'
#  - 'Silique'
#  - 'Stem'
#  - 'Tassel'
#  - 'Tassel FM-S2'
#  - 'Tassel FM-S3'
#  - 'Tissue forming a lateral root'
#  - 'Tomato pericarp'
#  - 'Tomato seedlings (whole plants at the stage of four fully expanded true leaves)'
#  - 'V2 seedling leaf 2, distal 6cm'
#  - 'WT 4DAP endosperm'
#  - 'Whole root'
#  - 'Whole root (excluding tip)'
#  - 'Whole root cells (protoplasts extracted from the whole roots of 7–8 day old seedlings)'
#  - 'Whole root from seedlings'
#  - 'Whole root tissue, focusing on periderm'
#  - 'Whole root – specifically, protoplast cells extracted from the roots of 7–8 day old seedlings'
#  - 'Whole silique'
#  - 'Young ear of rice'
#  - 'Young panicles (booting), unopened florets (flowering), developing grains (grain-filling)'
#  - 'Young panicles, unopened florets, developing grains'
#  - 'aerial parts'
#  - 'all'
#  - 'blade–sheath boundary of lower-canopy maize leaves (protoplasts)'
#  - 'blade–sheath boundary protoplasts (upper canopy)'
#  - 'blade–sheath boundary protoplasts from maize leaf'
#  - 'bud'
#  - 'bud (germinated seed at budding stage)'
#  - 'bulk genomic DNA'
#  - 'callus'
#  - 'callus (12-day induction culture)'
#  - 'callus (4-day induction culture)'
#  - 'callus (Nipponbare cultivar)'
#  - 'callus (from 12-day-old seedlings)'
#  - 'callus (inbred line: Huolv13)'
#  - 'callus (induction culture for 12 days)'
#  - 'callus (induction culture, 8 days)'
#  - 'callus (undifferentiated plant tissue) from 12-day-old seedlings'
#  - 'callus culture'
#  - 'callus derived from 12-day-old seedlings'
#  - 'callus tissue (from 12-day-old seedlings)'
#  - 'core leaf'
#  - 'cotyledon'
#  - 'cotyledon, whole aerial tissue of 5-day-old seedlings'
#  - 'crown root'
#  - 'crown root (10-day-old seedling)'
#  - 'culm'
#  - 'developing ear primordia'
#  - 'developing ear primordia (2–5 mm stage)'
#  - 'developing ear primordia (2–5 mm)'
#  - 'developing ear primordia (2–5 mm, stage V10)'
#  - 'developing leaf tissue'
#  - 'ear'
#  - 'ear immature meristem'
#  - 'ear inflorescence (spikelet-pair meristem, SPM)'
#  - 'ear inflorescence apex'
#  - 'ear primordia'
#  - 'ear primordia (2-5 mm)'
#  - 'ear primordia (2–5 mm)'
#  - 'ear primordia (2–5 mm, V10 stage)'
#  - 'ear primordia (V10 stage, 2–5 mm)'
#  - 'ear shoot meristem (ear SM)'
#  - 'ear spikelet-pair meristem (SPM)'
#  - 'ear, floral meristem stage 1 (FM-S1)'
#  - 'ear, spikelet meristem (SPM)'
#  - 'early ear'
#  - 'early maize ear'
#  - 'early-stage male germ cells (microspores, tetrads, bicellular microspores, mature pollen)'
#  - 'early-stage microspore'
#  - 'embryo from mature seed'
#  - 'embryo of mature seed'
#  - 'embryogenic callus'
#  - 'embryonic root'
#  - 'endosperm'
#  - 'endosperm (10 days after pollination)'
#  - 'endosperm12'
#  - 'environmental sample (ground plant, soil)'
#  - 'environmental sample (plant-associated, field station)'
#  - 'epicotyl'
#  - 'epicotyl (48 h seedling stage, cultivar Longrui 999)'
#  - 'epicotyl (48 h seedling)'
#  - 'epicotyl (seedling shoot)'
#  - 'epicotyl (seedling stage, 0 h)'
#  - 'epicotyl (seedling, 48 h)'
#  - 'epicotyl (seedling, 48h)'
#  - 'epicotyl (seedling, 96 h)'
#  - 'epicotyl of 96 h seedling'
#  - 'epicotyl of maize seedlings'
#  - 'female germline cells from flower'
#  - 'female germline cells, ovule primordia, flower'
#  - 'flag leaf'
#  - 'floral and vegetative tissues'
#  - 'floral and vegetative tissues (flower buds, rosette leaves, open flowers, seedlings)'
#  - 'floral receptacle'
#  - 'floral tissue'
#  - 'floral tissue and mature pollen'
#  - 'floral tissue, unopen flower buds, rosette leaves, open flowers, inflorescences'
#  - 'floral tissue, unopen flower buds, rosette leaves, open flowers, inflorescences, seedlings'
#  - 'floral tissue, unopened flower buds, rosette leaves, open flowers'
#  - 'flower'
#  - 'flower (female germline cells)'
#  - 'flower (ovule primordia)'
#  - 'flower (ovule primordia), female germline cells'
#  - 'flower (ovule primordia, female germline cells)'
#  - 'flower abscission zone'
#  - 'flower buds and rosette leaves'
#  - 'flower buds, open flowers, rosette leaves, inflorescences, seedlings'
#  - 'flower buds, rosette leaves'
#  - 'flower buds, rosette leaves, inflorescences'
#  - 'flower ovule primordia'
#  - 'flower ovule primordia (female germline)'
#  - 'flower, female germline precursor cells'
#  - 'flowers'
#  - 'flowers and soil'
#  - 'flowers, soil'
#  - 'frozen spikelet'
#  - 'fruit'
#  - 'fruit (7 days post-anthesis)'
#  - 'fruit (mature stage, cultivar 'luoyang')'
#  - 'fruit (mature)'
#  - 'fruit (mature, cultivar 'luoyang')'
#  - 'fruit pericarp (red ripe stage)'
#  - 'fully expanded true leaves'
#  - 'genomic DNA (whole plant)'
#  - 'germinated pollen'
#  - 'germinated seed (bud stage)'
#  - 'germinated seed bud'
#  - 'germinated seed, bud stage'
#  - 'germinating seedling'
#  - 'germinating seeds'
#  - 'germinating seeds (1.25 days old)'
#  - 'grain (rice grain, 10 days after flowering)'
#  - 'ground plant'
#  - 'ground plant (environmental medium)'
#  - 'ground plant (environmental medium); not specified'
#  - 'ground plant (environmental sample)'
#  - 'ground plant (environmental sample); not specific tissue'
#  - 'ground plant (environmental sample); tissue not specified'
#  - 'ground plant (environmental sample, no discrete tissue specified)'
#  - 'ground plant (environmental sample, not specific tissue)'
#  - 'ground plant (field-collected Arabidopsis thaliana)'
#  - 'ground plant (field-collected Arabidopsis)'
#  - 'ground plant (field-collected)'
#  - 'ground plant (field-grown)'
#  - 'ground plant (not further specified)'
#  - 'ground plant material'
#  - 'ground plant material (not further specified)'
#  - 'ground plant material (phyllosphere)'
#  - 'ground plant sample (not further specified)'
#  - 'ground plant tissue'
#  - 'ground-plant sample (not further specified)'
#  - 'hypocotyl'
#  - 'hypocotyl callus'
#  - 'imbibed seeds'
#  - 'immature anthers (male meiocytes)'
#  - 'immature ear meristem'
#  - 'immature embryo'
#  - 'immature embryo (12 days after self-pollination)'
#  - 'immature embryo (12 days after self-pollination), embryogenic callus induction'
#  - 'immature embryo callus'
#  - 'immature maize ear tissue'
#  - 'infected leaves'
#  - 'inflorescence meristem (ear IM)'
#  - 'kernel'
#  - 'leaf'
#  - 'leaf (10 day-old seedling)'
#  - 'leaf (10-day-old seedling)'
#  - 'leaf (10-day-old seedlings)'
#  - 'leaf (10-day-old tomato leaf protoplasts)'
#  - 'leaf (2-week-old rosette)'
#  - 'leaf (3rd leaf, 18-day-old plants)'
#  - 'leaf (40 days old)'
#  - 'leaf (40-day-old seedling stage, recombinant inbred line)'
#  - 'leaf (Kitaake variety)'
#  - 'leaf (four-leaf stage, 15-day-old plant)'
#  - 'leaf (four-week-old seedlings)'
#  - 'leaf (front zone of lesion)'
#  - 'leaf (jointing stage, 75 days)'
#  - 'leaf (jointing stage, 75-day-old plants)'
#  - 'leaf (male)'
#  - 'leaf (mature, 3 month old)'
#  - 'leaf (mesophyll cells)'
#  - 'leaf (microbiome focus)'
#  - 'leaf (microbiome)'
#  - 'leaf (phyllosphere microbiome study)'
#  - 'leaf (phyllosphere microbiome)'
#  - 'leaf (phyllosphere)'
#  - 'leaf (phyllosphere/core leaf microbiome)'
#  - 'leaf (seedling stage)'
#  - 'leaf (seedling)'
#  - 'leaf (seedling, 40 days old)'
#  - 'leaf (seedling, four fully expanded true leaves)'
#  - 'leaf (seedling, one-month-old)'
#  - 'leaf (seedling, three-leaf and one-heart stage)'
#  - 'leaf (seedling, three-leaf/one-heart stage)'
#  - 'leaf (seedling-stage, three-leaf and one-heart stage)'
#  - 'leaf (sporophyte vegetative stage)'
#  - 'leaf (sporophyte vegetative stage, male)'
#  - 'leaf (sporophyte vegetative)'
#  - 'leaf (sporophyte vegetative-stage leaf)'
#  - 'leaf (sporophyte, vegetative stage)'
#  - 'leaf (three-leaf stage)'
#  - 'leaf (three-leaf, one-heart stage seedling)'
#  - 'leaf (two-week-old seedlings)'
#  - 'leaf (young leaf)'
#  - 'leaf (young leaf, cultivar Kitaake)'
#  - 'leaf (young leaf, seedling stage)'
#  - 'leaf (young leaves)'
#  - 'leaf (young seedling)'
#  - 'leaf and stem (plant microbiome)'
#  - 'leaf blade–sheath boundary'
#  - 'leaf blade–sheath boundary (protoplasts)'
#  - 'leaf epidermis'
#  - 'leaf microbiome'
#  - 'leaf phyllosphere'
#  - 'leaf phyllosphere (ground plant)'
#  - 'leaf phyllosphere (ground plant/environmental sample)'
#  - 'leaf phyllosphere (microbial community from leaf surface)'
#  - 'leaf phyllosphere (microbiome)'
#  - 'leaf phyllosphere (surface microbiome)'
#  - 'leaf phyllosphere microbiome'
#  - 'leaf primordia'
#  - 'leaf protoplasts'
#  - 'leaf surface (phyllosphere)'
#  - 'leaf tissue'
#  - 'leaf tissues'
#  - 'leaf tissues at seedling stage'
#  - 'leaf tissues, seedling'
#  - 'leaf, stomatal lineage'
#  - 'leaf/seedling tissue'
#  - 'leaf9'
#  - 'leaves'
#  - 'leaves and soil'
#  - 'leaves of 10-day-old seedlings'
#  - 'maize immature ear'
#  - 'maize immature/early ear tissue'
#  - 'maize leaf'
#  - 'maize leaf blade–sheath boundary'
#  - 'maize leaf blade–sheath boundary (lower and upper canopy)'
#  - 'maize leaf blade–sheath boundary (upper canopy protoplasts)'
#  - 'maize leaf tissue'
#  - 'maize leaf-blade/sheath boundary protoplasts'
#  - 'maize seedling'
#  - 'maize seedling tissue'
#  - 'maize seedlings'
#  - 'male gametophyte (developing pollen vegetative cells)'
#  - 'male germ cells (tetrads, microspores, pollen, sperm)'
#  - 'male meiocyte'
#  - 'male meiocyte sacs (prophase I of meiosis)'
#  - 'male meiocyte sacs (prophase of meiosis)'
#  - 'male meiocytes (from immature anthers, leptotene–pachytene stage)'
#  - 'male meiocytes (prophase of meiosis)'
#  - 'male meiocytes from immature anthers'
#  - 'male meiocytes from immature anthers (meiotic prophase)'
#  - 'mature leaf'
#  - 'mature leaf tissue'
#  - 'mature leaves'
#  - 'mature pollen'
#  - 'mature pollen, rosette leaves, open flowers, young seedlings'
#  - 'meiocyte (tetrads/microspores)'
#  - 'mesophyll cells'
#  - 'mixed-stage male gametophytes'
#  - 'not available'
#  - 'not specified'
#  - 'ovule primordia'
#  - 'ovule primordia (female flower tissue)'
#  - 'ovule primordia (female germline cells)'
#  - 'ovule primordia (female germline cells), flower'
#  - 'ovule primordia (female germline differentiation stage)'
#  - 'ovule primordia (female germline precursor cells, early/mid/late stages)'
#  - 'ovule primordia (female germline primordia)'
#  - 'ovule primordia (female germline), flower'
#  - 'ovule primordia (female germline, reproductive flower tissue)'
#  - 'ovule primordia (flower tissue)'
#  - 'ovule primordia (flower)'
#  - 'ovule primordia (flower) at three developmental time points'
#  - 'ovule primordia, flower, female germline'
#  - 'panicle'
#  - 'panicle (booting stage)'
#  - 'panicle (booting stage, young panicle)'
#  - 'panicle (booting/flowering stage)'
#  - 'panicle (flowering panicle stage)'
#  - 'panicle (flowering panicle)'
#  - 'panicle (flowering stage florets)'
#  - 'panicle (flowering stage)'
#  - 'panicle (unopened florets)'
#  - 'panicle (unopened florets, flowering stage)'
#  - 'panicle (young panicle, booting stage)'
#  - 'panicle at booting stage'
#  - 'panicle florets (unopened, flowering stage)'
#  - 'phyllosphere'
#  - 'phyllosphere (ground plant)'
#  - 'phyllosphere (ground plant, leaf surface)'
#  - 'phyllosphere (leaf surface microbiome)'
#  - 'phyllosphere (leaf surface)'
#  - 'pistil'
#  - 'plant leaves'
#  - 'plant protoplasts'
#  - 'pollen'
#  - 'pollen, rosette leaf, open flowers, unopen flower buds'
#  - 'pollen, rosette leaves, inflorescences'
#  - 'pollen, unopen flower buds, open flowers, rosette leaves, inflorescences, 10-day-old pooled seedlings'
#  - 'pollen, unopen flower buds, rosette leaves, open flowers'
#  - 'pollen, unopen flower buds, rosette leaves, open flowers, inflorescence, 10-day-old seedlings'
#  - 'pollen, unopened flower buds, rosette leaf tissues, open flowers, seedlings'
#  - 'pollen, unopened flower buds, rosette leaves, open flowers, inflorescence, 10-day-old seedlings'
#  - 'primary root tips'
#  - 'protoplasts'
#  - 'rhizosphere'
#  - 'rhizosphere (root-associated soil)'
#  - 'rhizosphere/phyllosphere microbiome (ground plant environment)'
#  - 'rice leaves'
#  - 'rice nuclei (tissue type not further specified)'
#  - 'rice seedlings'
#  - 'rice sheath'
#  - 'rice sheath (4-leaf stage)'
#  - 'rice shoot'
#  - 'root'
#  - 'root (7 days post germination)'
#  - 'root (maize seedling root)'
#  - 'root (seedling)'
#  - 'root (seedling, three weeks old)'
#  - 'root (six-day-old seedling, 0.5–0.7 cm from root tip)'
#  - 'root and shoot cells from 4-day-old seedlings'
#  - 'root cells'
#  - 'root cells from lateral root formation region'
#  - 'root hair'
#  - 'root meristem'
#  - 'root nuclei'
#  - 'root phloem'
#  - 'root phloem pole'
#  - 'root tip'
#  - 'root tip protoplasts (5-day-old seedlings)'
#  - 'root tip protoplasts (5-day-old)'
#  - 'root tip, all cell types of root'
#  - 'root tips'
#  - 'root tissue'
#  - 'root tissue (bending zone associated with lateral root formation)'
#  - 'root tissue (whole root without the tip)'
#  - 'root tissue from the bending zone associated with lateral root formation'
#  - 'root, rhizosphere soil'
#  - 'roots'
#  - 'rosette'
#  - 'rosette (vegetative stage)'
#  - 'rosette leaf'
#  - 'rosette leaf, open flowers'
#  - 'rosette leaf, open flowers, 10-day-old seedlings'
#  - 'rosette leaf, open flowers, inflorescence, flower buds, seedlings'
#  - 'rosette leaf, open flowers, inflorescence, seedlings'
#  - 'rosette leaf, open flowers, inflorescences, unopen flower buds, seedlings'
#  - 'rosette leaf, open flowers, unopened flower buds, inflorescence, seedlings'
#  - 'rosette leaves'
#  - 'rosette leaves (31-day-old)'
#  - 'rosette leaves (whole plant)'
#  - 'rosette leaves, flower buds, open flowers, inflorescence, seedlings'
#  - 'rosette leaves, open flower buds, inflorescence, seedlings'
#  - 'rosette leaves, open flowers, seedlings'
#  - 'rosette leaves, open flowers, unopened flower buds, inflorescences, 10-day-old seedlings'
#  - 'rosette leaves, unopen flower buds, open flowers, inflorescences, seedlings'
#  - 'secondary root'
#  - 'seed'
#  - 'seed (24 hours after germination)'
#  - 'seed (embryo of mature seed)'
#  - 'seed (metagenomic DNA from rice seed)'
#  - 'seedling'
#  - 'seedling (10-day-old)'
#  - 'seedling (12 days old)'
#  - 'seedling (2-week-old)'
#  - 'seedling (6 days old)'
#  - 'seedling (germination)'
#  - 'seedling (mature stage)'
#  - 'seedling leaf'
#  - 'seedling leaf (10-day-old B73 inbred line)'
#  - 'seedling leaves'
#  - 'seedling root'
#  - 'seedling tissue'
#  - 'seedling, leaf'
#  - 'seedling, leaf tissues'
#  - 'seedlings'
#  - 'seedlings (14-day-old)'
#  - 'seedlings (7-day-old)'
#  - 'sheath'
#  - 'shoot'
#  - 'shoot (10 days post-germination)'
#  - 'shoot apex (14-day-old seedlings)'
#  - 'shoot apex (SAM+P6)'
#  - 'shoot apex protoplasts'
#  - 'shoot apex, third leaf'
#  - 'shoot apical meristem'
#  - 'shoot apical meristem (panicle-initiation stage)'
#  - 'shoot, root'
#  - 'shoot, root (seedling stage)'
#  - 'shoots'
#  - 'silique'
#  - 'sperm'
#  - 'spikelet'
#  - 'spikelet meristem (ear SM)'
#  - 'stem'
#  - 'stems and leaves'
#  - 'third leaf'
#  - 'tiller bud'
#  - 'tomato fruit at breaker stage'
#  - 'top third of leaf 1'
#  - 'true leaves'
#  - 'unopen flower buds'
#  - 'unopen flower buds and rosette leaves'
#  - 'unopen flower buds, open flowers, rosette leaves, inflorescences'
#  - 'unopen flower buds, rosette leaves'
#  - 'unopen flower buds, rosette leaves, open flowers'
#  - 'unopen flower buds, rosette leaves, open flowers, inflorescence'
#  - 'unopen flower buds, rosette leaves, open flowers, inflorescences, seedlings'
#  - 'unopen flower buds, rosette leaves, open flowers, mature pollen vegetative cell'
#  - 'unopen flower buds, rosette leaves, open flowers/inflorescences, 10-day-old seedlings'
#  - 'unopened florets (young inflorescences, flowering stage)'
#  - 'unsure'
#  - 'unsure (bulk transcriptomic RNA from Arabidopsis thaliana; tissue not specified)'
#  - 'unsure (likely ground plant/environmental sample)'
#  - 'unsure (likely leaf or root, but not specified)'
#  - 'unsure (likely whole plant or rhizosphere sample)'
#  - 'unsure (likely whole plant or seedling, not specified)'
#  - 'unsure (likely whole plant or unspecified tissue)'
#  - 'unsure (likely whole seedling or leaf, not specified)'
#  - 'unsure (likely whole seedlings or plant tissue, not specified)'
#  - 'unsure (not specified in SRA or BioSample)'
#  - 'unsure (not specified in SRA or BioSample; likely whole plant or leaf)'
#  - 'unsure (not specified in experiment metadata)'
#  - 'unsure (not specified in experiment or BioSample metadata)'
#  - 'unsure (not specified in metadata)'
#  - 'unsure (not specified in metadata, likely whole plant or seedling)'
#  - 'unsure (not specified in metadata, likely whole plant)'
#  - 'unsure (not specified in record, but likely leaf or aerial tissue based on Sclerotinia infection studies)'
#  - 'unsure (not specified in sample metadata)'
#  - 'unsure/not specified'
#  - 'unsure; likely environmental or plant tissue (not specified)'
#  - 'unsure; not specified in sample metadata'
#  - 'valve (flower valve, 3 days after stage 14 flower, ecotype Col-0)'
#  - 'valve tissue from 3-day-old stage-14 flowers'
#  - 'whole 4-day-old seedling'
#  - 'whole flowers'
#  - 'whole ground plant material (field-collected)'
#  - 'whole plant'
#  - 'whole plant (3-week-old Arabidopsis, ecotype Columbia)'
#  - 'whole plant (3-week-old)'
#  - 'whole plant (exact tissue not specified)'
#  - 'whole plant (genomic DNA)'
#  - 'whole plant (ground material)'
#  - 'whole plant (ground plant environmental medium)'
#  - 'whole plant (ground plant material)'
#  - 'whole plant (ground sample)'
#  - 'whole plant (not further specified)'
#  - 'whole plant (seedling, acclimated in temperate climate)'
#  - 'whole root'
#  - 'whole root excluding tip'
#  - 'whole root less tip'
#  - 'whole root tip'
#  - 'whole roots'
#  - 'whole seed'
#  - 'whole seedling'
#  - 'whole seedlings'
#  - 'whole seedlings (2-week-old)'
#  - 'whole shoot'
#  - 'whole shoot (10-day-old seedlings)'
#  - 'whole shoots from 10-day-old seedlings'
#  - 'whole shoots of 4-day-old seedlings'
#  - 'whole silique'
#  - 'young ear'
#  - 'young flag leaf (leaf covering the inflorescence)'
#  - 'young inflorescence (stage 2)'
#  - 'young inflorescence (stage S2)'
#  - 'young inflorescences'
#  - 'young leaf'
#  - 'young leaf (mutant, cultivar Kitaake)'
#  - 'young leaf (seedling stage)'
#  - 'young leaves'
#  - 'young panicle'
#  - 'young panicle (booting stage)'
#  - 'young panicle at flowering'
#  - 'young panicle, unopened floret, developing grain'
#  - 'young panicles (booting stage), unopened florets (flowering stage), developing grains (grain-filling stage)'
#  - 'young panicles, unopened florets, developing grains'
#  - 'young spike'
#  - 'young, unexpanded leaves'

# %%
# tissue categories added to existing tissue categories
infile = base_dir / "data" / "tissues" / "2025-06-30_tissue_categories.csv"
pd.read_csv(infile).groupby("category").count().sort_values("tissue", ascending=False)
# Out:
#                   tissue
# category
# brain               2210
# other               1550
# blood               1279
# lung                 832
# embryo               668
# ...                  ...
# axilla                 4
# paracolic gutter       3
# ureter                 3
# neck                   2
# chest wall             2
#
# [75 rows x 1 columns]

# %% [markdown]
# # Animal tissue categories

# %%
#tissue_cat_file = "data/2025-02-20_tissue_categories.csv"
tissue_cat_file = base_dir / 'data' / 'tissues' / '2025-06-30_tissue_categories.csv'
tissue_cat = pd.read_csv(tissue_cat_file)
print(tissue_cat.shape)
tissue_cat.head()
# Out:
# (6250, 2)
#                                   tissue      category
# 0                       2 layer spheroid         other
# 1  3 layer spheroid channel 1,epithelial         other
# 2             3 layer spheroid channel 2         other
# 3                  3D healthy skin model  skin of body
# 4                             A549 cells          lung

# %%
plants = ["Arabidopsis thaliana", "Oryza sativa", "Solanum lycopersicum", "Zea mays"]

# %%
# list all records for a feature in scbasecamp_metadata, in which STAR results are not available; excluding plants
meta = Table("srx_metadata")
star = Table("screcounter_star_results")

star_query = (
    Query.from_(star)
    .select('*')
)

stmt = Query \
    .from_(star) \
    .join(meta) \
    .on(star.sample == meta.srx_accession) \
    .select(meta.tissue) \
    .distinct() \
    .where(~meta.organism.isin(plants))

with db_connect() as conn:
    df = pd.read_sql(str(stmt), conn)
print(df.shape)
df.head()
# Out:
# (13113, 1)
#                                               tissue
# 0  bone marrow (hematopoietic progenitors: Lin- c...
# 1                        lamina propria CD4+ T cells
# 2  ventricular myocardium (postnatal day 4 mouse ...
# 3    placenta (deep layer, maternal-fetal interface)
# 4  dentate gyrus and subventricular zone of the b...

# %%
# join on tissue categories
# merge df with tissue_cat on tissue
df_j = df.merge(tissue_cat, on="tissue", how="left")
df_j
# Out:
#                                                   tissue   category
# 0      bone marrow (hematopoietic progenitors: Lin- c...        NaN
# 1                            lamina propria CD4+ T cells        NaN
# 2      ventricular myocardium (postnatal day 4 mouse ...        NaN
# 3        placenta (deep layer, maternal-fetal interface)        NaN
# 4      dentate gyrus and subventricular zone of the b...      brain
# ...                                                  ...        ...
# 13112                                                FNA      other
# 13113          skin epithelium (epidermis, P2 back skin)        NaN
# 13114     transplanted human intestinal organoids (tHIO)  intestine
# 13115   Esophageal adenocarcinoma tumor microenvironment        NaN
# 13116                              Brain, right striatum        NaN
#
# [13117 rows x 2 columns]

# %%
# filter to nan category values
df_j = df_j[df_j["category"].isna()].sort_values("tissue")
df_j
# Out:
#                                                   tissue category
# 5653                          17.1 Wk human fetal kidney      NaN
# 3784   21-day human developmental cell aggregates (HD...      NaN
# 9070        24-hour post fertilization zebrafish embryos      NaN
# 363    26-somite stage ocular area (lens placode region)      NaN
# 10674                              2D Placental pericyte      NaN
# ...                                                  ...      ...
# 1821                                  zebrafish explants      NaN
# 526    zebrafish heads, cranial neural crest-derived ...      NaN
# 3722                          zebrafish larval intestine      NaN
# 5490                         zebrafish larval intestines      NaN
# 4291                                    zebrafish marrow      NaN
#
# [9404 rows x 2 columns]

# %%
9404 / 200
# Out:
# 47.02

# %%
# list all tissues in batches
def list_tissue_batch(df, batch_num=0, batch_size=200):
    batch = df.iloc[batch_size * batch_num:batch_size * (batch_num + 1)]
    print("\n".join([f" - '{x}'" for x in sorted(batch["tissue"].unique().tolist())]))

list_tissue_batch(df_j, 47)
# Out:
#  - 'zebrafish heads, cranial neural crest-derived cells'
#  - 'zebrafish larval intestine'
#  - 'zebrafish larval intestines'
#  - 'zebrafish marrow'

# %% [markdown]
# # Checking overall tissue categories

# %%
# tissue categories added to existing tissue categories
infile = base_dir / "data" / "tissues" / "2025-06-30_tissue_categories.csv"
df_tissue_cats = pd.read_csv(infile)
df_tissue_cats
# Out:
#                                                   tissue      category
# 0                                       2 layer spheroid         other
# 1                  3 layer spheroid channel 1,epithelial         other
# 2                             3 layer spheroid channel 2         other
# 3                                  3D healthy skin model  skin of body
# 4                                             A549 cells          lung
# ...                                                  ...           ...
# 15640                                 zebrafish explants         other
# 15641  zebrafish heads, cranial neural crest-derived ...          head
# 15642                         zebrafish larval intestine     intestine
# 15643                        zebrafish larval intestines     intestine
# 15644                                   zebrafish marrow   bone marrow
#
# [15645 rows x 2 columns]

# %%
# group by category and count
df_tissue_cats.groupby("category").count().sort_values("tissue", ascending=False)
# Out:
#                   tissue
# category
# brain               2210
# other               1550
# blood               1279
# lung                 832
# embryo               668
# ...                  ...
# axilla                 4
# paracolic gutter       3
# ureter                 3
# neck                   2
# chest wall             2
#
# [75 rows x 1 columns]

# %%
# remove duplicate tissues  
df_tissue_cats.drop_duplicates(subset="tissue", inplace=True)
df_tissue_cats
# Out:
#                                                   tissue      category
# 0                                       2 layer spheroid         other
# 1                  3 layer spheroid channel 1,epithelial         other
# 2                             3 layer spheroid channel 2         other
# 3                                  3D healthy skin model  skin of body
# 4                                             A549 cells          lung
# ...                                                  ...           ...
# 15640                                 zebrafish explants         other
# 15641  zebrafish heads, cranial neural crest-derived ...          head
# 15642                         zebrafish larval intestine     intestine
# 15643                        zebrafish larval intestines     intestine
# 15644                                   zebrafish marrow   bone marrow
#
# [15545 rows x 2 columns]

# %%
# write the results
outfile = base_dir / "data" / "tissues" / "2025-06-30_tissue_categories.csv.gz"
df_tissue_cats.to_csv(outfile, index=False, compression="gzip")

# %% [markdown]
# # OLD

# %% [markdown]
# ### Tissue summary

# %%
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select(tbl.organism, tbl.tissue) \
    .distinct()

with db_connect() as conn:
    df_srx_meta = pd.read_sql(str(stmt), conn)
df_srx_meta
# Out:
#            organism                                             tissue
# 0      Homo sapiens                                       Fecal matter
# 1              None                                               None
# 2      Mus musculus                           cortex (postnatal day 5)
# 3      Homo sapiens  iPSC-derived pancreatic duct-like organoids (P...
# 4      Mus musculus                                forebrain microglia
# ...             ...                                                ...
# 45675   Canis lupus                       bone marrow (CD34+ enriched)
# 45676  Mus musculus  murine tracheal epithelial cells (mTECs), air–...
# 45677  Homo sapiens              acute myeloid leukemia patient sample
# 45678  Homo sapiens         CD8+ T lymphocytes (from tumor co-culture)
# 45679  Mus musculus                                     Gut epithelium
#
# [45680 rows x 2 columns]

# %%
df_srx_meta = df_srx_meta.merge(
    tissue_cat_j.drop(columns=["category_x", "category_y"]),
    on="tissue", how="left"
)
df_srx_meta
# Out:
#            organism                                  tissue       category
# 0              None                                    None          other
# 1      Mus musculus        caudal tissues from E8.5 embryos            NaN
# 2       Danio rerio                     hepatized intestine      intestine
# 3      Homo sapiens            iPSC-derived neural cultures            NaN
# 4        Bos taurus                             macrophages  immune system
# ...             ...                                     ...            ...
# 6386   Homo sapiens              PBMC Healthy control (T50)          blood
# 6387   Homo sapiens                         parahippocampus          brain
# 6388   Mus musculus                                 urethra            NaN
# 6389  Gallus gallus  Basilar papillae (auditory epithelium)            NaN
# 6390   Homo sapiens            colon, mesenteric lymph node            NaN
#
# [6391 rows x 3 columns]

# %%
# filter to NaN
pd.set_option('display.max_rows', None)
df_srx_meta[df_srx_meta["category"].isnull()]["organism"].value_counts()
# Out:
# organism
# Homo sapiens               826
# Mus musculus               717
# Rattus norvegicus          106
# other                       85
# Danio rerio                 32
# Drosophila melanogaster     32
# metagenome                  31
# Gallus gallus               28
# Callithrix jacchus          27
# Macaca mulatta              25
# Sus scrofa                  18
# Pan troglodytes             17
# Canis lupus                 16
# Zea mays                    12
# Arabidopsis thaliana        10
# Ovis aries                   9
# Bos taurus                   7
# Solanum lycopersicum         5
# Equus caballus               5
# Schistosoma mansoni          4
# Oryza sativa                 2
# Caenorhabditis elegans       2
# Oryctolagus cuniculus        2
# Heterocephalus glaber        1
# Name: count, dtype: int64

# %%
# just mammals
pd.set_option('display.max_rows', 10)
mammals = [
    "Homo sapiens",
    "Mus musculus",
    "Rattus norvegicus",
    "Callithrix jacchus",
    "Macaca mulatta",
    "Sus scrofa",
    "Pan troglodytes",
    "Canis lupus",
    "Ovis aries",
    "Bos taurus",
    "Equus caballus",
    "Oryctolagus cuniculus",
    "Heterocephalus glaber"
]

df_srx_meta_mam = df_srx_meta[(df_srx_meta["category"].isnull()) & (df_srx_meta["organism"].isin(mammals))]
df_srx_meta_mam
# Out:
#           organism                            tissue category
# 1     Mus musculus  caudal tissues from E8.5 embryos      NaN
# 3     Homo sapiens      iPSC-derived neural cultures      NaN
# 7     Homo sapiens                    bronchus, lung      NaN
# 14    Homo sapiens                    ovarian tissue      NaN
# 15    Homo sapiens                    cardiomyocytes      NaN
# ...            ...                               ...      ...
# 6374  Mus musculus        ventricular cardiac tissue      NaN
# 6383  Mus musculus                    coronal suture      NaN
# 6384  Mus musculus        lung resident immune cells      NaN
# 6388  Mus musculus                           urethra      NaN
# 6390  Homo sapiens      colon, mesenteric lymph node      NaN
#
# [1776 rows x 3 columns]

# %%
print("\n".join(sorted(df_srx_meta_mam["tissue"].unique().tolist())))
# Out:
# 1st molar tooth
# 2-cell embryo
# 2nd molar tooth
# 3D culture
# 3D culture in RGF BME
# 8990_TBR1_S9_L003
# 8th section of the small intestine
# ALI culture of tracheal aspirate derived airway basal stem cells
# Abdominal adhesion tissue
# Acute slice culture of glioma resection
# Adipose Tissue
# Adrenal-Gland
# Adult Ovary Tissue
# Adult Ovary Tissue, Follicle 2-5mm
# Adult Ovary Tissue, Stroma
# Adult human heart
# Adult midbrain
# Adult mouse ILC progenitors from femur
# Adult mouse ILC progenitors harvested from femur
# Amnion
# Amygdala
# Aorta
# Aortic root
# Apex of the heart
# Apical region of left ventricle
# Arcuate-Median Eminence
# Area postrema and nucleus tractus solitarius
# Ascitic fluid
# Atrioventricular node
# Atrioventricular node, left cardiac atrium
# Auditory (AUD)
# Auditory Cortex
# B-cell
# B-cells
# B-cells (CVID naive B-cell)
# B-lymphocyte
# B-lymphocyte, Peripheral Blood
# B16-OVA tumor
# BALF cells (Bronchoalveolar Lavage Fluid)
# BALF cells (Bronchoalveolar lavage fluid)
# BALF cells (bronchoalveolar lavage fluid cells)
# BLA (Basolateral Amygdala)
# BVSC
# Basolateral amygdala
# Blastocyst
# Blastoids and day 8 blastocysts
# Blood, Spleen, Liver, Lung, Heart
# Blood-derived leukocytes
# Blood; antigen-specific B lymphocytes from PBMC
# Bone Marrow (BM)
# Bone Marrow 180d post treatment (M27)
# Bone Marrow 30d post treatment (M29)
# Bone Marrow 360d post treatment (T55)
# Bone Marrow 90d post treatment (M88)
# Bone Marrow Baseline (T53)
# Bone Marrow from AML PDXs
# Bone Marrow-Derived Macrophages (BMDM)
# Bone marrow, Thymus
# Bone marrow-derived macrophages
# Brain (Cerebral organoid)
# Brain (Cerebral organoids)
# Brain (cerebral organoids)
# Brain (from cerebral organoid)
# Brain (from cerebral organoids)
# Brain - Central Amygdala
# Brain, Ventricular-Subventricular zone
# Brain, cerebral organoid
# Brain-Nucleus accumbens core (NAcc)
# Brain; PFC (Prefrontal Cortex); Expressing scFLARE2 + TRE-mCherry-p2a-bReaChES
# Breast (normal mammary gland)
# Breast, normal mammary gland
# Brodmann area 6
# Bronchial AEC
# Bronchial AEC (Airway Epithelial Cells)
# Bronchiole
# Bronchoalveolar Lavage (BAL) cells
# Bronchoalveolar Lavage Fluid (BALF)
# Bronchoalveolar Lavage Fluid (BALF) cells
# Bronchoalveolar lavage (BAL) cells
# Bronchoalveolar lavage fluid (BALF cells)
# Bronchus
# Buccal
# Bulk_TILs_replica_1_tumor
# C11 (human induced pluripotent stem cells)
# CA1
# CA1 (hippocampus)
# CA1 (part of the hippocampus)
# CD14+ cells from peripheral blood mononuclear cells
# CD3+ T cells from bone marrow
# CD34 cells differentiated down erythroid lineage
# CD4 T cells
# CD4+ T cells (isolated from peripheral blood)
# CD4+ cells
# CD45+ (Lineage positive) WBC
# CD45+ (Lineage positive) White Blood Cells (WBC)
# CD45+ cells from subcutaneous CT26 tumor
# CD45+ cells from tumor
# CD45+ immune cells from brain parenchyma
# CD45+ live cells from visceral white adipose tissue (vWAT)
# CD45- (Lineage Negative) WBC
# CD45- (Lineage Negative) White Blood Cells (WBC)
# CD8+ OT1 T cells
# CD8+ T cells (sorted from tumors)
# CD8+ T cells from Bone Marrow
# CD8+ tissue-resident memory (TRM) cells
# CLA (Cortex Layer Anterior)
# CMM (Cardiac Mesenchymal Cells)
# CMM (Cardiac Muscle Mass)
# CMM (Cardiac Myocyte-like cells)
# CN7 e10.5 GFP-positive and negative
# CSF (Cerebrospinal Fluid) cells
# CSF leukocytes
# CVID memory switched b-cell
# CVID memory unswitched B-cell
# CVID memory unswitched b-cell
# CVID naïve B-cell
# CVID naïve b-cell
# Caecum (Colon tissue)
# Caecum (colon tissue)
# Caecum, Colon
# Caecum, Transverse colon, Sigmoid colon, Mesenteric lymph nodes
# Calu3 cell line
# Calu3 cells
# Calu3 cells (lung epithelial cell line)
# Calu3 cells (lung epithelial cells)
# Calu3 cells (lung)
# Cardiac Mesenchymal Cells
# Central amygdala
# Central gray substance of midbrain
# Central gray substance of midbrain (Periaqueductal gray neurons)
# Central gray substance of midbrain (periaqueductal gray)
# Cephalic vein
# Cerebellar Nestin-expressing progenitors
# Cerebral hemisphere
# Cerebral organoids
# Cerebrum
# Choroid plexus (CP)
# Ciliary body, Left Eye
# Circulating Tumor Cells (CTCs)
# Colon
# Cornea (Left Eye)
# Corpus cavernosum
# Cortex (Ctx1)
# Cortex (FACS-purified)
# Cortex and hippocampal formation
# Costal-cartilage-derived stem cells (CDSCs)
# Cotyledon
# Cryopreserved PBMC
# Ctx1 (Cortex)
# Ctx1.5
# Ctx2
# Ctx3
# Ctx3 (Cortex)
# Cultured-Cell-from-PSC
# D-LN
# D-LN (Dendritic Lymph Node)
# D-LN (Dendritic Lymph Nodes)
# D-LN (Dendritic cells from duodenal lymph nodes)
# D-LN (Dorsal Lymph Node)
# D-LN (Duodenal Lymph Node)
# D-LN (Duodenal Lymph Node), Gut tissue
# D-LN (Duodenal Lymph Nodes)
# DVC (Dorsal Vagal Complex)
# Dendritic Lymph Nodes (D-LN)
# Dentate Gyrus
# Dermal fibroblasts
# Dermal fibroblasts (Skin)
# Dermal fibroblasts (skin)
# Dermis (skin)
# Distal Colon
# Dorsal Vagal Complex (DVC)
# Dorsal root ganglion (DRG)
# Dorsal root ganglion neuron
# Dorsal skin wound
# Dorsolateral Prefrontal Cortex
# Dorsolateral Prefrontal Cortex (Brodmann area 46)
# Dorsolateral Prefrontal cortex (Brodmann area 46)
# Dorsolateral prefrontal cortex
# Duodenal Lymph Node (D-LN)
# Duodenal Lymph Nodes
# Duodenal Lymph Nodes (D-LN)
# Duodenum
# E10.5 anterior PGC migratory niche
# E10.5 posterior PGC migratory niche
# E11.5 PGC migratory niche / AGM
# E13.5 eye peripheral retina
# E13.5 mouse tissue
# E54 Frontal
# E9.5 anterior PGC migratory niche
# E9.5 posterior PGC migratory niche
# EMT6 tumor
# EMT6 tumors
# ENCC (Enteric Neural Crest Cells)
# ENS
# ENS (Enteric Nervous System)
# ENS (enteric nervous system)
# ES (Embryonic Stem)
# ESC-derived distal lung epithelium
# ESC-derived lung epithelium
# ESC-derived lung epithelium and iPSC-derived lung mesenchyme
# ESC-derived tip-like cells
# Embryo
# Embryonic day 6.5
# Embryonic disc
# Embryonic structure
# Embryonic structure (Embryo at the 8-cell stage)
# Engineered Heart Muscle
# Epiblast and amnion spheroids
# Epicardial Adipose Tissue
# Epithelium of circumvallate/von Ebner's gland (vEG)
# Expanded ILC2s from PBMC-derived ILC2s
# FACS-sorted microglia
# Feces
# Female brain section containing the medial hypothalamus
# Fetal Small Intestine
# Fetal brain (Inferior Parietal Cortex)
# Fetal brain (Ventrolateral Frontal Cortex)
# Fetal brain, Dorsolateral Frontal Cortex
# Fetal brain, Dorsolateral prefrontal cortex
# Fetal brain, Inferior Parietal Cortex
# Fetal brain, Orbitofrontal Cortex (OFC)
# Filamentous conceptus
# Fovea retina
# Frontal cortex neurons
# GBM and adjacent brain tissue
# GBM centre
# GBM neurospheres
# GBM surround
# GEMM, PbCre_Pten/Rb 47 Weeks
# GINS grafts under mouse renal capsule
# GL261 tumor
# GP muscle
# Gastrocnemius-plantaris (GP) muscle
# Ghost Matrigel Plugs
# Gingival tissue, peritoneal washes
# Gland
# Glioblastoma organoid
# Glioblastoma tissue
# Glioma surgical specimen
# H1 cells, PSC to definitive endoderm
# H1 hESC (Human Embryonic Stem Cells)
# H1 hESC, Day 11 of differentiation
# H1299 cell line
# H1299 cell line (lung cancer)
# H1299 cells
# H1299 cells (lung cancer cell line)
# H9 (Embryonic Stem Cell)
# H9 hPSC
# H9 human embryonic stem cells
# HCC cell line
# HCT116
# HCT116 cell line
# HEK293T cells
# HMLER
# HMPOS cell line
# HPG axis-related tissues
# HeLa cells
# Healthy memory switched B-cell
# Healthy memory switched B-cell, Memory B-cell
# Healthy memory unswitched B-cell
# Healthy naïve B-cell
# Hidradenitis suppurativa lesional skin - Dermis
# Hippocampal Intermediate Progenitors (Day 1)
# Hippocampal Intermediate Progenitors (Day 2)
# Hippocampal Intermediate Progenitors (Day 3)
# Hippocampal Intermediate Progenitors (Day 5)
# Hippocampi
# Human Dermal Cells
# Human ES Cell Line
# Human ES-derived DA neuron
# Human Engineered Heart Muscle
# Human Kidney Cortex
# Human Kidney Cortex - DN2
# Human Kidney Cortex - DN5
# Human Kidney Cortex - DN7
# Human Mediastinal LN 10L
# Human Mediastinal LN 10R
# Human Mediastinal LN 12R
# Human Mediastinal LN 4R
# Human Tumor Tissue
# Human bronchial epithelial cells (HBECs)
# Human epithelial tracheal, cultured
# Human fetal DRG
# Human prostate basal epithelia
# Human prostate fibromuscular stroma
# Human prostate luminal epithelia
# Human prostate transition zone
# I1DN cKit+ Cd11b- cells
# ICx_Posterior_Lateral_L5
# ILC progenitors
# ILC progenitors from adult mouse femur
# ILC progenitors from femur
# ILC2 (Innate Lymphoid Cells type 2)
# ILC2 cells
# ILC2 from femur
# ILCs from blood
# ILCs from blood and bone marrow
# Ileal tissue
# Induced Pluripotent Stem Cells (iPSCs)
# Infarct zone
# Inguinal WAT
# Inner cell mass
# Inner cell mass, Embryo
# Interventricular septum
# Invasive ductal breast carcinoma
# Iris
# Islet cells
# Isolated root tip cells
# Isolated single cells from normal human islets
# Isolated single cells from type-2 diabetes human islets
# K562 cells
# Kidney Cortex
# Kidney Cortex - DN3
# Kidney Cortex / Medulla
# Kidney Medulla
# Kidney cross-section
# LLC tumour
# LN (Lymph Node)
# LNI-DDRR-nosupplements
# Lamina propria of colon and matching mesenteric lymph nodes
# Lamina propria of colon and mesenteric lymph nodes
# Lamina propria of colon, Mesenteric lymph nodes
# Lateral Septum
# Left Eye (Cornea sclera wedge)
# Left Eye (Iris)
# Left Eye (Macula)
# Left ventricle region 1B
# Left ventricle region 2B
# Left ventricle region 3B
# Lin-Kit+ cells
# Locus coeruleus
# Longus dorsi muscles
# Lung, bronchoalveolar lavage fluid
# Lymph Node (LN)
# Lymph nodes (inguinal, axillary, and brachial)
# M cells from Peyer's patches
# MB - IC (Midbrain - Intercalated)
# MB - MRN-CUN-RN-RR-PPN-PRT
# MB_RN
# MB_RN (brain region related to spinal projecting neurons)
# MC38 murine colon carcinoma
# MCF7 (breast cancer cell line)
# MDCK cell
# MII oocyte
# MII oocytes and 2-cell embryos
# MOs_FRP
# MY_GRN_PRN_LC
# Male brain section containing the medial hypothalamus
# Mammary Gland
# Mammary Gland / Mammary T cells
# Mammary T cells
# Mammary gland
# Mammary tissue
# Marjolin ulcer
# Mediastinal Lymph Node
# Medulla
# Meibomian gland
# Memory B-cell
# Memory B-cell (CVID memory unswitched B-cell)
# Mesenteric artery - small (< 150 um)
# Mesenteric lymph node, Colon (lamina propria)
# Mesenteric lymph node, Lamina propria of colon
# Mesenteric lymph node, caecum, transverse colon, sigmoid colon
# Mesenteric lymph node, colon (lamina propria)
# Metastatic CRPC Biopsy
# MidbrainDorsal
# MidbrainVentral
# Mix of L-cells and HEK293T cells
# Mouse E13.5
# Mouse Müller glia (cultured in vitro)
# Mouse tracheal epithelial cells
# Mucosa of the small intestine of wild type C57 mouse
# Murine C57BL/6 ovarian surface epithelium
# Myocardium
# Müller glia in vitro
# N/A
# NAc (Nucleus Accumbens) nuclei
# NAc nuclei
# NSCLC tumor tissue
# NSCLC tumor tissues
# Naïve B-cell
# Naïve b-cell
# Neuroblastoma O-PDX (Patient-Derived Xenograft)
# Nonsmoker airway basal stem cells
# Normal Omentum tissue
# Nuclei from specimen CBTM-386C_LA
# Nuclei from specimen H0037_AX
# Nuclei from specimen H0037_LA
# Nuclei from the left ventricle
# Nuclei from the left ventricle of Donor3, CBTM-364B
# Nuclei from the left ventricle of the heart
# Nucleus accumbens
# Nucleus accumbens shell
# OS tumor
# OSS
# OSS (Osteosarcoma)
# OT-I cells
# OT-I cells from B16-OVA tumor
# Oesophagus
# Oesophagus, Mucosa including epithelium
# Olfactory Bulb
# Olfactory Bulb (OB)
# Oocytes
# Osteosarcoma
# Outer tissue of filamentous conceptus
# P14 T cells sorted from B16-OVA tumor
# P20 Testis
# PAR-POST-PRE-SUB-ProS (mouse brain region)
# PBMC 30d post treatment (M30)
# PBMC Healthy control (T43)
# PBMC Healthy control (T46)
# PBMC and notochordal-like cells
# PBMC-derived ILC2s
# PCL scaffold
# PDAC liver met
# PDAC liver metastasis
# PDAC peritoneal node met
# PDX GBM22 orthotopic xenograft (frontal-cortex)
# PDX tumor harvest from mice
# PGCLC (Primordial Germ Cell-Like Cells)
# PL-ILA (Posterior part of the lateral amygdala)
# PL-ILA (anterior part of the brain)
# PP
# PP (presumably peripheral blood)
# Palatine tonsil
# PanIN pancreas
# Panc-1 cells
# Pancreatic Lymph Node
# Pancreatic islet
# Paraventricular hypothalamic nucleus
# Patient-Derived Organoid
# Penis
# Peri-implantitis bone tissue
# Peri-implantitis gingiva tissue
# Peripheral Blood Leukopak
# Peripheral Blood Mononuclear Cells (PBMCs), Plasma
# Peripheral CD4+ T cells
# Peripheral T cells
# Peripheral T cells, TCRab+
# Peripheral blood (PBMC)
# Peripheral blood (PBMCs)
# Peripheral blood T cells, TCRab+
# Peripheral-Blood
# Peritoneal Cells
# Pia-derived leukocytes
# Pig
# Pig epididymis caput
# Pituitary
# PolyA RNA from Calu3 cells
# PolyA RNA from H1299 cells (lung cancer cell line)
# Pons
# Pons-Medulla
# Pooled Dorsal Striatum
# Prefrontal Cortex
# Prenatal lung
# Primary CD138+ MM cells
# Primary CD138+ Multiple Myeloma (MM) cells
# Primary T cells
# Primordial germ cell
# Pulmonary arteries
# Pulmonary veins
# PyMT-BO1 tumour
# RPE
# RPE (Retinal Pigment Epithelium)
# RPE-choroid, Periphery
# RPE/choroid single cells
# RSP (Region of interest in the brain)
# Reprogrammed MEFs (Mouse Embryonic Fibroblasts)
# Reprogrammed Mouse Embryonic Fibroblasts (MEFs)
# Retina + Choroid
# Retinal Pigment Epithelial Cell from Bioprinted Tissue
# Retinal Pigment Epithelium (RPE)
# Retinal Pigment Epithelium/Choroid
# Retinal Pigment Epithelium/Choroid, peripheral retina
# Retrosplenial Cortex
# Right Eye (Cornea)
# Right Eye (Macula)
# Right coronary artery
# Right ventricle region 2G
# Rumen
# SHH Medulloblastoma (MB) tumors with MBEN histology
# SScortex
# STR - LSX (specific brain region)
# Sciatic Nerve
# Sciatic nerves
# Second mandibular molar
# Septum apex
# Septum base
# Sigmoid colon
# Single Dorsal root ganglion neuron
# Sinoatrial node
# Skeletal Muscle
# Skin
# Skin (back skin and matched livers)
# Skin (dermal fibroblasts)
# Somatosensory cortex
# Sorted NAc nuclei
# Sorted activated B cells from peripheral blood
# Sorted cells from pooled spleen and lymph nodes
# Spinal Cord (SC)
# Spleen, Lymph Node, Bone Marrow
# Stalk (embryo stage, Carnegie Stage 7)
# Striatal grafts
# Striatum & Ventricular-Subventricular Zone
# Striatum & ventricular-subventricular zone
# Striatum, Substantia Nigra
# StriatumDorsal
# StriatumVentral
# Subependymal zone (SEZ)
# Substantia Nigra (FACS-purified)
# Substantia Nigra, Retina, Cerebral Cortices, Striatum, Midbrain
# Suprachiasmatic nucleus
# Sympath
# T-Cell
# TH - MD-IMD-PCN-CL (specific brain region)
# TH - VAL-VPM-VPL-VM
# TPS cell-derived teratomas
# TS543 (Patient-derived glioma neurospheres)
# Temporal Lobe
# Testicular tissue
# Thalamus
# Thoracic aorta perivascular adipose tissue
# Total Liver Homogenate
# Total clear cell renal cell carcinoma Homogenate
# Trachea, bronchi, lung parenchyma
# Transverse colon
# Trigeminal neurons
# Trophectoderm
# Tumor tissue from small intestinal tumors
# Tumor tissue from small intestinal tumors of ApcMin mice
# U937 acute myeloid leukemia cell line
# Urethra
# Uterine-placental interface tissue
# VE-enriched cell populations from E5.5 and E6.25 mouse embryos
# VE-enriched cell populations from E5.5 and E6.25 wild type mouse embryos
# VISp_L2-3 (Visual cortex layer 2-3)
# VISp_L5-L6
# Viable human prostate epithelia
# Viable human prostate luminal epithelia
# Viable human prostate peripheral zone
# Viable human prostate transition zone
# Viable human prostate “double negative” epithelia
# Visceral Adipose Tissue (VAT)
# Visceral Endoderm (VE) enriched cell populations
# Visceral adipose tissue
# Visual Cortex (VISm)
# Visual cortex (VISp)
# Whole Tumour
# Whole Tumour (B16-IFNA4 Tumours)
# Whole Tumour (B16-IFNA9 Tumours)
# Whole celiac ganglion
# Whole organism (embryonic stage)
# XCL4 cell line
# Zona Incerta
# abdomen
# abdominal adhesion tissue
# activated B cells from peripheral blood
# acute slice culture of glioma resection
# adjacent normal sample
# adrenal medulla
# adrenal neuroblastoma tumors
# adult brain - AId-AIv-AIp
# adult colon
# adult heart
# adult hindbrain
# adult intestinal stem cells; proximal 2/3 of intestine
# adult liver
# adult midbrain
# adult mouse ILC progenitors
# adult mouse ILC progenitors (femur)
# adult mouse ILC progenitors from femur
# adult mouse ILC progenitors harvested from femur
# adult mouse bone marrow
# adult mouse brain cortex and subventricular zone
# adult mouse brain cortex and subventricular zone (SVZ)
# adult mouse lung
# adult ovary tissue
# adult ovary tissue, stroma
# adult spleen
# advanced spherical blastocyst
# air-liquid interface airway epithelial cultures
# airway smooth muscle cells
# allograft breast tumor
# alveolar bone
# ameloblastoma tissue
# ankle joint
# anterior meninges (leptomeninges)
# anterior pituitary gland
# anterior segment of mouse eye
# anterior visceral endoderm
# antral GINS organoids derived from human antral stomach
# aorta (proximal)
# aortas, specifically atherosclerotic lesions
# aortic and carotid arteries
# aortic wall
# apex of the adult human heart
# apheresis
# apical region of left ventricle
# ascite
# ascitic fluid, epithelial cell
# ascitic fluid, ovarian tissue
# ascitic fluid, stromal cell
# astrocyte progenitor cells
# atrioventricular node
# atrioventricular node, left cardiac atrium
# auditory pathways
# avascular meniscus
# axillary lymph nodes
# back skin IFE
# basilar membrane
# benign
# benign prostate tissue
# biliary tract
# bladder mucosa
# blastocyst (trophectoderm)
# blastocyst-like structures
# blood (RBC depleted whole blood)
# blood (from placental and decidual tissue)
# blood (lymphocytes from murine eyeball blood)
# blood (mononuclear cells)
# blood and intestinal biopsies
# blood and kidney biopsy tissue samples
# blood leukocytes
# blood outgrowth endothelial cells
# blood platelets
# blood, memory B cells
# blood, spleen, and bone marrow
# blood, spleen, bone marrow
# bone (tibiae)
# bone marrow (BMMC)
# bone marrow (CD138- sorted)
# bone marrow 14d post treatment (M25)
# bone marrow and digested bone chips
# bone marrow and thymus
# bone marrow from all bones
# bone marrow including tumor
# bone marrow including tumour
# bone marrow mononuclear cells (BMMC)
# bone marrow organoid
# bone marrow, dental tissues
# bone marrow, lymph node, peripheral blood
# bone marrow, spleen, and lymph node
# bone marrow, spleen, blood
# bone marrow, thymus
# bone marrow-derived macrophages (BMDM)
# brain (BLA - Basolateral Amygdala)
# brain (Basolateral Amygdala - BLA)
# brain (arcuate nucleus)
# brain (cerebellum and adjacent region)
# brain (cerebellum and olfactory bulb removed)
# brain (cerebellum)
# brain (cerebral cortex)
# brain (cerebral organoid)
# brain (cerebral organoids)
# brain (corpus callosum and cortex)
# brain (derived from iPSC)
# brain (from cerebral organoid)
# brain (from cerebral organoids)
# brain (frontal lobe)
# brain (lateral habenula, LHb)
# brain (lateral hypothalamic area)
# brain (left caudate putamen)
# brain (medial prefrontal cortex)
# brain (motor cortex and cingulate cortex)
# brain (orbitofrontal cortex)
# brain (peri-LC and LC)
# brain (prefrontal cortex)
# brain (prefrontal cortex, somatosensory cortex, hippocampus, striatum, thalamus)
# brain (right frontal lobe)
# brain (temporal lobe)
# brain (ventral tegmental area)
# brain (xenograft)
# brain - central amygdala
# brain - striatum
# brain and respiratory system
# brain cortex and subventricular zone
# brain hemisphere
# brain hypothalamus
# brain microvascular endothelial cells
# brain midbrain
# brain region A24
# brain section
# brain stem tumor
# brain subclones, replicate2
# brain tumor from posterior fossa
# brain's right hemisphere
# brain, V-SVZ (Ventricular-Subventricular Zone)
# brain, arcuate nucleus of the hypothalamus
# brain, arcuate nucleus of the hypothalamus (ARC)
# brain, cerebral organoid
# brain, cortical plate
# brain, germinal matrix
# brain, globus pallidus externus
# brain, gray matter
# brain, hippocampus
# brain, infratentorial
# brain, lateral habenula
# brain, lateral hypothalamic area
# brain, nucleus accumbens
# brain, prefrontal cortex
# brain, preoptic region of the hypothalamus
# brain, specifically Basolateral Amygdala (BLA)
# brain, specifically the Medial Habenula
# brain, specifically the prefrontal cortex
# brain, supratentorial
# brain, svz+caudate
# brain, temporal lobe
# brain-PVT area
# brain; PFC (Prefrontal Cortex)
# brain; PFC (prefrontal cortex)
# brain; prefrontal cortex
# brainstem
# breast (normal mammary gland)
# breast TNBC
# breast cancer cell line (TAMR)
# breast cancer cell lines (MDA-MB-361 and MDA-MB-231)
# breast cancer organoids
# breast tumour
# bronchial
# bronchial AEC (Airway Epithelial Cells)
# bronchoalveolar lavage cells
# bronchoalveolar lavage fluid (BALF)
# bronchus
# bronchus, lung
# buccal
# buffy coat
# bulk pancreatic tumor
# buttock
# caecum, colon
# caecum, mesenteric lymph nodes
# calvaria
# calvaria/skull base
# cancerous tissues (colorectal cancer)
# capsule tissue
# cardiac cells, whole heart
# cardiac fibroblasts (hiPSC-derived)
# cardiomyocytes
# cardiomyocytes (hiPSC-CM)
# cardiovascular tissue (left ventricle)
# cartilage endplate
# caudal tissues
# caudal tissues from E8.5 embryos
# caudate putamen
# ccRCC tumor
# cecal contents
# cell
# cell line (H9-derived)
# cell line (Ovsaho)
# cells (PDX-GIC-sample)
# central gray substance of midbrain
# central gray substance of midbrain (periaqueductal gray area)
# central gray substance of midbrain (periaqueductal gray neurons)
# central gray substance of midbrain (periaqueductal gray)
# cephalic vein
# cerebellar brain organoid
# cerebellar tumor tissue
# cerebellar tumors
# cerebellum, brainstem, cervical spinal cord (C1-C2)
# cerebral aneurysms and immune cells
# cerebral cortex and hippocampal tissues
# cerebral hemisphere
# cerebrum
# cervical epidermis
# cervicovaginal
# cervicovaginal fluid
# cervix uteri
# chicken trachea
# chondrocyte
# choroid plexus (fresh frozen)
# choroid plexus brain organoids
# choroid plexus endothelial cells
# circulating NK cells
# circulating tumor cells
# circulating tumor cells (CTCs)
# circulating tumor cells from melanoma patients
# clear cell renal cell carcinoma
# clivus (skull base)
# cochlear nucleus
# colon (caecum)
# colon and esophageal tumors
# colon and mesenteric lymph node
# colon and mesenteric lymph nodes
# colon tissue
# colon, bone marrow
# colon, mesenteric lymph node
# colorectal adenocarcinoma
# colorectal adenocarcinoma cell line
# colorectal adenocarcinoma cell line (Caco-2)
# colorectal cancer biopsy
# colorectal cancer tumor
# colorectal liver metastasis
# colorectal polyps
# colorectal primary tumor
# colorectal tumors (HT-29)
# combined proximal, distal, and whole lung organoid
# common bile duct, gall bladder, liver biopsies
# cornea (left eye)
# coronal brain section
# coronal suture
# corpus GINS organoids derived from human corpus stomach
# corpus and antrum gastric units
# corpus cavernosum
# corpus gastric units
# corpus striatum
# cortex (P56)
# cortex and corpus callosum
# cortex and hippocampal formation
# cortical brain tissue
# cortical cells
# corticotroph tumor
# cotyledon
# cultured ESC-derived cells
# cultured Müller glia from adult mouse retina
# cultured cell
# cultured cells on biomaterials
# cultured neurons
# cultured olfactory ensheathing cells
# cultured primary cells
# cutaneous neurofibroma
# dLGN (dorsal lateral geniculate nucleus)
# dLN (draining lymph node)
# dLN (draining lymph nodes)
# decidual tissues
# dendritic cell
# dendritic cells from duodenal lymph nodes
# dendritic lymph nodes
# dental follicle
# dental follicle tissue
# dental follicle tissue (derived organoids)
# dental pulp cells
# derived definitive endoderm
# dermal fibroblasts (skin)
# dermal fibroblasts and blood leukocyte subsets
# dermal fibroblasts, fetal blood cells
# dermis (skin)
# developing human limb and cranium
# developing human limb and cranium tissue
# developing human limb and cranium tissue, specific organ part: hip
# developing limb and cranium
# diseased tissues
# dissociated colorectal cancer tumor
# dissociated lung
# distal lung organoid
# dorsal lateral geniculate nucleus
# dorsal root ganglion neuron
# dorsal vagal complex
# draining lymph node (dLN)
# draining lymph nodes (dLN)
# duodenal gut-draining lymph nodes
# duodenal lymph node
# duodenal lymph nodes
# ears and lungs
# ectopic tissue masses
# embryo (E5.5 and E6.25)
# embryo model, 2.5 days after tissue assembly
# embryonic (whole organism)
# embryonic cortical cells at E16
# embryonic day 6.5
# embryonic disc
# embryonic forelimb segment of the distal zeugopod and autopod
# embryonic stem
# embryonic stem (ES)
# embryonic stem cell
# embryonic stem cells (hESC)
# embryonic structure
# embryonic structure (compacted morula)
# embryonic structure, 8-cell stage
# embryonic structure, compacted morula
# embryonic structure, compacted morula stage
# embryonic whole organism
# embryos (epiblast cells)
# embryos (extra-embryonic ectoderm and epiblast cells)
# embryos (extra-embryonic ectoderm removed to enrich for epiblast cells)
# empty well
# endocervical tissue
# endogenous breast tumors
# endometrial tissue
# endometriosis lesions
# endometrium biopsy
# endothelial cells plus melanoma cell line
# enriched subdural meninges
# enteric neural crest cells
# epiblast
# epiblast and amnion spheroids
# epiblast cells
# epiblast cells from early mouse embryos
# epiblast cells from embryos
# epiblast cells from mouse embryos
# epiblast stem cells, definitive endoderm
# epicardium
# epidermis and dermis
# epididymal adipose tissue (eWAT)
# epididymal initial segment
# epididymis
# epididymis cauda
# epiglottis
# epithelial tracheal, cultured
# erythrocyte matrigel plugs
# esophageal adenocarcinoma
# esophageal organoid
# esophagus (organoid)
# ethmoid mucosal tissues
# exocrine pancreas
# extra-embryonic ectoderm
# extra-embryonic ectoderm (ExE)
# extra-embryonic ectoderm and embryonic tissues
# extra-embryonic ectoderm and epiblast
# extra-embryonic ectoderm and epiblast cells
# extraembryonic ectoderm
# extraembryonic ectoderm and epiblast cells
# extraembryonic endoderm and visceral endoderm
# extraembryonic mesoderm
# eye (optic choroid)
# eye ball, corneal cells
# facial nerve
# faeces
# feces
# female brain section containing the medial hypothalamus
# female breast normal tissue
# female breast tumor tissue
# femur bone marrow
# femur growth plate
# fetal arm tissue
# fetal brain (dorsolateral region)
# fetal brain and placenta
# fetal brain, Lateral Ganglionic Eminence (LGE)
# fetal brain, Medial Frontal Cortex
# fetal brain, frontal region
# fetal brain, occipital, E77, WT, female
# fetal brain, placenta
# fetal brain, ventral frontal cortex
# fetal colon
# fetal eye, except retina
# fetal leg tissue
# fetal placenta
# fetal skin
# fetal small intestine
# fetal-gonad
# fibroblast
# fibroblasts (WI-38)
# first mandibular molar
# flank tumor (subcutaneous)
# footpad granuloma
# forebrain organoid
# foreskin fibroblasts
# formalin-fixed paraffin-embedded hepatoblastoma
# fovea retina
# fresh lung
# fresh tumor tissue from G3/G4 medulloblastoma patients
# frontal lobe
# frozen postmortem brain
# gall bladder
# gall bladder, bile duct, liver
# gastric (corpus)
# gastric cancer
# gastric corpus
# gastric intestinal metaplasia
# gastric organoids
# gastrointestinal stromal tumors
# gastrointestinal tract
# genetically matched pairs deficient or proficient in XPA
# genomic DNA
# germinal center B cells
# germinal matrix
# gingiva (palatal gingiva)
# glioblastoma center
# glioblastoma organoid
# glioblastoma tumor core
# glioblastoma tumor peripheral tissue
# glioma cells
# glioma cells from patient-derived neurospheres
# glioma neurospheres
# glioma neurospheres (TS543)
# glioma resection
# glioma surgical biopsy
# glioma surgical specimen
# glioma, leading edge
# gliomas
# globose basal cells (GBC)
# gonadal tissue
# gut lamina propria
# gut-associated lymph nodes
# hCA3 neurons from huES6 derived NPCs
# hESC aggregate
# hESC aggregates
# hESC-derived mature sympathoadrenal progenitors
# hESC-derived sympathoadrenal progenitors
# hESC-derived xEM cells
# hPS-derived cerebellar organoids
# hair follicle stem cells
# head/ear
# healthy memory unswitched B-cell
# healthy naïve B-cell
# heart apex nuclei
# heart biopsies
# heart left ventricle
# heart right ventricle
# heart tissue (atrioventricular junction)
# heart, atrioventricular node, left cardiac atrium
# heart, left ventricle, non-myocytes
# heart, muscle
# heart, specifically the right ventricle
# hematopoietic cell from IPSC
# hematopoietic progenitor cells
# hepatoblastoma sample 35
# hiPSC (induced pluripotent stem cells)
# hiPSC derived cardiac fibroblasts
# hiPSC sensory neurons
# hiPSC-BV-integrated liver organoids (BVLO)
# hiPSC-derived
# hiPSC-derived neurons
# hiPSC-derived-hCS
# hiPSC-derived-hSS
# high grade IPMN
# high grade IPMN with co-occurring PDAC
# high grade glioma
# high grade glioma tissue
# hilar lymph node
# hindbrain neuroepithelial stem cell
# hindlimb epiphyses
# hip
# hip joint
# hippocampal and cortical tissue
# hippocampal intermediate progenitors
# hippocampal intermediate progenitors (Day 2)
# hippocampal intermediate progenitors (Day 3)
# hippocampal neurons
# hippocampal slices
# hippocampus (anterior)
# hippocampus - medial y
# hippocampus brain
# human ES cell line
# human airway epithelial cells (HBEC2)
# human brain organoid
# human cerebral organoids
# human cortical organoids
# human engineered heart muscle
# human epithelial tracheal, cultured
# human foreskin fibroblasts
# human islet cells
# human islets
# human prostate basal epithelia
# human tumor tissue
# human umbilical vein endothelial cells (HUVEC)
# human umbilical vein endothelial cells (HUVECs)
# humeral head - supraspinatus tendon (enthesis)
# hypopharynx
# hypothalamic nuclei
# hypothalamic preoptic area
# hypothalamic preoptic area of the brain
# iAssembloid
# iMeLC (induced pluripotent stem cells)
# iPSC derived RPE
# iPSC derived RPE (Retinal Pigment Epithelium)
# iPSC derived kidney organoid
# iPSC derived neuron
# iPSC tri-culture (microglia, neurons, astrocytes)
# iPSC tri-cultures (microglia, neurons, astrocytes)
# iPSC-CD4sp
# iPSC-Derived Cell Lines
# iPSC-Neurons
# iPSC-airway epithelium through basal cell intermediate
# iPSC-derived airway epithelium
# iPSC-derived alveolar epithelial type 2 cells (iAT2s) in 3D
# iPSC-derived alveolar epithelial type I-like cells (iAT1s)
# iPSC-derived alveolar epithelial type II-like cells
# iPSC-derived alveolar type 2 cells (iAT2s)
# iPSC-derived cardiomyocytes and stromal cells
# iPSC-derived cells
# iPSC-derived iAT1s grown in LDCI medium in 3D
# iPSC-derived iAT2s
# iPSC-derived iAT2s grown in CKDCI medium in 3D
# iPSC-derived lung mesenchyme
# iPSC-derived neural cultures
# iPSC-derived neuronal cell lines
# iPSC-derived neurons
# iPSC-derived neuroprogenitor cell lines
# iPSC-derived organoid
# iPSC-derived progenitor
# iPSC-derived spinal motor neuron
# iPSC-derived thyroid follicular cells
# iPSC-induced microglia
# iPSC-induced neurons
# ileal tissue
# ileum-derived intestine organoid
# immune cells (B-cells)
# immune response (CVID memory unswitched B-cell)
# immune system
# immune system (CVID memory switched B-cell)
# in vitro (derived from cell lines)
# in vitro (derived from tumor, spleen, and tdLN)
# in vitro (derived from tumors, spleen, and tdLN)
# in vitro cell line
# in vitro iPSC
# in vitro, endogenous CD8+ T cells
# incisor + molar tooth
# incisor pulp
# induced GABAergic neurons
# induced pluripotent stem cell derived kidney organoids
# induced pluripotent stem cell-derived kidney organoid
# induced pluripotent stem cells (IPSC)
# induced pluripotent stem cells (iPSC), human dermal fibroblasts
# induced pluripotent stem cells (iPSC-derived cardiomyocytes)
# induced pluripotent stem cells (iPSCs) derived cardiomyocytes
# induced pluripotent stem cells and human dermal fibroblasts
# infarct zone
# inguinal WAT
# inner cell mass (embryo)
# inner cell mass (from brain organoids)
# inner cell mass, embryo
# inner tissue of filamentous conceptus
# innervated engineered human myocardium
# innervated engineered human myocardium (iEHM)
# intercotyledonary placenta
# interneuron progenitors
# intervertebral disc
# interzone
# intestinal crypts
# intestinal organoids
# intestine (jejunum)
# intestine jejunum
# intrahepatic bile duct
# intrahepatic bile duct, gall bladder, liver biopsies
# intrahepatic duct
# invasive ductal breast carcinoma
# invasive lobular breast carcinoma
# ipsilateral feet
# iris
# isolated single cells from normal human islets
# keloid
# keloid tissue
# kidney & lung
# kidney (glomerulus)
# kidney cross-section
# knee
# knee articular chondrocytes
# knee joint
# knee joint immune cells
# knee joints
# lacrimal sac
# lamina propria of colon and mesenteric lymph nodes
# lamina propria of colon, mesenteric lymph nodes
# large intestine, small intestine
# lateral habenula
# lateral habenula neurons
# lateral hypothalamus
# left breast
# left cardiac atrium
# left eye
# left eye (cornea sclera wedge)
# left eye (iris)
# left eye (lens)
# left eye (trabecular meshwork)
# left eye, ciliary body
# left eye, iris
# left hippocampus
# left ventricle region 1B
# left ventricle region 2A
# left ventricle region 2B
# left ventricle region 2B, 17 weeks, male, Wistar strain
# left ventricle region 2C
# left ventricle region 3B
# left ventricular apex
# lens
# lens epithelium
# lesional skin - dermis
# lesioned grey matter of the somatosensory cortex
# leukemia model
# leukocytes
# limb and cranium
# lineage depleted bone marrow
# liver cancer
# liver cells
# liver micrometastasis
# liver, specifically NK cells
# longissimus dorsi muscle
# low grade IPMN
# lower grade glioma tumor core
# lower grade glioma tumor peripheral tissue
# lower lobe of lung
# lumbar disc herniation
# lung (Calu3 cell line)
# lung (bronchiole)
# lung (bronchus)
# lung (distal)
# lung (left lobe)
# lung (lower left lobe and parenchyma)
# lung (trachea, bronchi, parenchyma)
# lung (tumor tissue and peripheral blood)
# lung (tumor tissue)
# lung adenocarcinoma tissue
# lung and hilar lymph node
# lung cancer cell
# lung cancer cell line (H1299)
# lung draining lymph nodes
# lung epithelial
# lung epithelial cell line
# lung epithelial cell line (Calu3)
# lung epithelial cells (Calu3)
# lung epithelium
# lung fibroblasts
# lung fibroblasts (WI-38)
# lung metastatic niche
# lung mononuclear cell
# lung parenchyma, lower left lobe
# lung resident immune cells
# lung resident immune cells (CD45+ CD45IV-negative cells)
# lung tissue (from bronchoalveolar lavage)
# lung, bronchoalveolar lavage fluid
# lung, left lobe
# lymph
# lymphocytes
# lymphocytes (isolated from murine eyeball blood)
# lymphocytes from murine eyeball blood
# mTEC cell culture
# macrophage cultures (J774 cell line)
# macula lutea (fetal retina tissue)
# male brain section containing the medial hypothalamus
# male genitalia
# mammary carcinoma models
# mammary gland basal cell
# mammary gland luminal cell
# mammary gland/breast
# mammary glands
# mammary tumor cells
# mammary tumor tissue
# mandibular molar tooth organ
# mandibular molars
# maternal blood
# maxillary molar tooth organ
# maxillary process
# medial brain - prefrontal cortex
# medial prefrontal cortex (mPFC)
# medial prefrontal cortex and cerebellum
# mediastinal LN
# medulla (kidney)
# meibomian gland
# melanoma arising in congenital melanocytic nevi (CMN)
# melanoma model (HCmel12)
# melanoma primary tumor
# melanoma single cell suspension
# memory B-cell
# memory b-cell
# memory switched B-cell
# memory unswitched B-cell
# memory unswitched b-cell
# menstrual effluent
# menstrual effluent tissue
# mesenchymal stem cell
# mesenchymal stem cell from human bone marrow
# mesendoderm lineage cell types
# mesenteric artery - large (> 300 um)
# mesenteric artery - large (>300 um)
# mesenteric artery - small (< 150 um)
# mesenteric artery - small (<150 um)
# mesenteric lymph node and colon
# mesenteric lymph node and human colon
# mesenteric lymph node, colon (lamina propria)
# mesenteric lymph node, colon lamina propria
# mesenteric lymph node, lamina propria of colon
# mesenteric white adipose tissue
# metastatic regions of sentinel lymph nodes
# microcirculation in newborns
# midbrain reticular nucleus
# mini gland basal cell
# mini gland luminal cell
# mobilized peripheral blood (mPB)
# mouse E13.5
# mouse cortex
# mouse embryonic fibroblasts
# mouse embryonic fibroblasts (MEFs)
# mouse intestinal organoids
# mouse melanoma
# mouse tracheal epithelial cells cultured at air-liquid interface
# mouse tumor-derived cells
# murine hearts
# myeloid cells
# myometrial arteries
# myometrial strips
# myometrial strips (utero-placental tissue)
# nasal swab
# nasal tissue
# nasal tissue and peripheral blood
# naïve B-cell
# naïve b-cell
# neural organoids derived from human iPS cells
# neural progenitor cell
# neural progenitor cell monolayer
# neural stem cell
# neural stem cells (in vitro)
# neural stem cells derived from iPSCs
# neuroblastoma cell line
# neuroblastoma cell line (SKNAS)
# neuroblastoma cell line (SKNFI)
# neuroblastoma cell line (SKNSH)
# neuroblastoma cell lines
# neuroblastoma patient-derived xenografts
# neuron derived from SB2-iPSC
# neurons derived from human iPSCs
# neurosphere culture
# neurospheres derived from patient-derived glioma
# nodose ganglia
# non-lactating breast tissue
# non-small cell lung carcinoma tissue, peripheral blood
# non-tumor DNA sample from a human female participant
# normal
# normal ascending colon
# normal back skin
# normal bladder mucosa
# normal breast
# normal esophagus
# normal human islets
# normal mammary gland
# normal mammary gland, breast
# normal pancreata
# not_collected
# notochordal-like cells
# nuclei from specimen CBTM-364B_AX
# nuclei from specimen CBTM-417C_SP
# nuclei from the left atrium
# nucleus accumbens
# nucleus accumbens shell
# ocular outflow tissues
# oesophagus
# oesophagus cells
# oesophagus epithelium
# oesophagus mucosa
# oesophagus mucosa including epithelium
# oesophagus, spinal cord
# olfactory bulb & late RMS
# olfactory bulb - piriform cortex
# olfactory bulb-derived olfactory ensheathing cells
# olfactory bulbs
# olfactory region of the brain
# omental adipose tissue
# omental metastasis
# omental metastasis from HGSOC post NACT
# omental metastasis from HGSOC pre NACT
# omental tumor
# oocyte
# oocyte (MII oocyte)
# oocytes
# optic nerve head
# oral squamous cell carcinoma tumor biopsy
# oral tissue
# orbitofrontal cortex (Brodmann area 11)
# organoids derived from hiPSC
# oropharynx
# osteoblasts
# osteoblasts (MC3T3-E1 cell line)
# osteosarcoma
# osteosarcoma cells
# outer ear
# ovarian tissue
# ovary (oocyte)
# ovary stroma
# ovary, stroma
# pancreas body
# pancreas body/tail
# pancreas head
# pancreas neck
# pancreas tail
# pancreas, small ducts
# pancreatic adenocarcinoma
# pancreatic cells
# pancreatic ductal adenocarcinoma, dissociated orthotopic tumor
# pancreatic neuroendocrine tumor
# papillary thyroid carcinoma
# parasympathetic neurons derived from human pluripotent stem cells
# paraventricular hypothalamic nucleus
# patient-derived xenograft (PDX) from breast cancer
# pediatric brain tumors and other solid and hematologic malignancies
# pelvic pouch
# peri-implant soft tissue
# periaqueductal gray (PAG) neurons
# periaqueductal gray neurons
# periodontal ligament
# peripapillary sclera
# peripheral blood (sorted activated B cells)
# peripheral blood / leukocytes
# peripheral blood monocyte
# peripheral blood, connective tissue
# peripheral blood, leukocytes
# peripheral nervous system tumors
# peripheral organs
# peripheral organs (heart, lung, liver, spleen, blood, bone marrow)
# peripheral whole blood
# peritoneal cavity fluid
# peritoneal surfaces, omentum, bowel loops
# peritoneum, ectopic adjacent location
# perivascular adipose
# pia mater
# pig
# pig epididymis corpus
# pineal gland
# pituitary prolactinoma
# placental tissue
# plantar foot ulcer
# plasmablasts
# pluripotent stem cell
# pons-medulla
# pons-medulla (brainstem)
# pontine nucleus
# pooled dorsal striatum
# poorly metastatic melanoma
# post-anal tail bud
# posterior dorsal pallium
# postmortem cortex
# postnatal neocortex
# pre-frontal cortex
# pre-implantation embryos
# prenatal lung
# preoptic area of hypothalamus
# preoptic region of the hypothalamus
# primary PDAC
# primary PDAC (Pancreatic Ductal Adenocarcinoma)
# primary T cells
# primary T cells from blood
# primary colorectal cancer biopsy
# primary culture from colon cancer tumor
# primary hepatocytes
# primary human T lymphocytes
# primary monocytes
# primary neural stem cells
# primary tibia
# primary visual cortex
# primary visual cortex V1 neurons
# prostate basal epithelia
# prostate epithelia
# prostate fibromuscular stroma
# prostate luminal epithelia
# prostate organoids
# prostate peripheral zone
# prostate transition zone
# proximal lung organoid
# psoriasis lesional skin
# psoriasis lesional skin (epidermis and dermis)
# psoriasis lesional skin after treatment
# psoriasis lesional skin after treatment (epidermis and dermis)
# pulmonary
# pulmonary arteries
# pulmonary tissue
# pulmonary veins
# pyloric antrum
# quad
# quadriceps muscles
# rat choroid
# rectal wall
# regionalized midbrain organoid
# related to human induced pluripotent stem cells (hiPSCs)
# reprogrammed MEFs
# reprogrammed MEFs (Mouse Embryonic Fibroblasts)
# reprogrammed cells derived from Cry1 KO MEFs
# reprogrammed cells derived from WT MEFs
# reprogrammed cells from wild-type MEFs
# reprogramming intermediates from mouse embryonic fibroblasts
# resected glioblastoma
# respiratory epithelium
# rete ovarii
# retina, cerebral cortices, striatum, midbrain
# retina, choroid
# retinal ganglion cell
# retinal pigment epithelium/choroid
# retinal tissue
# retinoblastoma
# right breast
# right cardiac atrium
# right coronary artery
# right eye
# right eye (lens)
# right eye (macula)
# right eye, macula
# right ventricle region 2G
# right-sided colon
# rumen
# saliva, blood, buffy coat
# salivary gland epithelium
# sarcoma tissues
# sclera
# scraped urothelium
# secondary lymphoid tissues
# secondary palate
# semitendinosus muscle
# septum apex
# septum base
# sgFlcn-transduced OT-1 cells from siIEL post-LM-OVA infection
# shoulder
# sigmoid colon, caecum, transverse colon, lymph nodes from intestine mesentery
# sigmoid colon, lamina propria
# sigmoid colon, lamina propria of colon, mesenteric lymph nodes
# single dendritic cell
# single dorsal root ganglion neuron
# sinoatrial node
# skeletal muscle (quadriceps)
# skeletal muscle stem
# skin (dermal fibroblasts)
# skin (epidermis and dermis)
# skin (fibroblast of dermis)
# skin (non-lesional biopsy)
# skin adipose tissue
# skin cells from lower back
# skin draining lymph nodes
# skin draining lymph nodes (inguinal, axillary, and brachial)
# skin lesions and non-sun exposed skin
# skin neoplasms (melanoma)
# skin or lymph node (LN)
# skin tissue
# skin, dermal fibroblast
# skin, fibroblast of dermis
# skin, hair follicle epithelial cell
# skin, hair follicle epithelial cell, upper outer root sheath
# skin, hair follicle epithelial cell, upper-middle outer root sheath
# skin, hair follicle epithelial region: upper outer root sheath
# skin, lymph nodes, spleen
# skin, specifically fibroblast of dermis
# skin, upper outer root sheath of hair follicle epithelial region
# skull base
# small RNA from Calu3 cells
# small intestinal tumor
# small intestine (macroscopic ApcMin/+ adenomas)
# small intestine-derived lamina propria CD45+ cells
# snap frozen cortical tissue
# snap frozen, FFPE tissue samples
# solid tumor
# solitary nucleus of the brainstem
# somatosensory cortex (S1 cortex)
# somatosensory cortex and motor cortex
# sorted blood
# spherical blastocyst
# spinal canal
# spinal cord (ependymal cells)
# spinal cord ependymal cells
# spinal cord, ependymal cell
# spinal cord, lumbar, P0
# spine
# spleen (germinal center B cells)
# spleen / germinal center B cells
# spleen and bone marrow
# spleen and liver
# spleen cells (72h)
# spleen of humanized mice
# spleen, blood
# spleen, bone marrow
# spleen, bone marrow, blood
# spleen, colon, and skin
# spleen, lymph nodes, bone marrow, peripheral blood
# stem cell derived
# stem cell derived astrocytes
# stem cell-derived astrocytes
# stomach (corpus tissue)
# stomach (corpus)
# stomach (desert type)
# stomach (epithelial cells of stomach)
# stomach (epithelial cells)
# stomach (gastric corpus)
# stomach (gastric epithelial cells)
# stomach (gastric parietal cells)
# stomach (inflamed type)
# stomach (inflamed type, T3)
# stomach corpus
# stomach corpus tissue
# stomach epithelial cell
# stomach epithelial cells
# stomach infiltrating immune cells
# stomach, epithelial cell of stomach
# stomach, specifically corpus tissue
# stool
# stria vascularis
# striatal cells
# striatal tissue
# striatum & ventricular-subventricular zone
# striatum and ventricular-subventricular zone
# striatum, retina, cerebral cortices, midbrain
# stroma
# stromal vascular cells from epididymal fat
# sub-ventricular zone
# subchondral bone
# subcortical white matter and motor cortex
# subcutaneous inoculated B16 tumor
# subcutaneous metastatic sample
# subcutaneous transplantation
# subcutaneous tumor tissues of MC38
# subscapular brown adipose tissue
# subsegmental bronchus
# superior cervical ganglia
# sympathoadrenal
# synovial capsule
# synovial fibroblasts
# tHIO (transplanted human intestinal organoids)
# tail skin IFE
# tail skin IFE (Interfollicular epidermis)
# tarsal plates
# teeth
# teeth, specifically periodontal ligament stem cells
# temporal lobe
# tendon adhesion tissue
# tendon enthesis
# testicular tissue
# testicular tissues
# thalamic organoids
# thymus (sorted thymocytes)
# thyroid follicular cells
# tibia tumor
# tibialis anterior (TA)
# tooth organoid
# total clear cell renal cell carcinoma homogenate
# tracheal aspirates
# tracheal epithelium
# transcriptomic single cell
# transplanted into rat
# transverse colon, lamina propria
# trigeminal ganglia (TG) and dorsal root ganglia (DRG)
# trigeminal neurons
# trophectoderm
# trophoblast
# tubular conceptus
# tumor (AT3-OVA)
# tumor (EMT6)
# tumor (MC38 model)
# tumor (subcutaneous flank, orthotopic primary, experimental metastases)
# tumor B16F10
# tumor cell and BMDM spheroids
# tumor cell spheroids
# tumor cells (MC38-GFP)
# tumor dissociated cells
# tumor from bone marrow chimeric mice
# tumor infiltrating CD45 cells
# tumor infiltrating CD8 T cells
# tumor infiltrating CD8 cells
# tumor sample (esophagus)
# tumor sub-ventricular zone
# tumor sub-ventricular zone (SVZ) sample of glioblastoma patient 20
# tumor tissue (dLN)
# tumor tissue from a neuroblastoma model
# tumor tissue from small intestinal tumors
# tumor tissue from small intestinal tumors of ApcMin mice
# tumor tissues (isolated from mice)
# tumor, CD45+
# tumor, CD45+ tumor-infiltrating lymphocytes
# tumor, FFPE sample
# tumor, posterior fossa
# tumor, spleen, and tumor-draining lymph nodes (tdLN)
# tumor, spleen, tdLN
# tumor, spleen, tumor-draining lymph node
# tumor, spleen, tumor-draining lymph node (tdLN)
# tumor, spleen, tumor-draining lymph nodes
# tumor, spleen, tumor-draining lymph nodes (tdLN)
# tumor-adjacent mammary tissue
# tumor-adjacent normal skin
# tumor-bearing liver
# tumor-bearing pancreata
# tumor-infiltrating lymphocytes from head and neck cancer
# tumour free scar tissue
# tumour tissue
# tumours
# tumours (B16-GFP)
# turbinate and adjacent mucosal tissues
# umbilical cord blood mononuclear cells
# upper lobe of lung
# upper small intestine
# urethra
# urine and serum
# urine mesenchymal
# uterine smooth muscle tumors
# uterine tissue
# uterosacral ligament
# utricle and crista ampullaris
# utricles
# uveal melanoma
# vagina
# vascular smooth muscle cells
# vascular smooth muscle cells from lesion-bearing aorta
# ventral ganglionic eminence
# ventral ganglionic eminence from brain slices
# ventral midbrain nuclei
# ventricular cardiac tissue
# ventricular heart tissue
# ventricular-subventricular zone
# ventricular-subventricular zone, striatum, olfactory bulb
# ventroposterior hypothalamus
# vessel organoid
# viable human prostate PDPN negative stroma
# viable human prostate PDPN positive stroma
# viable human prostate luminal epithelia
# viable human prostate transition zone
# viable mouse prostate
# visceral endoderm
# visceral endoderm (VE) cells
# visceral endoderm (VE) cells from E5.5 and E6.25 wild type mouse embryos
# visceral endoderm (VE) cells from embryos at embryonic day 6.25
# visceral endoderm (VE) enriched cell populations
# visceral endoderm cells from E5.5 and E6.25 mouse embryos
# visceral endoderm cells from embryos at embryonic day 6.25
# visceral endoderm enriched cell populations
# visceral fat
# visual area in the mouse brain (VISl)
# vitreous
# weight-bearing heel
# whole brain (tumor-bearing)
# whole brain CD11b+ CD45- cells
# whole brain and dura mater
# whole cell
# whole embryos at embryonic day 6.5
# whole endometrial tissue
# whole hippocampus
# whole hippocampus, tissue from adult mice brain
# whole hypothalamus
# whole inner ear containing otic capsule
# whole lacrimal gland
# whole neocortex
# whole organism (embryo)
# whole organism (embryo), embryonic day 5.5
# whole organism (embryo), enriched for visceral endoderm (VE) cells
# whole organism (embryo), enrichment for visceral endoderm (VE) cells
# whole organism (embryonic day 11)
# whole organism (embryonic day 5.5)
# whole organism (embryonic day 6.25)
# whole organism (embryonic day 6.5)
# whole organism (embryonic development)
# whole organism (embryonic stage)
# whole organism (embryonic tissue)
# whole organism (embryonic)
# whole organism (human embryos)
# whole organism at embryonic day 6.5
# whole organism at embryonic stage E6.5
# whole organism, embryo
# whole organism, embryo (E5.5 and E6.25)
# whole organism, embryonic day 5.5
# whole organism, embryonic day 6.25
# whole organism, embryonic day 6.5
# whole organism, embryonic day 6.5, epiblast
# whole organism, embryonic day 9
# whole pancreas
# whole tumour
# whole tumour (B16-IFNA4 Tumours)
# whole tumour, specifically B16-IFNA4 tumours
# whole tumour, specifically B16-IFNA9 tumours
# whole-tumor organoid-derived primary colorectal cancer
# whole-tumour primary CRC
# whole-tumour primary colorectal cancer
# whole-tumour primary liver metastasis
# whole-tumour primary peritoneal carcinomatosis
# wholeME (menstrual effluent)
# wildtype maxillary process
# zona incerta

# %% [markdown]
# ### Updated categories

# %%
pd.set_option('display.max_rows', 10)
df_updated_cats = pd.read_csv("./data/2025-03-11_tissue_categories.csv")
df_updated_cats
# Out:
#                                                  tissue      category
# 0                                      2 layer spheroid         other
# 1                 3 layer spheroid channel 1,epithelial         other
# 2                            3 layer spheroid channel 2         other
# 3                                 3D healthy skin model  skin of body
# 4                                            A549 cells          lung
# ...                                                 ...           ...
# 5613  whole animal, developmental stages: 26, 28, 30...         other
# 5614                                  whole skin tissue  skin of body
# 5615                                               wing         other
# 5616                                  zebrafish embryos        embryo
# 5617                           brain's right hemisphere         brain
#
# [5618 rows x 2 columns]

# %%
# reload metadata
tbl = Table("srx_metadata")
stmt = Query \
    .from_(tbl) \
    .select(tbl.organism, tbl.tissue) \
    .distinct()

with db_connect() as conn:
    df_srx_meta = pd.read_sql(str(stmt), conn)
df_srx_meta
# Out:
#            organism                                  tissue
# 0              None                                    None
# 1      Mus musculus        caudal tissues from E8.5 embryos
# 2       Danio rerio                     hepatized intestine
# 3      Homo sapiens            iPSC-derived neural cultures
# 4        Bos taurus                             macrophages
# ...             ...                                     ...
# 6386   Homo sapiens              PBMC Healthy control (T50)
# 6387   Homo sapiens                         parahippocampus
# 6388   Mus musculus                                 urethra
# 6389  Gallus gallus  Basilar papillae (auditory epithelium)
# 6390   Homo sapiens            colon, mesenteric lymph node
#
# [6391 rows x 2 columns]

# %%
# merge on tissue
df_srx_meta = df_srx_meta.merge(df_updated_cats, on="tissue", how="left")
df_srx_meta
# Out:
#            organism                                  tissue        category
# 0              None                                    None           other
# 1              None                                    None           other
# 2              None                                    None           other
# 3      Mus musculus        caudal tissues from E8.5 embryos          embryo
# 4       Danio rerio                     hepatized intestine       intestine
# ...             ...                                     ...             ...
# 6388   Homo sapiens              PBMC Healthy control (T50)           blood
# 6389   Homo sapiens                         parahippocampus           brain
# 6390   Mus musculus                                 urethra           other
# 6391  Gallus gallus  Basilar papillae (auditory epithelium)  sensory system
# 6392   Homo sapiens            colon, mesenteric lymph node           colon
#
# [6393 rows x 3 columns]

# %%
# filter to NaN
pd.set_option('display.max_rows', None)
df_srx_meta[df_srx_meta["category"].isnull()]["organism"].value_counts()
# Out:
# organism
# other           78
# metagenome      28
# Homo sapiens     1
# Name: count, dtype: int64

# %%
# tissues to categorize
x = sorted(df_srx_meta[(df_srx_meta["category"].isnull()) & (~df_srx_meta["organism"].isin(["other", "metagenome"]))]["tissue"].unique())
print('\n'.join(x))
# Out:
# N/A

# %% [markdown]
# # sessionInfo

# %%
# !mamba list
# Out:
# # packages in environment at /home/nickyoungblut/miniforge3/envs/SRAgent:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# aiohappyeyeballs          2.4.3                    pypi_0    pypi
# aiohttp                   3.10.10                  pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.6.2.post1              pypi_0    pypi
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# attrs                     24.2.0                   pypi_0    pypi
# beautifulsoup4            4.12.3                   pypi_0    pypi
# biopython                 1.84                     pypi_0    pypi
# build                     1.2.2.post1              pypi_0    pypi
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.34.3               heb4867d_0    conda-forge
# ca-certificates           2024.8.30            hbcca054_0    conda-forge
# cachetools                5.5.0                    pypi_0    pypi
# certifi                   2024.8.30                pypi_0    pypi
# cffi                      1.17.1                   pypi_0    pypi
# charset-normalizer        3.4.0                    pypi_0    pypi
# comm                      0.2.2              pyhd8ed1ab_0    conda-forge
# cryptography              44.0.1                   pypi_0    pypi
# curl                      8.10.1               hbbe4b11_0    conda-forge
# dataclasses-json          0.6.7                    pypi_0    pypi
# db-dtypes                 1.3.1                    pypi_0    pypi
# debugpy                   1.8.7           py312h2ec8cdc_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# distro                    1.9.0                    pypi_0    pypi
# docutils                  0.21.2                   pypi_0    pypi
# dynaconf                  3.2.6                    pypi_0    pypi
# exceptiongroup            1.2.2              pyhd8ed1ab_0    conda-forge
# executing                 2.1.0              pyhd8ed1ab_0    conda-forge
# frozenlist                1.5.0                    pypi_0    pypi
# google-api-core           2.23.0                   pypi_0    pypi
# google-auth               2.36.0                   pypi_0    pypi
# google-auth-oauthlib      1.2.1                    pypi_0    pypi
# google-cloud              0.34.0                   pypi_0    pypi
# google-cloud-bigquery     3.27.0                   pypi_0    pypi
# google-cloud-bigquery-storage 2.27.0                   pypi_0    pypi
# google-cloud-core         2.4.1                    pypi_0    pypi
# google-cloud-secret-manager 2.22.0                   pypi_0    pypi
# google-cloud-storage      2.19.0                   pypi_0    pypi
# google-crc32c             1.6.0                    pypi_0    pypi
# google-resumable-media    2.7.2                    pypi_0    pypi
# googleapis-common-protos  1.66.0                   pypi_0    pypi
# greenlet                  3.1.1                    pypi_0    pypi
# grpc-google-iam-v1        0.13.1                   pypi_0    pypi
# grpcio                    1.68.1                   pypi_0    pypi
# grpcio-status             1.68.1                   pypi_0    pypi
# gspread                   6.1.4                    pypi_0    pypi
# gspread-dataframe         4.0.0                    pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# httpcore                  1.0.6                    pypi_0    pypi
# httpx                     0.27.2                   pypi_0    pypi
# httpx-sse                 0.4.0                    pypi_0    pypi
# icu                       70.1                 h27087fc_0    conda-forge
# id                        1.5.0                    pypi_0    pypi
# idna                      3.10                     pypi_0    pypi
# importlib-metadata        8.5.0              pyha770c72_0    conda-forge
# ipykernel                 6.29.5             pyh3099207_0    conda-forge
# ipython                   8.29.0             pyh707e725_0    conda-forge
# jaraco-classes            3.4.0                    pypi_0    pypi
# jaraco-context            6.0.1                    pypi_0    pypi
# jaraco-functools          4.1.0                    pypi_0    pypi
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# jeepney                   0.8.0                    pypi_0    pypi
# jiter                     0.7.0                    pypi_0    pypi
# jsonpatch                 1.33                     pypi_0    pypi
# jsonpointer               3.0.0                    pypi_0    pypi
# jupyter_client            8.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.2              pyh31011fe_1    conda-forge
# keyring                   25.6.0                   pypi_0    pypi
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# krb5                      1.21.3               h659f571_0    conda-forge
# langchain                 0.3.7                    pypi_0    pypi
# langchain-community       0.3.5                    pypi_0    pypi
# langchain-core            0.3.15                   pypi_0    pypi
# langchain-openai          0.2.6                    pypi_0    pypi
# langchain-text-splitters  0.3.2                    pypi_0    pypi
# langchainhub              0.1.21                   pypi_0    pypi
# langgraph                 0.2.45                   pypi_0    pypi
# langgraph-checkpoint      2.0.2                    pypi_0    pypi
# langgraph-sdk             0.1.35                   pypi_0    pypi
# langsmith                 0.1.140                  pypi_0    pypi
# ld_impl_linux-64          2.43                 h712a8e2_2    conda-forge
# libcurl                   8.10.1               hbbe4b11_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 hd590300_2    conda-forge
# libexpat                  2.6.4                h5888daf_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc                    14.2.0               h77fa898_1    conda-forge
# libgcc-ng                 14.2.0               h69a702a_1    conda-forge
# libgomp                   14.2.0               h77fa898_1    conda-forge
# libiconv                  1.17                 hd590300_2    conda-forge
# libnghttp2                1.64.0               h161d5f1_0    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libsodium                 1.0.20               h4ab18f5_0    conda-forge
# libsqlite                 3.47.0               hadc24fc_1    conda-forge
# libssh2                   1.11.0               h0841786_0    conda-forge
# libstdcxx                 14.2.0               hc0a3c3a_1    conda-forge
# libstdcxx-ng              14.2.0               h4852527_1    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxml2                   2.9.14               h22db469_4    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# markdown-it-py            3.0.0                    pypi_0    pypi
# marshmallow               3.23.1                   pypi_0    pypi
# matplotlib-inline         0.1.7              pyhd8ed1ab_0    conda-forge
# mdurl                     0.1.2                    pypi_0    pypi
# more-itertools            10.6.0                   pypi_0    pypi
# msgpack                   1.1.0                    pypi_0    pypi
# multidict                 6.1.0                    pypi_0    pypi
# mypy-extensions           1.0.0                    pypi_0    pypi
# ncbi-vdb                  3.1.1                h4ac6f70_2    bioconda
# ncurses                   6.5                  he02047a_1    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# nh3                       0.2.21                   pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# openai                    1.57.2                   pypi_0    pypi
# openssl                   3.3.2                hb9d3cd8_0    conda-forge
# orjson                    3.10.11                  pypi_0    pypi
# ossuuid                   1.6.2             hf484d3e_1000    conda-forge
# packaging                 24.1               pyhd8ed1ab_0    conda-forge
# pandas                    2.2.3                    pypi_0    pypi
# parso                     0.8.4              pyhd8ed1ab_0    conda-forge
# perl                      5.26.2            h36c2ea0_1008    conda-forge
# perl-app-cpanminus        1.7044                  pl526_1    bioconda
# perl-business-isbn        3.004                   pl526_0    bioconda
# perl-business-isbn-data   20140910.003            pl526_0    bioconda
# perl-carp                 1.38                    pl526_3    bioconda
# perl-constant             1.33                    pl526_1    bioconda
# perl-data-dumper          2.173                   pl526_0    bioconda
# perl-encode               2.88                    pl526_1    bioconda
# perl-exporter             5.72                    pl526_1    bioconda
# perl-extutils-makemaker   7.36                    pl526_1    bioconda
# perl-file-path            2.16                    pl526_0    bioconda
# perl-file-temp            0.2304                  pl526_2    bioconda
# perl-mime-base64          3.15                    pl526_1    bioconda
# perl-parent               0.236                   pl526_1    bioconda
# perl-uri                  1.76                    pl526_0    bioconda
# perl-xml-libxml           2.0132          pl526h7ec2d77_1    bioconda
# perl-xml-namespacesupport 1.12                    pl526_0    bioconda
# perl-xml-sax              1.02                    pl526_0    bioconda
# perl-xml-sax-base         1.09                    pl526_0    bioconda
# perl-xsloader             0.24                    pl526_0    bioconda
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pip                       24.3.1             pyh8b19718_0    conda-forge
# pkginfo                   1.12.1.2                 pypi_0    pypi
# platformdirs              4.3.6              pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.48             pyha770c72_0    conda-forge
# propcache                 0.2.0                    pypi_0    pypi
# proto-plus                1.25.0                   pypi_0    pypi
# protobuf                  5.29.1                   pypi_0    pypi
# psutil                    6.1.0           py312h66e93f0_0    conda-forge
# psycopg2-binary           2.9.10                   pypi_0    pypi
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_0    conda-forge
# pyarrow                   18.1.0                   pypi_0    pypi
# pyasn1                    0.6.1                    pypi_0    pypi
# pyasn1-modules            0.4.1                    pypi_0    pypi
# pycparser                 2.22                     pypi_0    pypi
# pydantic                  2.9.2                    pypi_0    pypi
# pydantic-core             2.23.4                   pypi_0    pypi
# pydantic-settings         2.6.1                    pypi_0    pypi
# pyee                      12.0.0                   pypi_0    pypi
# pygments                  2.18.0             pyhd8ed1ab_0    conda-forge
# pypika                    0.48.9                   pypi_0    pypi
# pyproject-hooks           1.2.0                    pypi_0    pypi
# python                    3.12.7          hc5c86c4_0_cpython    conda-forge
# python-dateutil           2.9.0.post0              pypi_0    pypi
# python-dotenv             1.0.1                    pypi_0    pypi
# python_abi                3.12                    5_cp312    conda-forge
# pytz                      2024.2                   pypi_0    pypi
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     26.2.0          py312hbf22597_3    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# readme-renderer           44.0                     pypi_0    pypi
# regex                     2024.11.6                pypi_0    pypi
# requests                  2.32.3                   pypi_0    pypi
# requests-oauthlib         2.0.0                    pypi_0    pypi
# requests-toolbelt         1.0.0                    pypi_0    pypi
# rfc3986                   2.0.0                    pypi_0    pypi
# rich                      13.9.4                   pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# secretstorage             3.3.3                    pypi_0    pypi
# setuptools                75.3.0             pyhd8ed1ab_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sniffio                   1.3.1                    pypi_0    pypi
# soupsieve                 2.6                      pypi_0    pypi
# sqlalchemy                2.0.35                   pypi_0    pypi
# sra-tools                 3.1.1                h4304569_2    bioconda
# sragent                   0.1.0                    pypi_0    pypi
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# tabulate                  0.9.0                    pypi_0    pypi
# tenacity                  9.0.0                    pypi_0    pypi
# tiktoken                  0.8.0                    pypi_0    pypi
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tornado                   6.4.1           py312h66e93f0_1    conda-forge
# tqdm                      4.67.0                   pypi_0    pypi
# traitlets                 5.14.3             pyhd8ed1ab_0    conda-forge
# twine                     6.0.1                    pypi_0    pypi
# types-requests            2.32.0.20241016          pypi_0    pypi
# typing-inspect            0.9.0                    pypi_0    pypi
# typing_extensions         4.12.2             pyha770c72_0    conda-forge
# tzdata                    2024.2                   pypi_0    pypi
# urllib3                   2.2.3                    pypi_0    pypi
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# wheel                     0.44.0             pyhd8ed1ab_0    conda-forge
# xmltodict                 0.14.2                   pypi_0    pypi
# xz                        5.2.6                h166bdaf_0    conda-forge
# yarl                      1.17.1                   pypi_0    pypi
# zeromq                    4.3.5                h3b0a872_6    conda-forge
# zipp                      3.20.2             pyhd8ed1ab_0    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge

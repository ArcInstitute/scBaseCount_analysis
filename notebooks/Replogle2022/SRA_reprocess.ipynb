# %% [markdown]
# # Goals
#
# * Reprocess Replogle et al., 2022 dataset
#   * Just cell count data
# * Reprocess will make the data consistent with the scBaseCount dataset
# * Reprocessing from SRA read data
# * Bioprojects
#   * `PRJNA83156`
#   * `PRJNA1100571`

# %%
import os
from glob import glob
import pandas as pd

# %%
# get base directory of repo
repo_base_dir = !git rev-parse --show-toplevel
repo_base_dir = repo_base_dir[0]

# %% [markdown]
# # `PRJNA83156`

# %% [markdown]
# ## SRA metadata

# %% [markdown]
# ### Get metadata

# %%
# get srx info for the bioproject
# !{repo_base_dir}/scripts/bioproject2srx.py PRJNA83156 > {repo_base_dir}/data/Replogle2022/PRJNA83156_SRX-SRR.csv

# %%
meta_file = os.path.join(repo_base_dir, "data", "Replogle2022", "PRJNA83156_SRX-SRR.csv")
meta_file
# Out:
# '/home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA83156_SRX-SRR.csv'

# %% [markdown]
# ### Summarize

# %%
meta = pd.read_csv(meta_file)
meta
# Out:
#                                      exp_name          srx          srr
# 0     KD6_seq1_essential_mRNA_lane_1_S49_L004  SRX15390082  SRR19330645
# 1     KD6_seq1_essential_mRNA_lane_1_S49_L001  SRX15390083  SRR19330644
# 2     KD6_seq1_essential_sgRNA_lane_1_S1_L002  SRX15390084  SRR19330643
# 3     KD6_seq1_essential_mRNA_lane_9_S33_L004  SRX15390085  SRR19330642
# 4     KD6_seq1_essential_mRNA_lane_9_S33_L003  SRX15390086  SRR19330641
# ...                                       ...          ...          ...
# 7878                          KD6_6_essential  SRX15703621  SRR19653804
# 7879                          KD6_7_essential  SRX15703622  SRR19653803
# 7880                          KD6_8_essential  SRX15703623  SRR19653802
# 7881                          KD6_9_essential  SRX15703624  SRR19653801
# 7882                         KD6_10_essential  SRX15703625  SRR19653800
#
# [7883 rows x 3 columns]

# %%
# repeat names?
df = meta['exp_name'].value_counts().reset_index()
df[df['count'] > 1]
# Out:
# Empty DataFrame
# Columns: [exp_name, count]
# Index: []

# %%
# checking RPE1
df = meta[meta['exp_name'].str.contains("RPE1")].sort_values("exp_name")
df
# Out:
#                                exp_name          srx          srr
# 5666   RD7_seq1_RPE1_mRNA_10_1_S10_L001  SRX15542269  SRR19489445
# 5141   RD7_seq1_RPE1_mRNA_10_1_S10_L002  SRX15541744  SRR19488970
# 5670   RD7_seq1_RPE1_mRNA_10_1_S10_L003  SRX15542273  SRR19489441
# 5661   RD7_seq1_RPE1_mRNA_10_1_S10_L004  SRX15542264  SRR19489450
# 5143   RD7_seq1_RPE1_mRNA_10_2_S66_L001  SRX15541746  SRR19488968
# ...                                 ...          ...          ...
# 5657  RD7_seq1_RPE1_sgRNA_9_3_S149_L004  SRX15542260  SRR19489454
# 5650  RD7_seq1_RPE1_sgRNA_9_4_S205_L001  SRX15542253  SRR19489461
# 5117  RD7_seq1_RPE1_sgRNA_9_4_S205_L002  SRX15541720  SRR19488994
# 5648  RD7_seq1_RPE1_sgRNA_9_4_S205_L003  SRX15542251  SRR19489463
# 5659  RD7_seq1_RPE1_sgRNA_9_4_S205_L004  SRX15542262  SRR19489452
#
# [1792 rows x 3 columns]

# %%
# format the mRNA samples
meta_f = meta.copy()
meta_f[['exp_name', 'lane', 'X']] = meta_f['exp_name'].str.extract(r"(.+)_((L[0-9]+))$")
meta_f = meta_f[meta_f['lane'].notna()]
meta_f = meta_f[meta_f['exp_name'].str.contains('mRNA')].reset_index(drop=True)
meta_f = meta_f.drop(columns=['X']).sort_values(['exp_name', 'srx'])
meta_f
# Out:
#                                  exp_name          srx          srr  lane
# 10    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390098  SRR19330629  L004
# 11    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390099  SRR19330628  L001
# 12    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390100  SRR19330627  L003
# 13    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390101  SRR19330626  L002
# 6     KD6_seq1_essential_mRNA_lane_10_S58  SRX15390093  SRR19330634  L001
# ...                                   ...          ...          ...   ...
# 2912          RD7_seq1_RPE1_mRNA_9_3_S121  SRX15542257  SRR19489457  L002
# 2646          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541700  SRR19489014  L002
# 2647          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541701  SRR19489013  L003
# 2656          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541711  SRR19489003  L001
# 2662          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541717  SRR19488997  L004
#
# [3576 rows x 4 columns]

# %%
# number of SRR per SRX
meta_f['exp_name'].value_counts().reset_index().describe()
# Out:
#        count
# count  894.0
# mean     4.0
# std      0.0
# min      4.0
# 25%      4.0
# 50%      4.0
# 75%      4.0
# max      4.0

# %%
# use first srx for each exp_name
meta_f['srx'] = meta_f.groupby('exp_name')['srx'].transform('first')
meta_f
# Out:
#                                  exp_name          srx          srr  lane
# 10    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390098  SRR19330629  L004
# 11    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390098  SRR19330628  L001
# 12    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390098  SRR19330627  L003
# 13    KD6_seq1_essential_mRNA_lane_10_S34  SRX15390098  SRR19330626  L002
# 6     KD6_seq1_essential_mRNA_lane_10_S58  SRX15390093  SRR19330634  L001
# ...                                   ...          ...          ...   ...
# 2912          RD7_seq1_RPE1_mRNA_9_3_S121  SRX15541702  SRR19489457  L002
# 2646          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541700  SRR19489014  L002
# 2647          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541700  SRR19489013  L003
# 2656          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541700  SRR19489003  L001
# 2662          RD7_seq1_RPE1_mRNA_9_4_S177  SRX15541700  SRR19488997  L004
#
# [3576 rows x 4 columns]

# %%
# format
meta_f['organism'] = 'Homo sapiens'
meta_f = meta_f.rename(columns={'srx' : 'sample', 'srr' : 'accession' }).sort_values('sample')
meta_f
# Out:
#                                 exp_name       sample    accession  lane  \
# 0     KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19330645  L004
# 1     KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19330644  L001
# 50    KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19330566  L003
# 594   KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19331148  L002
# 2     KD6_seq1_essential_mRNA_lane_9_S33  SRX15390085  SRR19330642  L004
# ...                                  ...          ...          ...   ...
# 3474        RD7_seq1_RPE1_mRNA_54_4_S194  SRX15550255  SRR19497729  L004
# 3563        RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497533  L002
# 3560        RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497536  L003
# 3556        RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497540  L004
# 3564        RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497532  L001
#
#           organism
# 0     Homo sapiens
# 1     Homo sapiens
# 50    Homo sapiens
# 594   Homo sapiens
# 2     Homo sapiens
# ...            ...
# 3474  Homo sapiens
# 3563  Homo sapiens
# 3560  Homo sapiens
# 3556  Homo sapiens
# 3564  Homo sapiens
#
# [3576 rows x 5 columns]

# %%
outfile = os.path.join(repo_base_dir, 'data', 'Replogle2022', 'PRJNA83156_SRX-SRR_mRNA.csv')
meta_f.to_csv(outfile, index=False)

# %% [markdown]
# ## scRecounter: essential
#
# > Ran in a tmux session

# %% [markdown]
# ```bash
# nextflow run main.nf \
#   -ansi-log false \
#   -profile conda,trace,report,dev,chimera \
#   --use_database false \
#   --keep_raw_h5ad false \
#   --accessions /home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA83156_SRX-SRR_mRNA_essential.csv \
#   --output_dir /processed_datasets/scRecount/scRecounter/Replogle2022_essential \
#   > runs/Replogle2022_essential.log 2>&1
# ```

# %% [markdown]
# ### Summarize results

# %%
nextflow_out_dir = os.path.join("/processed_datasets/scRecount/scRecounter/Replogle2022_essential", 'STAR')

# %%
# filter to 'essential'
meta_ff = meta_f[meta_f['exp_name'].str.contains('essential')].reset_index(drop=True)
meta_ff
# Out:
#                                 exp_name       sample    accession  lane  \
# 0     KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19330645  L004
# 1     KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19330644  L001
# 2     KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19330566  L003
# 3     KD6_seq1_essential_mRNA_lane_1_S49  SRX15390082  SRR19331148  L002
# 4     KD6_seq1_essential_mRNA_lane_9_S33  SRX15390085  SRR19330642  L004
# ..                                   ...          ...          ...   ...
# 379  KD6_seq1_essential_mRNA_lane_17_S65  SRX15391059  SRR19331153  L001
# 380  KD6_seq1_essential_mRNA_lane_17_S41  SRX15391063  SRR19331151  L003
# 381  KD6_seq1_essential_mRNA_lane_17_S41  SRX15391063  SRR19331152  L001
# 382  KD6_seq1_essential_mRNA_lane_17_S41  SRX15391063  SRR19331149  L004
# 383  KD6_seq1_essential_mRNA_lane_17_S41  SRX15391063  SRR19331150  L002
#
#          organism
# 0    Homo sapiens
# 1    Homo sapiens
# 2    Homo sapiens
# 3    Homo sapiens
# 4    Homo sapiens
# ..            ...
# 379  Homo sapiens
# 380  Homo sapiens
# 381  Homo sapiens
# 382  Homo sapiens
# 383  Homo sapiens
#
# [384 rows x 5 columns]

# %%
# number of unique srx
len(meta_ff['sample'].unique())
# Out:
# 96

# %%
# find all star output dirs
star_out_dirs = glob(os.path.join(nextflow_out_dir, "SRX*"))
len(star_out_dirs)
# Out:
# 79

# %%
# missing from essential
srx = [os.path.basename(x) for x in star_out_dirs]
meta_fff = meta_ff[~meta_ff['sample'].isin(srx)].reset_index(drop=True)
# number of unique srx
print(f"Missing SRX count: {len(meta_fff['sample'].unique())}")
# Out:
# Missing SRX count: 17

# %%
# missing samples
sorted(meta_fff['sample'].unique().tolist())
# Out:
# ['SRX15390337',
#  'SRX15390349',
#  'SRX15390362',
#  'SRX15390375',
#  'SRX15390384',
#  'SRX15390421',
#  'SRX15390427',
#  'SRX15390429',
#  'SRX15390554',
#  'SRX15390611',
#  'SRX15390615',
#  'SRX15390637',
#  'SRX15390645',
#  'SRX15390654',
#  'SRX15390667',
#  'SRX15390696',
#  'SRX15390909']

# %%
# write to file
outfile = os.path.join(repo_base_dir, 'data', 'Replogle2022', 'PRJNA83156_SRX-SRR_mRNA_essential-missing.csv')
meta_fff.to_csv(outfile, index=False)

# %% [markdown]
# #### Essential-missing run
#
# ```bash
# nextflow run main.nf \
#   -ansi-log false \
#   -profile conda,trace,report,dev,chimera \
#   --use_database false \
#   --keep_raw_h5ad false \
#   --accessions /home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA83156_SRX-SRR_mRNA_essential-missing.csv \
#   --output_dir /processed_datasets/scRecount/scRecounter/Replogle2022_essential-missing \
#   > runs/Replogle2022_essential-missing.log 2>&1
# ```

# %% [markdown]
# > Manually merged the missing samples into the essential run

# %%
# check for all h5ad files
h5ad_files = glob(os.path.join(nextflow_out_dir, "*", "h5ad", "filtered", "Gene.h5ad"))
len(h5ad_files)
# Out:
# 92

# %%
# missing h5ad files
srx = [x.split("/")[-4] for x in h5ad_files]
meta_fff = meta_ff[~meta_ff['sample'].isin(srx)]
meta_fff
# Out:
#                                 exp_name       sample    accession  lane  \
# 60   KD6_seq1_essential_mRNA_lane_26_S74  SRX15390163  SRR19330561  L001
# 61   KD6_seq1_essential_mRNA_lane_26_S74  SRX15390163  SRR19330563  L003
# 62   KD6_seq1_essential_mRNA_lane_26_S74  SRX15390163  SRR19330564  L004
# 63   KD6_seq1_essential_mRNA_lane_26_S74  SRX15390163  SRR19330562  L002
# 96   KD6_seq1_essential_mRNA_lane_47_S71  SRX15390206  SRR19330518  L001
# 97   KD6_seq1_essential_mRNA_lane_47_S71  SRX15390206  SRR19330519  L003
# 98   KD6_seq1_essential_mRNA_lane_47_S71  SRX15390206  SRR19330520  L002
# 99   KD6_seq1_essential_mRNA_lane_47_S71  SRX15390206  SRR19330521  L004
# 116   KD6_seq1_essential_mRNA_lane_7_S31  SRX15390275  SRR19330441  L002
# 117   KD6_seq1_essential_mRNA_lane_7_S31  SRX15390275  SRR19330452  L003
# 118   KD6_seq1_essential_mRNA_lane_7_S31  SRX15390275  SRR19330430  L004
# 119   KD6_seq1_essential_mRNA_lane_7_S31  SRX15390275  SRR19330928  L001
# 168   KD6_seq1_essential_mRNA_lane_1_S25  SRX15390401  SRR19331001  L003
# 169   KD6_seq1_essential_mRNA_lane_1_S25  SRX15390401  SRR19330815  L004
# 170   KD6_seq1_essential_mRNA_lane_1_S25  SRX15390401  SRR19331256  L002
# 171   KD6_seq1_essential_mRNA_lane_1_S25  SRX15390401  SRR19331217  L001
#
#          organism
# 60   Homo sapiens
# 61   Homo sapiens
# 62   Homo sapiens
# 63   Homo sapiens
# 96   Homo sapiens
# 97   Homo sapiens
# 98   Homo sapiens
# 99   Homo sapiens
# 116  Homo sapiens
# 117  Homo sapiens
# 118  Homo sapiens
# 119  Homo sapiens
# 168  Homo sapiens
# 169  Homo sapiens
# 170  Homo sapiens
# 171  Homo sapiens

# %%
meta_fff['sample'].unique()
# Out:
# array(['SRX15390163', 'SRX15390206', 'SRX15390275', 'SRX15390401'],
#       dtype=object)

# %%
# write missing samples to file
outfile = os.path.join(repo_base_dir, 'data', 'Replogle2022', 'PRJNA83156_SRX-SRR_mRNA_essential-missing2.csv')
meta_fff.to_csv(outfile, index=False)

# %% [markdown]
# #### Essential-missing2 run
#
# ```bash
# nextflow run main.nf \
#   -ansi-log false \
#   -profile conda,trace,report,dev,chimera \
#   --use_database false \
#   --keep_raw_h5ad false \
#   --accessions /home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA83156_SRX-SRR_mRNA_essential-missing2.csv \
#   --output_dir /processed_datasets/scRecount/scRecounter/Replogle2022_essential-missing2 \
#   > runs/Replogle2022_essential-missing2.log 2>&1
# ```

# %% [markdown]
# > Manually merged the missing samples into the essential-missing run

# %%
# check for all h5ad files
h5ad_files = glob(os.path.join(nextflow_out_dir, "*", "h5ad", "filtered", "Gene.h5ad"))
len(h5ad_files)
# Out:
# 96

# %% [markdown]
# ## scRecounter: non-essential (other)
#
# > Ran in a tmux session

# %% [markdown]
# ```bash
# nextflow run main.nf \
#   -ansi-log false \
#   -profile conda,trace,report,dev,chimera \
#   --use_database false \
#   --keep_raw_h5ad false \
#   --accessions /home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA83156_SRX-SRR_mRNA_other.csv \
#   --output_dir /processed_datasets/scRecount/scRecounter/Replogle2022_other \
#   > runs/Replogle2022_other.log 2>&1
# ```

# %% [markdown]
# ### Summarize results

# %%
nextflow_out_dir = os.path.join("/processed_datasets/scRecount/scRecounter/Replogle2022_other", 'STAR')

# %%
# filter to non-essential
meta_ff = meta_f[~meta_f['exp_name'].str.contains('essential')].reset_index(drop=True)
meta_ff
# Out:
#                           exp_name       sample    accession  lane  \
# 0            KD8_seq1_p1_mRNA_4_S5  SRX15390228  SRR19330499  L001
# 1            KD8_seq1_p1_mRNA_4_S5  SRX15390228  SRR19330498  L002
# 2            KD8_seq1_p1_mRNA_4_S5  SRX15390228  SRR19330497  L003
# 3            KD8_seq1_p1_mRNA_4_S5  SRX15390228  SRR19330496  L004
# 4            KD8_seq2_p1_mRNA_4_S5  SRX15390232  SRR19330492  L001
# ...                            ...          ...          ...   ...
# 3187  RD7_seq1_RPE1_mRNA_54_4_S194  SRX15550255  SRR19497729  L004
# 3188  RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497533  L002
# 3189  RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497536  L003
# 3190  RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497540  L004
# 3191  RD7_seq1_RPE1_mRNA_47_4_S187  SRX15550444  SRR19497532  L001
#
#           organism
# 0     Homo sapiens
# 1     Homo sapiens
# 2     Homo sapiens
# 3     Homo sapiens
# 4     Homo sapiens
# ...            ...
# 3187  Homo sapiens
# 3188  Homo sapiens
# 3189  Homo sapiens
# 3190  Homo sapiens
# 3191  Homo sapiens
#
# [3192 rows x 5 columns]

# %%
# number of unique srx
len(meta_ff['sample'].unique())
# Out:
# 798

# %%
# find all star output dirs
star_out_dirs = glob(os.path.join(nextflow_out_dir, "SRX*"))
len(star_out_dirs)
# Out:
# 798

# %%
# missing from essential
srx = [os.path.basename(x) for x in star_out_dirs]
meta_fff = meta_ff[~meta_ff['sample'].isin(srx)].reset_index(drop=True)
# number of unique srx
print(f"Missing SRX count: {len(meta_fff['sample'].unique())}")
# Out:
# Missing SRX count: 0

# %%
# check for all h5ad files
h5ad_files = glob(os.path.join(nextflow_out_dir, "*", "h5ad", "filtered", "Gene.h5ad"))
len(h5ad_files)
# Out:
# 798

# %% [markdown]
# # `PRJNA1100571`

# %%
bioproject_id = 'PRJNA1100571'

# %%
# get srx info for the bioproject
# !{repo_base_dir}/scripts/bioproject2srx.py --email nick.youngblut@arcinstitute.org {bioproject_id} > {repo_base_dir}/data/Replogle2022/{bioproject_id}_SRX-SRR.csv
# Out:
# esearch of bioproject for: PRJNA1100571
# elink of bioproject for: PRJNA1100571
#   Total SRA records: 2240
# efetch of sra for: 32614908
# efetch of sra for: 32614907
# efetch of sra for: 32614906
# efetch of sra for: 32614905
# efetch of sra for: 32614904
# efetch of sra for: 32614903
# efetch of sra for: 32614902
# efetch of sra for: 32614901
# efetch of sra for: 32614900
# efetch of sra for: 32614899
# efetch of sra for: 32614898
# efetch of sra for: 32614897
# efetch of sra for: 32614896
# efetch of sra for: 32614895
# efetch of sra for: 32614894
# efetch of sra for: 32614893
# efetch of sra for: 32614892
# efetch of sra for: 32614891
# efetch of sra for: 32614890
# efetch of sra for: 32614889
# efetch of sra for: 32614888
# efetch of sra for: 32614887
# efetch of sra for: 32614886
# efetch of sra for: 32614885
# efetch of sra for: 32614884
# efetch of sra for: 32614883
# efetch of sra for: 32614882
# efetch of sra for: 32614881
# efetch of sra for: 32614880
# efetch of sra for: 32614879
# efetch of sra for: 32614878
# efetch of sra for: 32614877
# efetch of sra for: 32614876
# efetch of sra for: 32614875
# efetch of sra for: 32614874
# efetch of sra for: 32614873
# efetch of sra for: 32614872
# efetch of sra for: 32614871
# efetch of sra for: 32614870
# efetch of sra for: 32614869
# efetch of sra for: 32614868
# efetch of sra for: 32614867
# efetch of sra for: 32614866
# efetch of sra for: 32614865
# efetch of sra for: 32614864
# efetch of sra for: 32614863
# efetch of sra for: 32614862
# efetch of sra for: 32614861
# efetch of sra for: 32614860
# efetch of sra for: 32614859
# efetch of sra for: 32614858
# efetch of sra for: 32614857
# efetch of sra for: 32614856
# efetch of sra for: 32614855
# efetch of sra for: 32614854
# efetch of sra for: 32614853
# efetch of sra for: 32614852
# efetch of sra for: 32614851
# efetch of sra for: 32614850
# efetch of sra for: 32614849
# efetch of sra for: 32614848
# efetch of sra for: 32614847
# efetch of sra for: 32614846
# efetch of sra for: 32614845
# efetch of sra for: 32614844
# efetch of sra for: 32614843
# efetch of sra for: 32614842
# efetch of sra for: 32614841
# efetch of sra for: 32614840
# efetch of sra for: 32614839
# efetch of sra for: 32614838
# efetch of sra for: 32614837
# efetch of sra for: 32614836
# efetch of sra for: 32614835
# efetch of sra for: 32614834
# efetch of sra for: 32614833
# efetch of sra for: 32614832
# efetch of sra for: 32614831
# efetch of sra for: 32614830
# efetch of sra for: 32614829
# efetch of sra for: 32614828
# efetch of sra for: 32614827
# efetch of sra for: 32614826
# efetch of sra for: 32614825
# efetch of sra for: 32614824
# efetch of sra for: 32614823
# efetch of sra for: 32614822
# efetch of sra for: 32614821
# efetch of sra for: 32614820
# efetch of sra for: 32614819
# efetch of sra for: 32614818
# efetch of sra for: 32614817
# efetch of sra for: 32614816
# efetch of sra for: 32614815
# efetch of sra for: 32614814
# efetch of sra for: 32614813
# efetch of sra for: 32614812
# efetch of sra for: 32614811
# efetch of sra for: 32614810
# efetch of sra for: 32614809
# efetch of sra for: 32614808
# efetch of sra for: 32614807
# efetch of sra for: 32614806
# efetch of sra for: 32614805
# efetch of sra for: 32614804
# efetch of sra for: 32614803
# efetch of sra for: 32614802
# efetch of sra for: 32614801
# efetch of sra for: 32614800
# efetch of sra for: 32614799
# efetch of sra for: 32614798
# efetch of sra for: 32614797
# efetch of sra for: 32614796
# efetch of sra for: 32614795
# efetch of sra for: 32614794
# efetch of sra for: 32614793
# efetch of sra for: 32614792
# efetch of sra for: 32614791
# efetch of sra for: 32614790
# efetch of sra for: 32614789
# efetch of sra for: 32614788
# efetch of sra for: 32614787
# efetch of sra for: 32614786
# efetch of sra for: 32614785
# efetch of sra for: 32614784
# efetch of sra for: 32614783
# efetch of sra for: 32614782
# efetch of sra for: 32614781
# efetch of sra for: 32614780
# efetch of sra for: 32614779
# efetch of sra for: 32614778
# efetch of sra for: 32614777
# efetch of sra for: 32614776
# efetch of sra for: 32614775
# efetch of sra for: 32614774
# efetch of sra for: 32614773
# efetch of sra for: 32614772
# efetch of sra for: 32614771
# efetch of sra for: 32614770
# efetch of sra for: 32614769
# efetch of sra for: 32614768
# efetch of sra for: 32614767
# efetch of sra for: 32614766
# efetch of sra for: 32614765
# efetch of sra for: 32614764
# efetch of sra for: 32614763
# efetch of sra for: 32614762
# efetch of sra for: 32614761
# efetch of sra for: 32614760
# efetch of sra for: 32614759
# efetch of sra for: 32614758
# efetch of sra for: 32614757
# efetch of sra for: 32614756
# efetch of sra for: 32614755
# efetch of sra for: 32614754
# efetch of sra for: 32614753
# efetch of sra for: 32614752
# efetch of sra for: 32614751
# efetch of sra for: 32614750
# efetch of sra for: 32614749
# efetch of sra for: 32614748
# efetch of sra for: 32614747
# efetch of sra for: 32614746
# efetch of sra for: 32614745
# efetch of sra for: 32614744
# efetch of sra for: 32614743
# efetch of sra for: 32614742
# efetch of sra for: 32614741
# efetch of sra for: 32614740
# efetch of sra for: 32614739
# efetch of sra for: 32614738
# efetch of sra for: 32614737
# efetch of sra for: 32614736
# efetch of sra for: 32614735
# efetch of sra for: 32614734
# efetch of sra for: 32614733
# efetch of sra for: 32614732
# efetch of sra for: 32614731
# efetch of sra for: 32614730
# efetch of sra for: 32614729
# efetch of sra for: 32614728
# efetch of sra for: 32614727
# efetch of sra for: 32614726
# efetch of sra for: 32614725
# efetch of sra for: 32614724
# efetch of sra for: 32614723
# efetch of sra for: 32614722
# efetch of sra for: 32614721
# efetch of sra for: 32614720
# efetch of sra for: 32614719
# efetch of sra for: 32614718
# efetch of sra for: 32614717
# efetch of sra for: 32614716
# efetch of sra for: 32614715
# efetch of sra for: 32614714
# efetch of sra for: 32614713
# efetch of sra for: 32614712
# efetch of sra for: 32614711
# efetch of sra for: 32614710
# efetch of sra for: 32614709
# efetch of sra for: 32614708
# efetch of sra for: 32614707
# efetch of sra for: 32614706
# efetch of sra for: 32614705
# efetch of sra for: 32614704
# efetch of sra for: 32614703
# efetch of sra for: 32614702
# efetch of sra for: 32614701
# efetch of sra for: 32614700
# efetch of sra for: 32614699
# efetch of sra for: 32614698
# efetch of sra for: 32614697
# efetch of sra for: 32614696
# efetch of sra for: 32614695
# efetch of sra for: 32614694
# efetch of sra for: 32614693
# efetch of sra for: 32614692
# efetch of sra for: 32614691
# efetch of sra for: 32614690
# efetch of sra for: 32614689
# efetch of sra for: 32614688
# efetch of sra for: 32614687
# efetch of sra for: 32614686
# efetch of sra for: 32614685
# efetch of sra for: 32614684
# efetch of sra for: 32614683
# efetch of sra for: 32614682
# efetch of sra for: 32614681
# efetch of sra for: 32614680
# efetch of sra for: 32614679
# efetch of sra for: 32614678
# efetch of sra for: 32614677
# efetch of sra for: 32614676
# efetch of sra for: 32614675
# efetch of sra for: 32614674
# efetch of sra for: 32614673
# efetch of sra for: 32614672
# efetch of sra for: 32614671
# efetch of sra for: 32614670
# efetch of sra for: 32614669
# efetch of sra for: 32614668
# efetch of sra for: 32614667
# efetch of sra for: 32614666
# efetch of sra for: 32614665
# efetch of sra for: 32614664
# efetch of sra for: 32614663
# efetch of sra for: 32614662
# efetch of sra for: 32614661
# efetch of sra for: 32614660
# efetch of sra for: 32614659
# efetch of sra for: 32614658
# efetch of sra for: 32614657
# efetch of sra for: 32614656
# efetch of sra for: 32614655
# efetch of sra for: 32614654
# efetch of sra for: 32614653
# efetch of sra for: 32614652
# efetch of sra for: 32614651
# efetch of sra for: 32614650
# efetch of sra for: 32614649
# efetch of sra for: 32614648
# efetch of sra for: 32614647
# efetch of sra for: 32614646
# efetch of sra for: 32614645
# efetch of sra for: 32614644
# efetch of sra for: 32614643
# efetch of sra for: 32614642
# efetch of sra for: 32614641
# efetch of sra for: 32614640
# efetch of sra for: 32614639
# efetch of sra for: 32614638
# efetch of sra for: 32614637
# efetch of sra for: 32614636
# efetch of sra for: 32614635
# efetch of sra for: 32614634
# efetch of sra for: 32614633
# efetch of sra for: 32614632
# efetch of sra for: 32614631
# efetch of sra for: 32614630
# efetch of sra for: 32614629
# efetch of sra for: 32614628
# efetch of sra for: 32614627
# efetch of sra for: 32614626
# efetch of sra for: 32614625
# efetch of sra for: 32614624
# efetch of sra for: 32614623
# efetch of sra for: 32614622
# efetch of sra for: 32614621
# efetch of sra for: 32614620
# efetch of sra for: 32614619
# efetch of sra for: 32614618
# efetch of sra for: 32614617
# efetch of sra for: 32614616
# efetch of sra for: 32614615
# efetch of sra for: 32614614
# efetch of sra for: 32614613
# efetch of sra for: 32614612
# efetch of sra for: 32614611
# efetch of sra for: 32614610
# efetch of sra for: 32614609
# efetch of sra for: 32614608
# efetch of sra for: 32614607
# efetch of sra for: 32614606
# efetch of sra for: 32614605
# efetch of sra for: 32614604
# efetch of sra for: 32614603
# efetch of sra for: 32614602
# efetch of sra for: 32614601
# efetch of sra for: 32614600
# efetch of sra for: 32614599
# efetch of sra for: 32614598
# efetch of sra for: 32614597
# efetch of sra for: 32614596
# efetch of sra for: 32614595
# efetch of sra for: 32614594
# efetch of sra for: 32614593
# efetch of sra for: 32614592
# efetch of sra for: 32614591
# efetch of sra for: 32614590
# efetch of sra for: 32614589
# efetch of sra for: 32614588
# efetch of sra for: 32614587
# efetch of sra for: 32614586
# efetch of sra for: 32614585
# efetch of sra for: 32614584
# efetch of sra for: 32614583
# efetch of sra for: 32614582
# efetch of sra for: 32614581
# efetch of sra for: 32614580
# efetch of sra for: 32614579
# efetch of sra for: 32614578
# efetch of sra for: 32614577
# efetch of sra for: 32614576
# efetch of sra for: 32614575
# efetch of sra for: 32614574
# efetch of sra for: 32614573
# efetch of sra for: 32614572
# efetch of sra for: 32614571
# efetch of sra for: 32614570
# efetch of sra for: 32614569
# efetch of sra for: 32614568
# efetch of sra for: 32614567
# efetch of sra for: 32614566
# efetch of sra for: 32614565
# efetch of sra for: 32614564
# efetch of sra for: 32614563
# efetch of sra for: 32614562
# efetch of sra for: 32614561
# efetch of sra for: 32614560
# efetch of sra for: 32614559
# efetch of sra for: 32614558
# efetch of sra for: 32614557
# efetch of sra for: 32614556
# efetch of sra for: 32614555
# efetch of sra for: 32614554
# efetch of sra for: 32614553
# efetch of sra for: 32614552
# efetch of sra for: 32614551
# efetch of sra for: 32614550
# efetch of sra for: 32614549
# efetch of sra for: 32614548
# efetch of sra for: 32614547
# efetch of sra for: 32614546
# efetch of sra for: 32614545
# efetch of sra for: 32614544
# efetch of sra for: 32614543
# efetch of sra for: 32614542
# efetch of sra for: 32614541
# efetch of sra for: 32614540
# efetch of sra for: 32614539
# efetch of sra for: 32614538
# efetch of sra for: 32614537
# efetch of sra for: 32614536
# efetch of sra for: 32614535
# efetch of sra for: 32614534
# efetch of sra for: 32614533
# efetch of sra for: 32614532
# efetch of sra for: 32614531
# efetch of sra for: 32614530
# efetch of sra for: 32614529
# efetch of sra for: 32614528
# efetch of sra for: 32614527
# efetch of sra for: 32614526
# efetch of sra for: 32614525
# efetch of sra for: 32614524
# efetch of sra for: 32614523
# efetch of sra for: 32614522
# efetch of sra for: 32614521
# efetch of sra for: 32614520
# efetch of sra for: 32614519
# efetch of sra for: 32614518
# efetch of sra for: 32614517
# efetch of sra for: 32614516
# efetch of sra for: 32614515
# efetch of sra for: 32614514
# efetch of sra for: 32614513
# efetch of sra for: 32614512
# efetch of sra for: 32614511
# efetch of sra for: 32614510
# efetch of sra for: 32614509
# efetch of sra for: 32614508
# efetch of sra for: 32614507
# efetch of sra for: 32614506
# efetch of sra for: 32614505
# efetch of sra for: 32614504
# efetch of sra for: 32614503
# efetch of sra for: 32614502
# efetch of sra for: 32614501
# efetch of sra for: 32614500
# efetch of sra for: 32614499
# efetch of sra for: 32614498
# efetch of sra for: 32614497
# efetch of sra for: 32614496
# efetch of sra for: 32614495
# efetch of sra for: 32614494
# efetch of sra for: 32614493
# efetch of sra for: 32614492
# efetch of sra for: 32614491
# efetch of sra for: 32614490
# efetch of sra for: 32614489
# efetch of sra for: 32614488
# efetch of sra for: 32614487
# efetch of sra for: 32614486
# efetch of sra for: 32614485
# efetch of sra for: 32614484
# efetch of sra for: 32614483
# efetch of sra for: 32614482
# efetch of sra for: 32614481
# efetch of sra for: 32614480
# efetch of sra for: 32614479
# efetch of sra for: 32614478
# efetch of sra for: 32614477
# efetch of sra for: 32614476
# efetch of sra for: 32614475
# efetch of sra for: 32614474
# efetch of sra for: 32614473
# efetch of sra for: 32614472
# efetch of sra for: 32614471
# efetch of sra for: 32614470
# efetch of sra for: 32614469
# efetch of sra for: 32614468
# efetch of sra for: 32614467
# efetch of sra for: 32614466
# efetch of sra for: 32614465
# efetch of sra for: 32614464
# efetch of sra for: 32614463
# efetch of sra for: 32614462
# efetch of sra for: 32614461
# efetch of sra for: 32587815
# efetch of sra for: 32587814
# efetch of sra for: 32587813
# efetch of sra for: 32587812
# efetch of sra for: 32587811
# efetch of sra for: 32587810
# efetch of sra for: 32587809
# efetch of sra for: 32587808
# efetch of sra for: 32587807
# efetch of sra for: 32587806
# efetch of sra for: 32587805
# efetch of sra for: 32587804
# efetch of sra for: 32587803
# efetch of sra for: 32587802
# efetch of sra for: 32587801
# efetch of sra for: 32587800
# efetch of sra for: 32587799
# efetch of sra for: 32587798
# efetch of sra for: 32587797
# efetch of sra for: 32587796
# efetch of sra for: 32587795
# efetch of sra for: 32587794
# efetch of sra for: 32587793
# efetch of sra for: 32587792
# efetch of sra for: 32587791
# efetch of sra for: 32587790
# efetch of sra for: 32587789
# efetch of sra for: 32587788
# efetch of sra for: 32587787
# efetch of sra for: 32587786
# efetch of sra for: 32587785
# efetch of sra for: 32587784
# efetch of sra for: 32587783
# efetch of sra for: 32587782
# efetch of sra for: 32587781
# efetch of sra for: 32587780
# efetch of sra for: 32587779
# efetch of sra for: 32587778
# efetch of sra for: 32587777
# efetch of sra for: 32587776
# efetch of sra for: 32587775
# efetch of sra for: 32587774
# efetch of sra for: 32587773
# efetch of sra for: 32587772
# efetch of sra for: 32587771
# efetch of sra for: 32587770
# efetch of sra for: 32587769
# efetch of sra for: 32587768
# efetch of sra for: 32587767
# efetch of sra for: 32587766
# efetch of sra for: 32587765
# efetch of sra for: 32587764
# efetch of sra for: 32587763
# efetch of sra for: 32587762
# efetch of sra for: 32587761
# efetch of sra for: 32587760
# efetch of sra for: 32587759
# efetch of sra for: 32587758
# efetch of sra for: 32587757
# efetch of sra for: 32587756
# efetch of sra for: 32587755
# efetch of sra for: 32587754
# efetch of sra for: 32587753
# efetch of sra for: 32587752
# efetch of sra for: 32587751
# efetch of sra for: 32587750
# efetch of sra for: 32587749
# efetch of sra for: 32587748
# efetch of sra for: 32587747
# efetch of sra for: 32587746
# efetch of sra for: 32587745
# efetch of sra for: 32587744
# efetch of sra for: 32587743
# efetch of sra for: 32587742
# efetch of sra for: 32587741
# efetch of sra for: 32587740
# efetch of sra for: 32587739
# efetch of sra for: 32587738
# efetch of sra for: 32587737
# efetch of sra for: 32587736
# efetch of sra for: 32587735
# efetch of sra for: 32587734
# efetch of sra for: 32587733
# efetch of sra for: 32587732
# efetch of sra for: 32587731
# efetch of sra for: 32587730
# efetch of sra for: 32587729
# efetch of sra for: 32587728
# efetch of sra for: 32587727
# efetch of sra for: 32587726
# efetch of sra for: 32587725
# efetch of sra for: 32587724
# efetch of sra for: 32587723
# efetch of sra for: 32587722
# efetch of sra for: 32587721
# efetch of sra for: 32587720
# efetch of sra for: 32587719
# efetch of sra for: 32587718
# efetch of sra for: 32587717
# efetch of sra for: 32587716
# efetch of sra for: 32587715
# efetch of sra for: 32587714
# efetch of sra for: 32587713
# efetch of sra for: 32587712
# efetch of sra for: 32587711
# efetch of sra for: 32587710
# efetch of sra for: 32587709
# efetch of sra for: 32587708
# efetch of sra for: 32587707
# efetch of sra for: 32587706
# efetch of sra for: 32587705
# efetch of sra for: 32587704
# efetch of sra for: 32587703
# efetch of sra for: 32587702
# efetch of sra for: 32587701
# efetch of sra for: 32587700
# efetch of sra for: 32587699
# efetch of sra for: 32587698
# efetch of sra for: 32587697
# efetch of sra for: 32587696
# efetch of sra for: 32587695
# efetch of sra for: 32587694
# efetch of sra for: 32587693
# efetch of sra for: 32587692
# efetch of sra for: 32587691
# efetch of sra for: 32587690
# efetch of sra for: 32587689
# efetch of sra for: 32587688
# efetch of sra for: 32587687
# efetch of sra for: 32587686
# efetch of sra for: 32587685
# efetch of sra for: 32587684
# efetch of sra for: 32587683
# efetch of sra for: 32587682
# efetch of sra for: 32587681
# efetch of sra for: 32587680
# efetch of sra for: 32587679
# efetch of sra for: 32587678
# efetch of sra for: 32587677
# efetch of sra for: 32587676
# efetch of sra for: 32587675
# efetch of sra for: 32587674
# efetch of sra for: 32587673
# efetch of sra for: 32587672
# efetch of sra for: 32587671
# efetch of sra for: 32587670
# efetch of sra for: 32587669
# efetch of sra for: 32587668
# efetch of sra for: 32587667
# efetch of sra for: 32587666
# efetch of sra for: 32587665
# efetch of sra for: 32587664
# efetch of sra for: 32587663
# efetch of sra for: 32587662
# efetch of sra for: 32587661
# efetch of sra for: 32587660
# efetch of sra for: 32587659
# efetch of sra for: 32587658
# efetch of sra for: 32587657
# efetch of sra for: 32587656
# efetch of sra for: 32587655
# efetch of sra for: 32587654
# efetch of sra for: 32587653
# efetch of sra for: 32587652
# efetch of sra for: 32587651
# efetch of sra for: 32587650
# efetch of sra for: 32587649
# efetch of sra for: 32587648
# efetch of sra for: 32587647
# efetch of sra for: 32587646
# efetch of sra for: 32587645
# efetch of sra for: 32587644
# efetch of sra for: 32587643
# efetch of sra for: 32587642
# efetch of sra for: 32587641
# efetch of sra for: 32587640
# efetch of sra for: 32587639
# efetch of sra for: 32587638
# efetch of sra for: 32587637
# efetch of sra for: 32587636
# efetch of sra for: 32587635
# efetch of sra for: 32587634
# efetch of sra for: 32587633
# efetch of sra for: 32587632
# efetch of sra for: 32587631
# efetch of sra for: 32587630
# efetch of sra for: 32587629
# efetch of sra for: 32587628
# efetch of sra for: 32587627
# efetch of sra for: 32587626
# efetch of sra for: 32587625
# efetch of sra for: 32587624
# efetch of sra for: 32587623
# efetch of sra for: 32587622
# efetch of sra for: 32587621
# efetch of sra for: 32587620
# efetch of sra for: 32587619
# efetch of sra for: 32587618
# efetch of sra for: 32587617
# efetch of sra for: 32587616
# efetch of sra for: 32587615
# efetch of sra for: 32587614
# efetch of sra for: 32587613
# efetch of sra for: 32587612
# efetch of sra for: 32587611
# efetch of sra for: 32587610
# efetch of sra for: 32587609
# efetch of sra for: 32587608
# efetch of sra for: 32587607
# efetch of sra for: 32587606
# efetch of sra for: 32587605
# efetch of sra for: 32587604
# efetch of sra for: 32587603
# efetch of sra for: 32587602
# efetch of sra for: 32587601
# efetch of sra for: 32587600
# efetch of sra for: 32587599
# efetch of sra for: 32587598
# efetch of sra for: 32587597
# efetch of sra for: 32587596
# efetch of sra for: 32587595
# efetch of sra for: 32587594
# efetch of sra for: 32587593
# efetch of sra for: 32587592
# efetch of sra for: 32587591
# efetch of sra for: 32587590
# efetch of sra for: 32587589
# efetch of sra for: 32587588
# efetch of sra for: 32587587
# efetch of sra for: 32587586
# efetch of sra for: 32587585
# efetch of sra for: 32587584
# efetch of sra for: 32587583
# efetch of sra for: 32587582
# efetch of sra for: 32587581
# efetch of sra for: 32587580
# efetch of sra for: 32587579
# efetch of sra for: 32587578
# efetch of sra for: 32587577
# efetch of sra for: 32587576
# efetch of sra for: 32587575
# efetch of sra for: 32587574
# efetch of sra for: 32587573
# efetch of sra for: 32587572
# efetch of sra for: 32587571
# efetch of sra for: 32587570
# efetch of sra for: 32587569
# efetch of sra for: 32587568
# efetch of sra for: 32587567
# efetch of sra for: 32587566
# efetch of sra for: 32587565
# efetch of sra for: 32587564
# efetch of sra for: 32587563
# efetch of sra for: 32587562
# efetch of sra for: 32587561
# efetch of sra for: 32587560
# efetch of sra for: 32587559
# efetch of sra for: 32587558
# efetch of sra for: 32587557
# efetch of sra for: 32587556
# efetch of sra for: 32587555
# efetch of sra for: 32587554
# efetch of sra for: 32587553
# efetch of sra for: 32587552
# efetch of sra for: 32587551
# efetch of sra for: 32587550
# efetch of sra for: 32587549
# efetch of sra for: 32587548
# efetch of sra for: 32587547
# efetch of sra for: 32587546
# efetch of sra for: 32587545
# efetch of sra for: 32587544
# efetch of sra for: 32587543
# efetch of sra for: 32587542
# efetch of sra for: 32587541
# efetch of sra for: 32587540
# efetch of sra for: 32587539
# efetch of sra for: 32587538
# efetch of sra for: 32587537
# efetch of sra for: 32587536
# efetch of sra for: 32587535
# efetch of sra for: 32587534
# efetch of sra for: 32587533
# efetch of sra for: 32587532
# efetch of sra for: 32587531
# efetch of sra for: 32587530
# efetch of sra for: 32587529
# efetch of sra for: 32587528
# efetch of sra for: 32587527
# efetch of sra for: 32587526
# efetch of sra for: 32587525
# efetch of sra for: 32587524
# efetch of sra for: 32587523
# efetch of sra for: 32587522
# efetch of sra for: 32587521
# efetch of sra for: 32587520
# efetch of sra for: 32587519
# efetch of sra for: 32587518
# efetch of sra for: 32587517
# efetch of sra for: 32587516
# efetch of sra for: 32587515
# efetch of sra for: 32587514
# efetch of sra for: 32587513
# efetch of sra for: 32587512
# efetch of sra for: 32587511
# efetch of sra for: 32587510
# efetch of sra for: 32587509
# efetch of sra for: 32587508
# efetch of sra for: 32587507
# efetch of sra for: 32587506
# efetch of sra for: 32587505
# efetch of sra for: 32587504
# efetch of sra for: 32587503
# efetch of sra for: 32587502
# efetch of sra for: 32587501
# efetch of sra for: 32587500
# efetch of sra for: 32587499
# efetch of sra for: 32587498
# efetch of sra for: 32587497
# efetch of sra for: 32587496
# efetch of sra for: 32587495
# efetch of sra for: 32587494
# efetch of sra for: 32587493
# efetch of sra for: 32587492
# efetch of sra for: 32587491
# efetch of sra for: 32587490
# efetch of sra for: 32587489
# efetch of sra for: 32587488
# efetch of sra for: 32587487
# efetch of sra for: 32587486
# efetch of sra for: 32587485
# efetch of sra for: 32587484
# efetch of sra for: 32587483
# efetch of sra for: 32587482
# efetch of sra for: 32587481
# efetch of sra for: 32587480
# efetch of sra for: 32587479
# efetch of sra for: 32587478
# efetch of sra for: 32587477
# efetch of sra for: 32587476
# efetch of sra for: 32587475
# efetch of sra for: 32587474
# efetch of sra for: 32587473
# efetch of sra for: 32587472
# efetch of sra for: 32587471
# efetch of sra for: 32587470
# efetch of sra for: 32587469
# efetch of sra for: 32587468
# efetch of sra for: 32587467
# efetch of sra for: 32587466
# efetch of sra for: 32587465
# efetch of sra for: 32587464
# efetch of sra for: 32587463
# efetch of sra for: 32587462
# efetch of sra for: 32587461
# efetch of sra for: 32587460
# efetch of sra for: 32587459
# efetch of sra for: 32587458
# efetch of sra for: 32587457
# efetch of sra for: 32587456
# efetch of sra for: 32587455
# efetch of sra for: 32587454
# efetch of sra for: 32587453
# efetch of sra for: 32587452
# efetch of sra for: 32587451
# efetch of sra for: 32587450
# efetch of sra for: 32587449
# efetch of sra for: 32587448
# efetch of sra for: 32587447
# efetch of sra for: 32587446
# efetch of sra for: 32587445
# efetch of sra for: 32587444
# efetch of sra for: 32587443
# efetch of sra for: 32587442
# efetch of sra for: 32587441
# efetch of sra for: 32587440
# efetch of sra for: 32587439
# efetch of sra for: 32587438
# efetch of sra for: 32587437
# efetch of sra for: 32587436
# efetch of sra for: 32587435
# efetch of sra for: 32587434
# efetch of sra for: 32587433
# efetch of sra for: 32587432
# efetch of sra for: 32587431
# efetch of sra for: 32587430
# efetch of sra for: 32587429
# efetch of sra for: 32587428
# efetch of sra for: 32587427
# efetch of sra for: 32587426
# efetch of sra for: 32587425
# efetch of sra for: 32587424
# efetch of sra for: 32587423
# efetch of sra for: 32587422
# efetch of sra for: 32587421
# efetch of sra for: 32587420
# efetch of sra for: 32587419
# efetch of sra for: 32587418
# efetch of sra for: 32587417
# efetch of sra for: 32587416
# efetch of sra for: 32587415
# efetch of sra for: 32587414
# efetch of sra for: 32587413
# efetch of sra for: 32587412
# efetch of sra for: 32587411
# efetch of sra for: 32587410
# efetch of sra for: 32587409
# efetch of sra for: 32587408
# efetch of sra for: 32587407
# efetch of sra for: 32587406
# efetch of sra for: 32587405
# efetch of sra for: 32587404
# efetch of sra for: 32587403
# efetch of sra for: 32587402
# efetch of sra for: 32587401
# efetch of sra for: 32587400
# efetch of sra for: 32587399
# efetch of sra for: 32587398
# efetch of sra for: 32587397
# efetch of sra for: 32587396
# efetch of sra for: 32587395
# efetch of sra for: 32587394
# efetch of sra for: 32587393
# efetch of sra for: 32587392
# efetch of sra for: 32587391
# efetch of sra for: 32587390
# efetch of sra for: 32587389
# efetch of sra for: 32587388
# efetch of sra for: 32587387
# efetch of sra for: 32587386
# efetch of sra for: 32587385
# efetch of sra for: 32587384
# efetch of sra for: 32587383
# efetch of sra for: 32587382
# efetch of sra for: 32587381
# efetch of sra for: 32587380
# efetch of sra for: 32587379
# efetch of sra for: 32587378
# efetch of sra for: 32587377
# efetch of sra for: 32587376
# efetch of sra for: 32587375
# efetch of sra for: 32587374
# efetch of sra for: 32587373
# efetch of sra for: 32587372
# efetch of sra for: 32587371
# efetch of sra for: 32587370
# efetch of sra for: 32587369
# efetch of sra for: 32587368
# efetch of sra for: 32587367
# efetch of sra for: 32587366
# efetch of sra for: 32587365
# efetch of sra for: 32587364
# efetch of sra for: 32587363
# efetch of sra for: 32587362
# efetch of sra for: 32587361
# efetch of sra for: 32587360
# efetch of sra for: 32587359
# efetch of sra for: 32587358
# efetch of sra for: 32587357
# efetch of sra for: 32587356
# efetch of sra for: 32587355
# efetch of sra for: 32587354
# efetch of sra for: 32587353
# efetch of sra for: 32587352
# efetch of sra for: 32587351
# efetch of sra for: 32587350
# efetch of sra for: 32587349
# efetch of sra for: 32587348
# efetch of sra for: 32587347
# efetch of sra for: 32587346
# efetch of sra for: 32587345
# efetch of sra for: 32587344
# efetch of sra for: 32587343
# efetch of sra for: 32587342
# efetch of sra for: 32587341
# efetch of sra for: 32587340
# efetch of sra for: 32587339
# efetch of sra for: 32587338
# efetch of sra for: 32587337
# efetch of sra for: 32587336
# efetch of sra for: 32587335
# efetch of sra for: 32587334
# efetch of sra for: 32587333
# efetch of sra for: 32587332
# efetch of sra for: 32587331
# efetch of sra for: 32587330
# efetch of sra for: 32587329
# efetch of sra for: 32587328
# efetch of sra for: 32587327
# efetch of sra for: 32587326
# efetch of sra for: 32587325
# efetch of sra for: 32587324
# efetch of sra for: 32587323
# efetch of sra for: 32587322
# efetch of sra for: 32587321
# efetch of sra for: 32587320
# efetch of sra for: 32587319
# efetch of sra for: 32587318
# efetch of sra for: 32587317
# efetch of sra for: 32587316
# efetch of sra for: 32587315
# efetch of sra for: 32587314
# efetch of sra for: 32587313
# efetch of sra for: 32587312
# efetch of sra for: 32587311
# efetch of sra for: 32587310
# efetch of sra for: 32587309
# efetch of sra for: 32587308
# efetch of sra for: 32587307
# efetch of sra for: 32587306
# efetch of sra for: 32587305
# efetch of sra for: 32587304
# efetch of sra for: 32587303
# efetch of sra for: 32587302
# efetch of sra for: 32587301
# efetch of sra for: 32587300
# efetch of sra for: 32587299
# efetch of sra for: 32587298
# efetch of sra for: 32587297
# efetch of sra for: 32587296
# efetch of sra for: 32587295
# efetch of sra for: 32587294
# efetch of sra for: 32587293
# efetch of sra for: 32587292
# efetch of sra for: 32587291
# efetch of sra for: 32587290
# efetch of sra for: 32587289
# efetch of sra for: 32587288
# efetch of sra for: 32587287
# efetch of sra for: 32587286
# efetch of sra for: 32587285
# efetch of sra for: 32587284
# efetch of sra for: 32587283
# efetch of sra for: 32587282
# efetch of sra for: 32587281
# efetch of sra for: 32587280
# efetch of sra for: 32587279
# efetch of sra for: 32587278
# efetch of sra for: 32587277
# efetch of sra for: 32587276
# efetch of sra for: 32587275
# efetch of sra for: 32587274
# efetch of sra for: 32587273
# efetch of sra for: 32587272
# efetch of sra for: 32587271
# efetch of sra for: 32587270
# efetch of sra for: 32587269
# efetch of sra for: 32587268
# efetch of sra for: 32587267
# efetch of sra for: 32587266
# efetch of sra for: 32587265
# efetch of sra for: 32587264
# efetch of sra for: 32587263
# efetch of sra for: 32587262
# efetch of sra for: 32587261
# efetch of sra for: 32587260
# efetch of sra for: 32587259
# efetch of sra for: 32587258
# efetch of sra for: 32587257
# efetch of sra for: 32587256
# efetch of sra for: 32587255
# efetch of sra for: 32587254
# efetch of sra for: 32587253
# efetch of sra for: 32587252
# efetch of sra for: 32587251
# efetch of sra for: 32587250
# efetch of sra for: 32587249
# efetch of sra for: 32587248
# efetch of sra for: 32587247
# efetch of sra for: 32587246
# efetch of sra for: 32587245
# efetch of sra for: 32587244
# efetch of sra for: 32587243
# efetch of sra for: 32587242
# efetch of sra for: 32587241
# efetch of sra for: 32587240
# efetch of sra for: 32587239
# efetch of sra for: 32587238
# efetch of sra for: 32587237
# efetch of sra for: 32587236
# efetch of sra for: 32587235
# efetch of sra for: 32587234
# efetch of sra for: 32587233
# efetch of sra for: 32587232
# efetch of sra for: 32587231
# efetch of sra for: 32587230
# efetch of sra for: 32587229
# efetch of sra for: 32587228
# efetch of sra for: 32587227
# efetch of sra for: 32587226
# efetch of sra for: 32587225
# efetch of sra for: 32587224
# efetch of sra for: 32587223
# efetch of sra for: 32587222
# efetch of sra for: 32587221
# efetch of sra for: 32587220
# efetch of sra for: 32587219
# efetch of sra for: 32587218
# efetch of sra for: 32587217
# efetch of sra for: 32587216
# efetch of sra for: 32587215
# efetch of sra for: 32587214
# efetch of sra for: 32587213
# efetch of sra for: 32587212
# efetch of sra for: 32587211
# efetch of sra for: 32587210
# efetch of sra for: 32587209
# efetch of sra for: 32587208
# efetch of sra for: 32587207
# efetch of sra for: 32587206
# efetch of sra for: 32587205
# efetch of sra for: 32587204
# efetch of sra for: 32587203
# efetch of sra for: 32587202
# efetch of sra for: 32587201
# efetch of sra for: 32587200
# efetch of sra for: 32587199
# efetch of sra for: 32587198
# efetch of sra for: 32587197
# efetch of sra for: 32587196
# efetch of sra for: 32587195
# efetch of sra for: 32587194
# efetch of sra for: 32587193
# efetch of sra for: 32587192
# efetch of sra for: 32587191
# efetch of sra for: 32587190
# efetch of sra for: 32587189
# efetch of sra for: 32587188
# efetch of sra for: 32587187
# efetch of sra for: 32587186
# efetch of sra for: 32587185
# efetch of sra for: 32587184
# efetch of sra for: 32587183
# efetch of sra for: 32587182
# efetch of sra for: 32587181
# efetch of sra for: 32587180
# efetch of sra for: 32587179
# efetch of sra for: 32587178
# efetch of sra for: 32587177
# efetch of sra for: 32587176
# efetch of sra for: 32587175
# efetch of sra for: 32587174
# efetch of sra for: 32587173
# efetch of sra for: 32587172
# efetch of sra for: 32587171
# efetch of sra for: 32587170
# efetch of sra for: 32587169
# efetch of sra for: 32587168
# efetch of sra for: 32587167
# efetch of sra for: 32587166
# efetch of sra for: 32587165
# efetch of sra for: 32587164
# efetch of sra for: 32587163
# efetch of sra for: 32587162
# efetch of sra for: 32587161
# efetch of sra for: 32587160
# efetch of sra for: 32587159
# efetch of sra for: 32587158
# efetch of sra for: 32587157
# efetch of sra for: 32587156
# efetch of sra for: 32587155
# efetch of sra for: 32587154
# efetch of sra for: 32587153
# efetch of sra for: 32587152
# efetch of sra for: 32587151
# efetch of sra for: 32587150
# efetch of sra for: 32587149
# efetch of sra for: 32587148
# efetch of sra for: 32587147
# efetch of sra for: 32587146
# efetch of sra for: 32587145
# efetch of sra for: 32587144
# efetch of sra for: 32587143
# efetch of sra for: 32587142
# efetch of sra for: 32587141
# efetch of sra for: 32587140
# efetch of sra for: 32587139
# efetch of sra for: 32587138
# efetch of sra for: 32587137
# efetch of sra for: 32587136
# efetch of sra for: 32587135
# efetch of sra for: 32587134
# efetch of sra for: 32587133
# efetch of sra for: 32587132
# efetch of sra for: 32587131
# efetch of sra for: 32587130
# efetch of sra for: 32587129
# efetch of sra for: 32587128
# efetch of sra for: 32587127
# efetch of sra for: 32587126
# efetch of sra for: 32587125
# efetch of sra for: 32587124
# efetch of sra for: 32587123
# efetch of sra for: 32587122
# efetch of sra for: 32587121
# efetch of sra for: 32587120
# efetch of sra for: 32587119
# efetch of sra for: 32587118
# efetch of sra for: 32587117
# efetch of sra for: 32587116
# efetch of sra for: 32587115
# efetch of sra for: 32587114
# efetch of sra for: 32587113
# efetch of sra for: 32587112
# efetch of sra for: 32587111
# efetch of sra for: 32587110
# efetch of sra for: 32587109
# efetch of sra for: 32587108
# efetch of sra for: 32587107
# efetch of sra for: 32587106
# efetch of sra for: 32587105
# efetch of sra for: 32587104
# efetch of sra for: 32587103
# efetch of sra for: 32587102
# efetch of sra for: 32587101
# efetch of sra for: 32587100
# efetch of sra for: 32587099
# efetch of sra for: 32587098
# efetch of sra for: 32587097
# efetch of sra for: 32587096
# efetch of sra for: 32587095
# efetch of sra for: 32587094
# efetch of sra for: 32587093
# efetch of sra for: 32587092
# efetch of sra for: 32587091
# efetch of sra for: 32587090
# efetch of sra for: 32587089
# efetch of sra for: 32587088
# efetch of sra for: 32587087
# efetch of sra for: 32587086
# efetch of sra for: 32587085
# efetch of sra for: 32587084
# efetch of sra for: 32587083
# efetch of sra for: 32587082
# efetch of sra for: 32587081
# efetch of sra for: 32587080
# efetch of sra for: 32587079
# efetch of sra for: 32587078
# efetch of sra for: 32587077
# efetch of sra for: 32587076
# efetch of sra for: 32587075
# efetch of sra for: 32587074
# efetch of sra for: 32587073
# efetch of sra for: 32587072
# efetch of sra for: 32587071
# efetch of sra for: 32587070
# efetch of sra for: 32587069
# efetch of sra for: 32587068
# efetch of sra for: 32587067
# efetch of sra for: 32587066
# efetch of sra for: 32587065
# efetch of sra for: 32587064
# efetch of sra for: 32587063
# efetch of sra for: 32587062
# efetch of sra for: 32587061
# efetch of sra for: 32587060
# efetch of sra for: 32587059
# efetch of sra for: 32587058
# efetch of sra for: 32587057
# efetch of sra for: 32587056
# efetch of sra for: 32587055
# efetch of sra for: 32587054
# efetch of sra for: 32587053
# efetch of sra for: 32587052
# efetch of sra for: 32587051
# efetch of sra for: 32587050
# efetch of sra for: 32587049
# efetch of sra for: 32587048
# efetch of sra for: 32587047
# efetch of sra for: 32587046
# efetch of sra for: 32587045
# efetch of sra for: 32587044
# efetch of sra for: 32587043
# efetch of sra for: 32587042
# efetch of sra for: 32587041
# efetch of sra for: 32587040
# efetch of sra for: 32587039
# efetch of sra for: 32587038
# efetch of sra for: 32587037
# efetch of sra for: 32587036
# efetch of sra for: 32587035
# efetch of sra for: 32587034
# efetch of sra for: 32587033
# efetch of sra for: 32587032
# efetch of sra for: 32587031
# efetch of sra for: 32587030
# efetch of sra for: 32587029
# efetch of sra for: 32587028
# efetch of sra for: 32587027
# efetch of sra for: 32587026
# efetch of sra for: 32587025
# efetch of sra for: 32587024
# efetch of sra for: 32587023
# efetch of sra for: 32587022
# efetch of sra for: 32587021
# efetch of sra for: 32587020
# efetch of sra for: 32587019
# efetch of sra for: 32587018
# efetch of sra for: 32587017
# efetch of sra for: 32587016
# efetch of sra for: 32587015
# efetch of sra for: 32587014
# efetch of sra for: 32587013
# efetch of sra for: 32587012
# efetch of sra for: 32587011
# efetch of sra for: 32587010
# efetch of sra for: 32587009
# efetch of sra for: 32587008
# efetch of sra for: 32587007
# efetch of sra for: 32587006
# efetch of sra for: 32587005
# efetch of sra for: 32587004
# efetch of sra for: 32587003
# efetch of sra for: 32587002
# efetch of sra for: 32587001
# efetch of sra for: 32587000
# efetch of sra for: 32586999
# efetch of sra for: 32586998
# efetch of sra for: 32586997
# efetch of sra for: 32586996
# efetch of sra for: 32586995
# efetch of sra for: 32586994
# efetch of sra for: 32586993
# efetch of sra for: 32586992
# efetch of sra for: 32586991
# efetch of sra for: 32586990
# efetch of sra for: 32586989
# efetch of sra for: 32586988
# efetch of sra for: 32586987
# efetch of sra for: 32586986
# efetch of sra for: 32586985
# efetch of sra for: 32586984
# efetch of sra for: 32586983
# efetch of sra for: 32586982
# efetch of sra for: 32586981
# efetch of sra for: 32586980
# efetch of sra for: 32586979
# efetch of sra for: 32586978
# efetch of sra for: 32586977
# efetch of sra for: 32586976
# efetch of sra for: 32586975
# efetch of sra for: 32586974
# efetch of sra for: 32586973
# efetch of sra for: 32586972
# efetch of sra for: 32586971
# efetch of sra for: 32586970
# efetch of sra for: 32586969
# efetch of sra for: 32586968
# efetch of sra for: 32586967
# efetch of sra for: 32586966
# efetch of sra for: 32586965
# efetch of sra for: 32586964
# efetch of sra for: 32586963
# efetch of sra for: 32586962
# efetch of sra for: 32586961
# efetch of sra for: 32586960
# efetch of sra for: 32586959
# efetch of sra for: 32586958
# efetch of sra for: 32586957
# efetch of sra for: 32586956
# efetch of sra for: 32586955
# efetch of sra for: 32586954
# efetch of sra for: 32586953
# efetch of sra for: 32586952
# efetch of sra for: 32586951
# efetch of sra for: 32586950
# efetch of sra for: 32586949
# efetch of sra for: 32586948
# efetch of sra for: 32586947
# efetch of sra for: 32586946
# efetch of sra for: 32586945
# efetch of sra for: 32586944
# efetch of sra for: 32586943
# efetch of sra for: 32586942
# efetch of sra for: 32586941
# efetch of sra for: 32586940
# efetch of sra for: 32586939
# efetch of sra for: 32586938
# efetch of sra for: 32586937
# efetch of sra for: 32586936
# efetch of sra for: 32586935
# efetch of sra for: 32586934
# efetch of sra for: 32586933
# efetch of sra for: 32586932
# efetch of sra for: 32586931
# efetch of sra for: 32586930
# efetch of sra for: 32586929
# efetch of sra for: 32586928
# efetch of sra for: 32586927
# efetch of sra for: 32586926
# efetch of sra for: 32586925
# efetch of sra for: 32586924
# efetch of sra for: 32586923
# efetch of sra for: 32586922
# efetch of sra for: 32586921
# efetch of sra for: 32586920
# efetch of sra for: 32571263
# efetch of sra for: 32571262
# efetch of sra for: 32571261
# efetch of sra for: 32571260
# efetch of sra for: 32571259
# efetch of sra for: 32571258
# efetch of sra for: 32571257
# efetch of sra for: 32571256
# efetch of sra for: 32571255
# efetch of sra for: 32571254
# efetch of sra for: 32571253
# efetch of sra for: 32571252
# efetch of sra for: 32571251
# efetch of sra for: 32571250
# efetch of sra for: 32571249
# efetch of sra for: 32571248
# efetch of sra for: 32571247
# efetch of sra for: 32571246
# efetch of sra for: 32571245
# efetch of sra for: 32571244
# efetch of sra for: 32571243
# efetch of sra for: 32571242
# efetch of sra for: 32571241
# efetch of sra for: 32571240
# efetch of sra for: 32571239
# efetch of sra for: 32571238
# efetch of sra for: 32571237
# efetch of sra for: 32571236
# efetch of sra for: 32571235
# efetch of sra for: 32571234
# efetch of sra for: 32571233
# efetch of sra for: 32571232
# efetch of sra for: 32571231
# efetch of sra for: 32571230
# efetch of sra for: 32571229
# efetch of sra for: 32571228
# efetch of sra for: 32571227
# efetch of sra for: 32571226
# efetch of sra for: 32571225
# efetch of sra for: 32571224
# efetch of sra for: 32571223
# efetch of sra for: 32571222
# efetch of sra for: 32571221
# efetch of sra for: 32571220
# efetch of sra for: 32571219
# efetch of sra for: 32571218
# efetch of sra for: 32571217
# efetch of sra for: 32571216
# efetch of sra for: 32571215
# efetch of sra for: 32571214
# efetch of sra for: 32571213
# efetch of sra for: 32571212
# efetch of sra for: 32571211
# efetch of sra for: 32571210
# efetch of sra for: 32571209
# efetch of sra for: 32571208
# efetch of sra for: 32571207
# efetch of sra for: 32571206
# efetch of sra for: 32571205
# efetch of sra for: 32571204
# efetch of sra for: 32571203
# efetch of sra for: 32571202
# efetch of sra for: 32571201
# efetch of sra for: 32571200
# efetch of sra for: 32571199
# efetch of sra for: 32571198
# efetch of sra for: 32571197
# efetch of sra for: 32571196
# efetch of sra for: 32571195
# efetch of sra for: 32571194
# efetch of sra for: 32571193
# efetch of sra for: 32571192
# efetch of sra for: 32571191
# efetch of sra for: 32571190
# efetch of sra for: 32571189
# efetch of sra for: 32571188
# efetch of sra for: 32571187
# efetch of sra for: 32571186
# efetch of sra for: 32571185
# efetch of sra for: 32571184
# efetch of sra for: 32571183
# efetch of sra for: 32571182
# efetch of sra for: 32571181
# efetch of sra for: 32571180
# efetch of sra for: 32571179
# efetch of sra for: 32571178
# efetch of sra for: 32571177
# efetch of sra for: 32571176
# efetch of sra for: 32571175
# efetch of sra for: 32571174
# efetch of sra for: 32571173
# efetch of sra for: 32571172
# efetch of sra for: 32571171
# efetch of sra for: 32571170
# efetch of sra for: 32571169
# efetch of sra for: 32571168
# efetch of sra for: 32571167
# efetch of sra for: 32571166
# efetch of sra for: 32571165
# efetch of sra for: 32571164
# efetch of sra for: 32571163
# efetch of sra for: 32571162
# efetch of sra for: 32571161
# efetch of sra for: 32571160
# efetch of sra for: 32571159
# efetch of sra for: 32571158
# efetch of sra for: 32571157
# efetch of sra for: 32571156
# efetch of sra for: 32571155
# efetch of sra for: 32571154
# efetch of sra for: 32571153
# efetch of sra for: 32571152
# efetch of sra for: 32571151
# efetch of sra for: 32571150
# efetch of sra for: 32571149
# efetch of sra for: 32571148
# efetch of sra for: 32571147
# efetch of sra for: 32571146
# efetch of sra for: 32571145
# efetch of sra for: 32571144
# efetch of sra for: 32571143
# efetch of sra for: 32571142
# efetch of sra for: 32571141
# efetch of sra for: 32571140
# efetch of sra for: 32571139
# efetch of sra for: 32571138
# efetch of sra for: 32571137
# efetch of sra for: 32571136
# efetch of sra for: 32571135
# efetch of sra for: 32571134
# efetch of sra for: 32571133
# efetch of sra for: 32571132
# efetch of sra for: 32571131
# efetch of sra for: 32571130
# efetch of sra for: 32571129
# efetch of sra for: 32571128
# efetch of sra for: 32571127
# efetch of sra for: 32571126
# efetch of sra for: 32571125
# efetch of sra for: 32571124
# efetch of sra for: 32571123
# efetch of sra for: 32571122
# efetch of sra for: 32571121
# efetch of sra for: 32571120
# efetch of sra for: 32571119
# efetch of sra for: 32571118
# efetch of sra for: 32571117
# efetch of sra for: 32571116
# efetch of sra for: 32571115
# efetch of sra for: 32571114
# efetch of sra for: 32571113
# efetch of sra for: 32571112
# efetch of sra for: 32571111
# efetch of sra for: 32571110
# efetch of sra for: 32571109
# efetch of sra for: 32571108
# efetch of sra for: 32571107
# efetch of sra for: 32571106
# efetch of sra for: 32571105
# efetch of sra for: 32571104
# efetch of sra for: 32571103
# efetch of sra for: 32571102
# efetch of sra for: 32571101
# efetch of sra for: 32571100
# efetch of sra for: 32571099
# efetch of sra for: 32571098
# efetch of sra for: 32571097
# efetch of sra for: 32571096
# efetch of sra for: 32571095
# efetch of sra for: 32571094
# efetch of sra for: 32571093
# efetch of sra for: 32571092
# efetch of sra for: 32571091
# efetch of sra for: 32571090
# efetch of sra for: 32571089
# efetch of sra for: 32571088
# efetch of sra for: 32571087
# efetch of sra for: 32571086
# efetch of sra for: 32571085
# efetch of sra for: 32571084
# efetch of sra for: 32571083
# efetch of sra for: 32571082
# efetch of sra for: 32571081
# efetch of sra for: 32571080
# efetch of sra for: 32571079
# efetch of sra for: 32571078
# efetch of sra for: 32571077
# efetch of sra for: 32571076
# efetch of sra for: 32571075
# efetch of sra for: 32571074
# efetch of sra for: 32571073
# efetch of sra for: 32571072
# efetch of sra for: 32571071
# efetch of sra for: 32571070
# efetch of sra for: 32571069
# efetch of sra for: 32571068
# efetch of sra for: 32571067
# efetch of sra for: 32571066
# efetch of sra for: 32571065
# efetch of sra for: 32571064
# efetch of sra for: 32571063
# efetch of sra for: 32571062
# efetch of sra for: 32571061
# efetch of sra for: 32571060
# efetch of sra for: 32571059
# efetch of sra for: 32571058
# efetch of sra for: 32571057
# efetch of sra for: 32571056
# efetch of sra for: 32571055
# efetch of sra for: 32571054
# efetch of sra for: 32571053
# efetch of sra for: 32571052
# efetch of sra for: 32571051
# efetch of sra for: 32571050
# efetch of sra for: 32571049
# efetch of sra for: 32571048
# efetch of sra for: 32571047
# efetch of sra for: 32571046
# efetch of sra for: 32571045
# efetch of sra for: 32571044
# efetch of sra for: 32571043
# efetch of sra for: 32571042
# efetch of sra for: 32571041
# efetch of sra for: 32571040
# efetch of sra for: 32571039
# efetch of sra for: 32571038
# efetch of sra for: 32571037
# efetch of sra for: 32571036
# efetch of sra for: 32571035
# efetch of sra for: 32571034
# efetch of sra for: 32571033
# efetch of sra for: 32571032
# efetch of sra for: 32571031
# efetch of sra for: 32571030
# efetch of sra for: 32571029
# efetch of sra for: 32571028
# efetch of sra for: 32571027
# efetch of sra for: 32571026
# efetch of sra for: 32571025
# efetch of sra for: 32571024
# efetch of sra for: 32571023
# efetch of sra for: 32571022
# efetch of sra for: 32571021
# efetch of sra for: 32571020
# efetch of sra for: 32571019
# efetch of sra for: 32571018
# efetch of sra for: 32571017
# efetch of sra for: 32571016
# efetch of sra for: 32571015
# efetch of sra for: 32571014
# efetch of sra for: 32571013
# efetch of sra for: 32571012
# efetch of sra for: 32571011
# efetch of sra for: 32571010
# efetch of sra for: 32571009
# efetch of sra for: 32571008
# efetch of sra for: 32571007
# efetch of sra for: 32571006
# efetch of sra for: 32571005
# efetch of sra for: 32571004
# efetch of sra for: 32571003
# efetch of sra for: 32571002
# efetch of sra for: 32571001
# efetch of sra for: 32571000
# efetch of sra for: 32570999
# efetch of sra for: 32570998
# efetch of sra for: 32570997
# efetch of sra for: 32570996
# efetch of sra for: 32570995
# efetch of sra for: 32570994
# efetch of sra for: 32570993
# efetch of sra for: 32570992
# efetch of sra for: 32570991
# efetch of sra for: 32570990
# efetch of sra for: 32570989
# efetch of sra for: 32570988
# efetch of sra for: 32570987
# efetch of sra for: 32570986
# efetch of sra for: 32570985
# efetch of sra for: 32570984
# efetch of sra for: 32570983
# efetch of sra for: 32570982
# efetch of sra for: 32570981
# efetch of sra for: 32570980
# efetch of sra for: 32570979
# efetch of sra for: 32570978
# efetch of sra for: 32570977
# efetch of sra for: 32570976
# efetch of sra for: 32570975
# efetch of sra for: 32570974
# efetch of sra for: 32570973
# efetch of sra for: 32570972
# efetch of sra for: 32570971
# efetch of sra for: 32570970
# efetch of sra for: 32570969
# efetch of sra for: 32570968
# efetch of sra for: 32570967
# efetch of sra for: 32570966
# efetch of sra for: 32570965
# efetch of sra for: 32570964
# efetch of sra for: 32570963
# efetch of sra for: 32570962
# efetch of sra for: 32570961
# efetch of sra for: 32570960
# efetch of sra for: 32570959
# efetch of sra for: 32570958
# efetch of sra for: 32570957
# efetch of sra for: 32570956
# efetch of sra for: 32570955
# efetch of sra for: 32570954
# efetch of sra for: 32570953
# efetch of sra for: 32570952
# efetch of sra for: 32570951
# efetch of sra for: 32570950
# efetch of sra for: 32570949
# efetch of sra for: 32570948
# efetch of sra for: 32570947
# efetch of sra for: 32570946
# efetch of sra for: 32570945
# efetch of sra for: 32570944
# efetch of sra for: 32570943
# efetch of sra for: 32570942
# efetch of sra for: 32570941
# efetch of sra for: 32570940
# efetch of sra for: 32570939
# efetch of sra for: 32570938
# efetch of sra for: 32570937
# efetch of sra for: 32570936
# efetch of sra for: 32570935
# efetch of sra for: 32570934
# efetch of sra for: 32570933
# efetch of sra for: 32570932
# efetch of sra for: 32570931
# efetch of sra for: 32570930
# efetch of sra for: 32570929
# efetch of sra for: 32570928
# efetch of sra for: 32570927
# efetch of sra for: 32570926
# efetch of sra for: 32570925
# efetch of sra for: 32570924
# efetch of sra for: 32570923
# efetch of sra for: 32570922
# efetch of sra for: 32570921
# efetch of sra for: 32570920
# efetch of sra for: 32570919
# efetch of sra for: 32570918
# efetch of sra for: 32570917
# efetch of sra for: 32570916
# efetch of sra for: 32570915
# efetch of sra for: 32570914
# efetch of sra for: 32570913
# efetch of sra for: 32570912
# efetch of sra for: 32570911
# efetch of sra for: 32570910
# efetch of sra for: 32570909
# efetch of sra for: 32570908
# efetch of sra for: 32570907
# efetch of sra for: 32570906
# efetch of sra for: 32570905
# efetch of sra for: 32570904
# efetch of sra for: 32570903
# efetch of sra for: 32570902
# efetch of sra for: 32570901
# efetch of sra for: 32570900
# efetch of sra for: 32570899
# efetch of sra for: 32570898
# efetch of sra for: 32570897
# efetch of sra for: 32570896
# efetch of sra for: 32570895
# efetch of sra for: 32570894
# efetch of sra for: 32570893
# efetch of sra for: 32570892
# efetch of sra for: 32570891
# efetch of sra for: 32570890
# efetch of sra for: 32570889
# efetch of sra for: 32570888
# efetch of sra for: 32570887
# efetch of sra for: 32570886
# efetch of sra for: 32570885
# efetch of sra for: 32570884
# efetch of sra for: 32570883
# efetch of sra for: 32570882
# efetch of sra for: 32570881
# efetch of sra for: 32570880
# efetch of sra for: 32570879
# efetch of sra for: 32570878
# efetch of sra for: 32570877
# efetch of sra for: 32570876
# efetch of sra for: 32570875
# efetch of sra for: 32570874
# efetch of sra for: 32570873
# efetch of sra for: 32570872
# efetch of sra for: 32570871
# efetch of sra for: 32570870
# efetch of sra for: 32570869
# efetch of sra for: 32570868
# efetch of sra for: 32570867
# efetch of sra for: 32570866
# efetch of sra for: 32570865
# efetch of sra for: 32570864
# efetch of sra for: 32570863
# efetch of sra for: 32570862
# efetch of sra for: 32570861
# efetch of sra for: 32570860
# efetch of sra for: 32570859
# efetch of sra for: 32570858
# efetch of sra for: 32570857
# efetch of sra for: 32570856
# efetch of sra for: 32570855
# efetch of sra for: 32570854
# efetch of sra for: 32570853
# efetch of sra for: 32570852
# efetch of sra for: 32570851
# efetch of sra for: 32570850
# efetch of sra for: 32570849
# efetch of sra for: 32570848
# efetch of sra for: 32570847
# efetch of sra for: 32570846
# efetch of sra for: 32570845
# efetch of sra for: 32570844
# efetch of sra for: 32570843
# efetch of sra for: 32570842
# efetch of sra for: 32570841
# efetch of sra for: 32570840
# efetch of sra for: 32570839
# efetch of sra for: 32570838
# efetch of sra for: 32570837
# efetch of sra for: 32570836
# efetch of sra for: 32570835
# efetch of sra for: 32570834
# efetch of sra for: 32570833
# efetch of sra for: 32570832
# efetch of sra for: 32570831
# efetch of sra for: 32570830
# efetch of sra for: 32570829
# efetch of sra for: 32570828
# efetch of sra for: 32570827
# efetch of sra for: 32570826
# efetch of sra for: 32570825
# efetch of sra for: 32570824
# efetch of sra for: 32570823
# efetch of sra for: 32570822
# efetch of sra for: 32570821
# efetch of sra for: 32570820
# efetch of sra for: 32570819
# efetch of sra for: 32570818
# efetch of sra for: 32570817
# efetch of sra for: 32570816
# efetch of sra for: 32570815
# efetch of sra for: 32570814
# efetch of sra for: 32570813
# efetch of sra for: 32570812
# efetch of sra for: 32570811
# efetch of sra for: 32570810
# efetch of sra for: 32570809
# efetch of sra for: 32570808
# efetch of sra for: 32570807
# efetch of sra for: 32570806
# efetch of sra for: 32570805
# efetch of sra for: 32570804
# efetch of sra for: 32570803
# efetch of sra for: 32570802
# efetch of sra for: 32570801
# efetch of sra for: 32570800
# efetch of sra for: 32570799
# efetch of sra for: 32570798
# efetch of sra for: 32570797
# efetch of sra for: 32570796
# efetch of sra for: 32570795
# efetch of sra for: 32570794
# efetch of sra for: 32570793
# efetch of sra for: 32570792
# efetch of sra for: 32570791
# efetch of sra for: 32570790
# efetch of sra for: 32570789
# efetch of sra for: 32570788
# efetch of sra for: 32570787
# efetch of sra for: 32570786
# efetch of sra for: 32570785
# efetch of sra for: 32570784
# efetch of sra for: 32570783
# efetch of sra for: 32570782
# efetch of sra for: 32570781
# efetch of sra for: 32570780
# efetch of sra for: 32570779
# efetch of sra for: 32570778
# efetch of sra for: 32570777
# efetch of sra for: 32570776
# efetch of sra for: 32570775
# efetch of sra for: 32570774
# efetch of sra for: 32570773
# efetch of sra for: 32570772
# efetch of sra for: 32570771
# efetch of sra for: 32570770
# efetch of sra for: 32570769
# efetch of sra for: 32570768
# efetch of sra for: 32570767
# efetch of sra for: 32570766
# efetch of sra for: 32570765
# efetch of sra for: 32570764
# efetch of sra for: 32570763
# efetch of sra for: 32570762
# efetch of sra for: 32570761
# efetch of sra for: 32570760
# efetch of sra for: 32570759
# efetch of sra for: 32570758
# efetch of sra for: 32570757
# efetch of sra for: 32570756
# efetch of sra for: 32570755
# efetch of sra for: 32570754
# efetch of sra for: 32570753
# efetch of sra for: 32570752
# efetch of sra for: 32570751
# efetch of sra for: 32570750
# efetch of sra for: 32570749
# efetch of sra for: 32570748
# efetch of sra for: 32570747
# efetch of sra for: 32570746
# efetch of sra for: 32570745
# efetch of sra for: 32570744
# efetch of sra for: 32570743
# efetch of sra for: 32570742
# efetch of sra for: 32570741
# efetch of sra for: 32570740
# efetch of sra for: 32570739
# efetch of sra for: 32570738
# efetch of sra for: 32570737
# efetch of sra for: 32570736
# efetch of sra for: 32570735
# efetch of sra for: 32570734
# efetch of sra for: 32570733
# efetch of sra for: 32570732
# efetch of sra for: 32570731
# efetch of sra for: 32570730
# efetch of sra for: 32570729
# efetch of sra for: 32570728
# efetch of sra for: 32570727
# efetch of sra for: 32570726
# efetch of sra for: 32570725
# efetch of sra for: 32570724
# efetch of sra for: 32570723
# efetch of sra for: 32570722
# efetch of sra for: 32570721
# efetch of sra for: 32570720
# efetch of sra for: 32570719
# efetch of sra for: 32570718
# efetch of sra for: 32570717
# efetch of sra for: 32570716
# efetch of sra for: 32570715
# efetch of sra for: 32570714
# efetch of sra for: 32570713
# efetch of sra for: 32570712
# efetch of sra for: 32570711
# efetch of sra for: 32570710
# efetch of sra for: 32570709
# efetch of sra for: 32570708
# efetch of sra for: 32570707
# efetch of sra for: 32570706
# efetch of sra for: 32570705
# efetch of sra for: 32570704
# efetch of sra for: 32570703
# efetch of sra for: 32570702
# efetch of sra for: 32570701
# efetch of sra for: 32570700
# efetch of sra for: 32570699
# efetch of sra for: 32570698
# efetch of sra for: 32570697
# efetch of sra for: 32570696
# efetch of sra for: 32570695
# efetch of sra for: 32570694
# efetch of sra for: 32570693
# efetch of sra for: 32570692
# efetch of sra for: 32570691
# efetch of sra for: 32570690
# efetch of sra for: 32570689
# efetch of sra for: 32570688
# efetch of sra for: 32570687
# efetch of sra for: 32570686
# efetch of sra for: 32570685
# efetch of sra for: 32570684
# efetch of sra for: 32570683
# efetch of sra for: 32570682
# efetch of sra for: 32570681
# efetch of sra for: 32570680
# efetch of sra for: 32570679
# efetch of sra for: 32570678
# efetch of sra for: 32570677
# efetch of sra for: 32570676
# efetch of sra for: 32570675
# efetch of sra for: 32570674
# efetch of sra for: 32570673
# efetch of sra for: 32570672
# efetch of sra for: 32570671
# efetch of sra for: 32570670
# efetch of sra for: 32570669
# efetch of sra for: 32570668
# efetch of sra for: 32570667
# efetch of sra for: 32570666
# efetch of sra for: 32570665
# efetch of sra for: 32570664
# efetch of sra for: 32570663
# efetch of sra for: 32570662
# efetch of sra for: 32570661
# efetch of sra for: 32570660
# efetch of sra for: 32570659
# efetch of sra for: 32570658
# efetch of sra for: 32570657
# efetch of sra for: 32570656
# efetch of sra for: 32570655
# efetch of sra for: 32570654
# efetch of sra for: 32570653
# efetch of sra for: 32570652
# efetch of sra for: 32570651
# efetch of sra for: 32570650
# efetch of sra for: 32570649
# efetch of sra for: 32570648
# efetch of sra for: 32570647
# efetch of sra for: 32570646
# efetch of sra for: 32570645
# efetch of sra for: 32570644
# efetch of sra for: 32570643
# efetch of sra for: 32570642
# efetch of sra for: 32570641
# efetch of sra for: 32570640
# efetch of sra for: 32570639
# efetch of sra for: 32570638
# efetch of sra for: 32570637
# efetch of sra for: 32570636
# efetch of sra for: 32570635
# efetch of sra for: 32570634
# efetch of sra for: 32570633
# efetch of sra for: 32570632
# efetch of sra for: 32570631
# efetch of sra for: 32570630
# efetch of sra for: 32570629
# efetch of sra for: 32570628
# efetch of sra for: 32570627
# efetch of sra for: 32570626
# efetch of sra for: 32570625
# efetch of sra for: 32570624
# efetch of sra for: 32570623
# efetch of sra for: 32570622
# efetch of sra for: 32570621
# efetch of sra for: 32570620
# efetch of sra for: 32570619
# efetch of sra for: 32570618
# efetch of sra for: 32570617
# efetch of sra for: 32570616
# efetch of sra for: 32570615
# efetch of sra for: 32570614
# efetch of sra for: 32570613
# efetch of sra for: 32570612
# efetch of sra for: 32570611
# efetch of sra for: 32570610
# efetch of sra for: 32570609
# efetch of sra for: 32570608
# efetch of sra for: 32570607
# efetch of sra for: 32570606
# efetch of sra for: 32570605
# efetch of sra for: 32570604
# efetch of sra for: 32570603
# efetch of sra for: 32570602
# efetch of sra for: 32570601
# efetch of sra for: 32570600
# efetch of sra for: 32570599
# efetch of sra for: 32570598
# efetch of sra for: 32570597
# efetch of sra for: 32570596
# efetch of sra for: 32570595
# efetch of sra for: 32570594
# efetch of sra for: 32570593
# efetch of sra for: 32570592
# efetch of sra for: 32570591
# efetch of sra for: 32570590
# efetch of sra for: 32570589
# efetch of sra for: 32570588
# efetch of sra for: 32570587
# efetch of sra for: 32570586
# efetch of sra for: 32570585
# efetch of sra for: 32570584
# efetch of sra for: 32570583
# efetch of sra for: 32570582
# efetch of sra for: 32570581
# efetch of sra for: 32570580
# efetch of sra for: 32570579
# efetch of sra for: 32570578
# efetch of sra for: 32570577
# efetch of sra for: 32570576
# efetch of sra for: 32570575
# efetch of sra for: 32570574
# efetch of sra for: 32570573
# efetch of sra for: 32570572
# efetch of sra for: 32570571
# efetch of sra for: 32570570
# efetch of sra for: 32570569
# efetch of sra for: 32570568
# efetch of sra for: 32570567
# efetch of sra for: 32570566
# efetch of sra for: 32570565
# efetch of sra for: 32570564
# efetch of sra for: 32570563
# efetch of sra for: 32570562
# efetch of sra for: 32570561
# efetch of sra for: 32570560
# efetch of sra for: 32570559
# efetch of sra for: 32570558
# efetch of sra for: 32570557
# efetch of sra for: 32570556
# efetch of sra for: 32570555
# efetch of sra for: 32570554
# efetch of sra for: 32570553
# efetch of sra for: 32570552
# efetch of sra for: 32570551
# efetch of sra for: 32570550
# efetch of sra for: 32570549
# efetch of sra for: 32570548
# efetch of sra for: 32570547
# efetch of sra for: 32570546
# efetch of sra for: 32570545
# efetch of sra for: 32570544
# efetch of sra for: 32570543
# efetch of sra for: 32570542
# efetch of sra for: 32570541
# efetch of sra for: 32570540
# efetch of sra for: 32570539
# efetch of sra for: 32570538
# efetch of sra for: 32570537
# efetch of sra for: 32570536
# efetch of sra for: 32570535
# efetch of sra for: 32570534
# efetch of sra for: 32570533
# efetch of sra for: 32570532
# efetch of sra for: 32570531
# efetch of sra for: 32570530
# efetch of sra for: 32570529
# efetch of sra for: 32570528
# efetch of sra for: 32570527
# efetch of sra for: 32570526
# efetch of sra for: 32570525
# efetch of sra for: 32570524
# efetch of sra for: 32570523
# efetch of sra for: 32570522
# efetch of sra for: 32570521
# efetch of sra for: 32570520
# efetch of sra for: 32570519
# efetch of sra for: 32570518
# efetch of sra for: 32570517
# efetch of sra for: 32570516
# efetch of sra for: 32570515
# efetch of sra for: 32570514
# efetch of sra for: 32570513
# efetch of sra for: 32570512
# efetch of sra for: 32570511
# efetch of sra for: 32570510
# efetch of sra for: 32570509
# efetch of sra for: 32570508
# efetch of sra for: 32570507
# efetch of sra for: 32570506
# efetch of sra for: 32570505
# efetch of sra for: 32570504
# efetch of sra for: 32570503
# efetch of sra for: 32570502
# efetch of sra for: 32570501
# efetch of sra for: 32570500
# efetch of sra for: 32570499
# efetch of sra for: 32570498
# efetch of sra for: 32570497
# efetch of sra for: 32570496
# efetch of sra for: 32570495
# efetch of sra for: 32570494
# efetch of sra for: 32570493
# efetch of sra for: 32570492
# efetch of sra for: 32570491
# efetch of sra for: 32570490
# efetch of sra for: 32570489
# efetch of sra for: 32570488
# efetch of sra for: 32570487
# efetch of sra for: 32570486
# efetch of sra for: 32570485
# efetch of sra for: 32570484
# efetch of sra for: 32570483
# efetch of sra for: 32570482
# efetch of sra for: 32570481
# efetch of sra for: 32570480
# efetch of sra for: 32570479
# efetch of sra for: 32570478
# efetch of sra for: 32570477
# efetch of sra for: 32570476
# efetch of sra for: 32570475
# efetch of sra for: 32570474
# efetch of sra for: 32570473
# efetch of sra for: 32570472
# efetch of sra for: 32570471
# efetch of sra for: 32570470
# efetch of sra for: 32570469
# efetch of sra for: 32570468
# efetch of sra for: 32570467
# efetch of sra for: 32570466
# efetch of sra for: 32570465
# efetch of sra for: 32570464
# efetch of sra for: 32570463
# efetch of sra for: 32570462
# efetch of sra for: 32570461
# efetch of sra for: 32570460
# efetch of sra for: 32570459
# efetch of sra for: 32570458
# efetch of sra for: 32570457
# efetch of sra for: 32570456
# efetch of sra for: 32570455
# efetch of sra for: 32570454
# efetch of sra for: 32570453
# efetch of sra for: 32570452
# efetch of sra for: 32570451
# efetch of sra for: 32570450
# efetch of sra for: 32570449
# efetch of sra for: 32570448
# efetch of sra for: 32570447
# efetch of sra for: 32570446
# efetch of sra for: 32570445
# efetch of sra for: 32570444
# efetch of sra for: 32570443
# efetch of sra for: 32570442
# efetch of sra for: 32570441
# efetch of sra for: 32570440
# efetch of sra for: 32570439
# efetch of sra for: 32570438
# efetch of sra for: 32570437
# efetch of sra for: 32570436
# efetch of sra for: 32570435
# efetch of sra for: 32570434
# efetch of sra for: 32570433
# efetch of sra for: 32570432
# efetch of sra for: 32570431
# efetch of sra for: 32570430
# efetch of sra for: 32570429
# efetch of sra for: 32570428
# efetch of sra for: 32570427
# efetch of sra for: 32570426
# efetch of sra for: 32570425
# efetch of sra for: 32570424
# efetch of sra for: 32570423
# efetch of sra for: 32570422
# efetch of sra for: 32570421
# efetch of sra for: 32570420
# efetch of sra for: 32570419
# efetch of sra for: 32570418
# efetch of sra for: 32570417
# efetch of sra for: 32570416
# efetch of sra for: 32570415
# efetch of sra for: 32570414
# efetch of sra for: 32570413
# efetch of sra for: 32570412
# efetch of sra for: 32570411
# efetch of sra for: 32570410
# efetch of sra for: 32570409
# efetch of sra for: 32570408
# efetch of sra for: 32570407
# efetch of sra for: 32570406
# efetch of sra for: 32570405
# efetch of sra for: 32570404
# efetch of sra for: 32570403
# efetch of sra for: 32570402
# efetch of sra for: 32570401
# efetch of sra for: 32570400
# efetch of sra for: 32570399
# efetch of sra for: 32570398
# efetch of sra for: 32570397
# efetch of sra for: 32570396
# efetch of sra for: 32570395
# efetch of sra for: 32570394
# efetch of sra for: 32570393
# efetch of sra for: 32570392
# efetch of sra for: 32570391
# efetch of sra for: 32570390
# efetch of sra for: 32570389
# efetch of sra for: 32570388
# efetch of sra for: 32570387
# efetch of sra for: 32570386
# efetch of sra for: 32570385
# efetch of sra for: 32570384
# efetch of sra for: 32570383
# efetch of sra for: 32570382
# efetch of sra for: 32570381
# efetch of sra for: 32570380
# efetch of sra for: 32570379
# efetch of sra for: 32570378
# efetch of sra for: 32570377
# efetch of sra for: 32570376
# efetch of sra for: 32570375
# efetch of sra for: 32570374
# efetch of sra for: 32570373
# efetch of sra for: 32570372
# efetch of sra for: 32570371
# efetch of sra for: 32570370
# efetch of sra for: 32570369
# efetch of sra for: 32570368
#   Total SRA records found: 2240

# %% [markdown]
# ## Get metadata

# %%
meta_file = os.path.join(repo_base_dir, "data", "Replogle2022", f"{bioproject_id}_SRX-SRR.csv")
meta_file
# Out:
# '/home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA1100571_SRX-SRR.csv'

# %% [markdown]
# ### Summarize

# %%
meta = pd.read_csv(meta_file)
meta
# Out:
#                     exp_name          srx          srr
# 0      jurkat_mRNA_28_4_L002  SRX24257841  SRR28690026
# 1     jurkat_sgRNA_28_4_L002  SRX24257842  SRR28690025
# 2      jurkat_mRNA_28_4_L003  SRX24257843  SRR28690024
# 3     jurkat_sgRNA_28_4_L003  SRX24257844  SRR28690023
# 4      jurkat_mRNA_28_4_L004  SRX24257845  SRR28690022
# ...                      ...          ...          ...
# 2235      hepg2_mRNA_11_L004  SRX24302170  SRR28736022
# 2236     hepg2_sgRNA_11_L004  SRX24302171  SRR28736021
# 2237      hepg2_mRNA_12_L001  SRX24302172  SRR28736020
# 2238     hepg2_sgRNA_12_L001  SRX24302173  SRR28736019
# 2239      hepg2_sgRNA_2_L001  SRX24302174  SRR28736018
#
# [2240 rows x 3 columns]

# %%
# repeat names?
df = meta['exp_name'].value_counts().reset_index()
df[df['count'] > 1]
# Out:
# Empty DataFrame
# Columns: [exp_name, count]
# Index: []

# %%
# format the mRNA samples
meta_f = meta.copy()
meta_f[['exp_name', 'lane', 'X']] = meta_f['exp_name'].str.extract(r"(.+)_((L[0-9]+))$")
meta_f = meta_f[meta_f['lane'].notna()]
meta_f = meta_f[meta_f['exp_name'].str.contains('mRNA')].reset_index(drop=True)
meta_f = meta_f.drop(columns=['X']).sort_values(['exp_name', 'srx']).reset_index(drop=True)
meta_f
# Out:
#              exp_name          srx          srr  lane
# 0        hepg2_mRNA_1  SRX24301727  SRR28736017  L001
# 1        hepg2_mRNA_1  SRX24301935  SRR28735809  L002
# 2        hepg2_mRNA_1  SRX24302013  SRR28736179  L003
# 3        hepg2_mRNA_1  SRX24302059  SRR28736133  L004
# 4       hepg2_mRNA_10  SRX24302155  SRR28736037  L001
# ...               ...          ...          ...   ...
# 1115  jurkat_mRNA_9_3  SRX24258573  SRR28690314  L004
# 1116  jurkat_mRNA_9_4  SRX24258576  SRR28690311  L001
# 1117  jurkat_mRNA_9_4  SRX24258578  SRR28690309  L002
# 1118  jurkat_mRNA_9_4  SRX24258580  SRR28690307  L003
# 1119  jurkat_mRNA_9_4  SRX24258582  SRR28690305  L004
#
# [1120 rows x 4 columns]

# %%
# number of SRR per SRX
meta_f['exp_name'].value_counts().reset_index().describe()
# Out:
#        count
# count  280.0
# mean     4.0
# std      0.0
# min      4.0
# 25%      4.0
# 50%      4.0
# 75%      4.0
# max      4.0

# %%
# use first srx for each exp_name
meta_f['srx'] = meta_f.groupby('exp_name')['srx'].transform('first')
meta_f
# Out:
#              exp_name          srx          srr  lane
# 0        hepg2_mRNA_1  SRX24301727  SRR28736017  L001
# 1        hepg2_mRNA_1  SRX24301727  SRR28735809  L002
# 2        hepg2_mRNA_1  SRX24301727  SRR28736179  L003
# 3        hepg2_mRNA_1  SRX24301727  SRR28736133  L004
# 4       hepg2_mRNA_10  SRX24302155  SRR28736037  L001
# ...               ...          ...          ...   ...
# 1115  jurkat_mRNA_9_3  SRX24258370  SRR28690314  L004
# 1116  jurkat_mRNA_9_4  SRX24258576  SRR28690311  L001
# 1117  jurkat_mRNA_9_4  SRX24258576  SRR28690309  L002
# 1118  jurkat_mRNA_9_4  SRX24258576  SRR28690307  L003
# 1119  jurkat_mRNA_9_4  SRX24258576  SRR28690305  L004
#
# [1120 rows x 4 columns]

# %%
# format
meta_f['organism'] = 'Homo sapiens'
meta_f = meta_f.rename(columns={'srx' : 'sample', 'srr' : 'accession' }).sort_values('sample').reset_index(drop=True)
meta_f
# Out:
#               exp_name       sample    accession  lane      organism
# 0     jurkat_mRNA_28_4  SRX24257841  SRR28690024  L003  Homo sapiens
# 1     jurkat_mRNA_28_4  SRX24257841  SRR28690026  L002  Homo sapiens
# 2     jurkat_mRNA_28_4  SRX24257841  SRR28690022  L004  Homo sapiens
# 3     jurkat_mRNA_28_4  SRX24257841  SRR28690029  L001  Homo sapiens
# 4      jurkat_mRNA_3_4  SRX24257848  SRR28690038  L001  Homo sapiens
# ...                ...          ...          ...   ...           ...
# 1115     hepg2_mRNA_10  SRX24302155  SRR28736037  L001  Homo sapiens
# 1116     hepg2_mRNA_11  SRX24302164  SRR28736026  L002  Homo sapiens
# 1117     hepg2_mRNA_11  SRX24302164  SRR28736028  L001  Homo sapiens
# 1118     hepg2_mRNA_11  SRX24302164  SRR28736022  L004  Homo sapiens
# 1119     hepg2_mRNA_11  SRX24302164  SRR28736024  L003  Homo sapiens
#
# [1120 rows x 5 columns]

# %%
# number of unique srx (sample)
meta_f['sample'].unique().shape
# Out:
# (280,)

# %%
# write to file
outfile = os.path.join(repo_base_dir, 'data', 'Replogle2022', f'{bioproject_id}_SRX-SRR_mRNA.csv')
meta_f.to_csv(outfile, index=False)

# %% [markdown]
# ## scRecounter

# %% [markdown]
# ```bash
# nextflow run main.nf \
#   -ansi-log false \
#   -profile conda,trace,report,dev,chimera \
#   --use_database false \
#   --keep_raw_h5ad false \
#   --accessions /home/nickyoungblut/dev/python/scBaseCount_analysis/data/Replogle2022/PRJNA1100571_SRX-SRR_mRNA.csv \
#   --output_dir /processed_datasets/scRecount/scRecounter/Replogle2022_PRJNA1100571 \
#   > runs/Replogle2022_PRJNA1100571.log 2>&1
# ```

# %% [markdown]
# ### Summarize results

# %%
nextflow_out_dir = os.path.join("/processed_datasets/scRecount/scRecounter/Replogle2022_PRJNA1100571", 'STAR')

# %%
# find all star output dirs
star_out_dirs = glob(os.path.join(nextflow_out_dir, "SRX*"))
len(star_out_dirs)
# Out:
# 280

# %%
# missing from essential
srx = [os.path.basename(x) for x in star_out_dirs]
meta_fff = meta_ff[~meta_ff['sample'].isin(srx)].reset_index(drop=True)
# number of unique srx
print(f"Missing SRX count: {len(meta_fff['sample'].unique())}")
# Out:
# Missing SRX count: 17

# %%
# missing samples
sorted(meta_fff['sample'].unique().tolist())
# Out:
# ['SRX15390337',
#  'SRX15390349',
#  'SRX15390362',
#  'SRX15390375',
#  'SRX15390384',
#  'SRX15390421',
#  'SRX15390427',
#  'SRX15390429',
#  'SRX15390554',
#  'SRX15390611',
#  'SRX15390615',
#  'SRX15390637',
#  'SRX15390645',
#  'SRX15390654',
#  'SRX15390667',
#  'SRX15390696',
#  'SRX15390909']

# %%
# write to file
outfile = os.path.join(repo_base_dir, 'data', 'Replogle2022', 'PRJNA83156_SRX-SRR_mRNA_essential-missing.csv')
meta_fff.to_csv(outfile, index=False)

# %% [markdown]
# # Dataset summary

# %%
# set options to just print 4 rows
pd.set_option('display.max_rows', 4)

# %%
datasets = ["Replogle2022_essential", "Replogle2022_other", "Replogle2022_PRJNA1100571"]
summary_dfs = []
for dataset in datasets:
    nextflow_out_dir = os.path.join("/processed_datasets/scRecount/scRecounter", dataset, "STAR")
    # find all star output dirs
    summary_files = glob(os.path.join(nextflow_out_dir, "SRX*", "summary", "combined.csv"))
    #print(len(summary_files))
    # read in summary files
    summary_dfs.append(
        pd.concat([pd.read_csv(x) for x in summary_files])
    )

# combine all summary dataframes
summary_df = pd.concat(summary_dfs)
summary_df
# Out:
#                     feature  estimated_number_of_cells  \
# 0                      Gene                      12288
# 1                  GeneFull                      12450
# ..                      ...                        ...
# 3   GeneFull_ExonOverIntron                      12409
# 4                  Velocyto                          0
#
#     fraction_of_unique_reads_in_cells  mean_reads_per_cell  mean_umi_per_cell  \
# 0                            0.906709               8342.0             7467.0
# 1                            0.918815              10803.0             9668.0
# ..                                ...                  ...                ...
# 3                            0.956585               4413.0             3280.0
# 4                                 NaN                  NaN                NaN
#
#     mean_feature_per_cell  median_reads_per_cell  median_umi_per_cell  \
# 0                  2586.0                 8000.0               7156.0
# 1                  3650.0                10453.0               9348.0
# ..                    ...                    ...                  ...
# 3                  1988.0                 3912.0               2907.0
# 4                     NaN                    NaN                  NaN
#
#     median_feature_per_cell  number_of_reads  ...  \
# 0                    2633.0        185374541  ...
# 1                    3750.0        185374541  ...
# ..                      ...              ...  ...
# 3                    1877.0         69284062  ...
# 4                       NaN         69284062  ...
#
#     reads_mapped_to_velocyto__unique_multiple_velocyto  \
# 0                                                 NaN
# 1                                                 NaN
# ..                                                ...
# 3                                                 NaN
# 4                                                 0.0
#
#     reads_with_valid_barcodes  sequencing_saturation  total_feature_detected  \
# 0                    0.976479               0.103122                 23037.0
# 1                    0.975909               0.103335                 28034.0
# ..                        ...                    ...                     ...
# 3                    0.981650               0.255467                 27456.0
# 4                    0.983232                   -inf                     NaN
#
#     umis_in_cells  unique_reads_in_cells_mapped_to_gene  \
# 0        91764373                           102508409.0
# 1       120375815                                   NaN
# ..            ...                                   ...
# 3        40705287                                   NaN
# 4               0                                   NaN
#
#     unique_reads_in_cells_mapped_to_genefull  \
# 0                                        NaN
# 1                                134506074.0
# ..                                       ...
# 3                                        NaN
# 4                                        NaN
#
#     unique_reads_in_cells_mapped_to_genefull_ex50pas  \
# 0                                                NaN
# 1                                                NaN
# ..                                               ...
# 3                                                NaN
# 4                                                NaN
#
#     unique_reads_in_cells_mapped_to_genefull_exonoverintron       sample
# 0                                                 NaN        SRX15390667
# 1                                                 NaN        SRX15390667
# ..                                                ...                ...
# 3                                          54766485.0        SRX24257896
# 4                                                 NaN        SRX24257896
#
# [5870 rows x 33 columns]

# %%
# filter to just `GeneFull_Ex50pAS` for `feature` column
summary_df_f = summary_df[summary_df['feature'] == 'GeneFull_Ex50pAS']
summary_df_f
# Out:
#              feature  estimated_number_of_cells  \
# 2   GeneFull_Ex50pAS                      12456
# 2   GeneFull_Ex50pAS                      13616
# ..               ...                        ...
# 2   GeneFull_Ex50pAS                      12070
# 2   GeneFull_Ex50pAS                      12406
#
#     fraction_of_unique_reads_in_cells  mean_reads_per_cell  mean_umi_per_cell  \
# 2                            0.918303              11016.0             9858.0
# 2                            0.929253              10734.0             9583.0
# ..                                ...                  ...                ...
# 2                            0.957497               5100.0             3701.0
# 2                            0.956609               4399.0             3270.0
#
#     mean_feature_per_cell  median_reads_per_cell  median_umi_per_cell  \
# 2                  3681.0                10664.0               9539.0
# 2                  3620.0                10326.0               9225.0
# ..                    ...                    ...                  ...
# 2                  2117.0                 4572.0               3317.0
# 2                  1981.0                 3903.0               2898.0
#
#     median_feature_per_cell  number_of_reads  ...  \
# 2                    3781.0        185374541  ...
# 2                    3717.0        190845115  ...
# ..                      ...              ...  ...
# 2                    2024.0         77097683  ...
# 2                    1870.0         69284062  ...
#
#     reads_mapped_to_velocyto__unique_multiple_velocyto  \
# 2                                                 NaN
# 2                                                 NaN
# ..                                                ...
# 2                                                 NaN
# 2                                                 NaN
#
#     reads_with_valid_barcodes  sequencing_saturation  total_feature_detected  \
# 2                    0.975953               0.103431                 29035.0
# 2                    0.977768               0.105701                 28924.0
# ..                        ...                    ...                     ...
# 2                    0.982754               0.273061                 27232.0
# 2                    0.981678               0.255459                 27353.0
#
#     umis_in_cells  unique_reads_in_cells_mapped_to_gene  \
# 2       122796317                                   NaN
# 2       130488348                                   NaN
# ..            ...                                   ...
# 2        44671802                                   NaN
# 2        40571726                                   NaN
#
#     unique_reads_in_cells_mapped_to_genefull  \
# 2                                        NaN
# 2                                        NaN
# ..                                       ...
# 2                                        NaN
# 2                                        NaN
#
#     unique_reads_in_cells_mapped_to_genefull_ex50pas  \
# 2                                        137225560.0
# 2                                        146157149.0
# ..                                               ...
# 2                                         61568574.0
# 2                                         54586397.0
#
#     unique_reads_in_cells_mapped_to_genefull_exonoverintron       sample
# 2                                                 NaN        SRX15390667
# 2                                                 NaN        SRX15390616
# ..                                                ...                ...
# 2                                                 NaN        SRX24258398
# 2                                                 NaN        SRX24257896
#
# [1174 rows x 33 columns]

# %%
pd.set_option('display.max_rows', 10)

# %%
# summarize number of cells
print(summary_df_f['estimated_number_of_cells'].sum())
summary_df_f['estimated_number_of_cells'].describe()
# Out:
# 15434942
# count     1174.000000
# mean     13147.310051
# std       4672.226274
# min        421.000000
# 25%      11004.000000
# 50%      12572.500000
# 75%      14663.250000
# max      49764.000000
# Name: estimated_number_of_cells, dtype: float64

# %%
# summarize reads
reads_bil = summary_df_f['number_of_reads'].sum() / 1e9
print(f"{reads_bil:.2f} billion reads")
summary_df_f['number_of_reads'].describe()
# Out:
# 185.83 billion reads
# count    1.174000e+03
# mean     1.582907e+08
# std      8.351201e+07
# min      1.382970e+05
# 25%      8.178377e+07
# 50%      1.542568e+08
# 75%      2.239959e+08
# max      4.250947e+08
# Name: number_of_reads, dtype: float64

# %% [markdown]
# # session info

# %%
# !conda list
# Out:
# # packages in environment at /home/nickyoungblut/miniforge3/envs/asmbl:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# aiohappyeyeballs          2.4.6              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.11.12         py312h178313f_0    conda-forge
# aiosignal                 1.3.2              pyhd8ed1ab_0    conda-forge
# alsa-lib                  1.2.11               hd590300_1    conda-forge
# anyio                     4.8.0              pyhd8ed1ab_0    conda-forge
# appdirs                   1.4.4              pyhd8ed1ab_1    conda-forge
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# attrs                     25.1.0             pyh71513ae_0    conda-forge
# bash                      5.2.21               h7f99829_0    conda-forge
# bash_kernel               0.9.3              pyh4f82c71_0    conda-forge
# bedtools                  2.31.1               hf5e1c6e_2    bioconda
# biopython                 1.85            py312h66e93f0_1    conda-forge
# biothings_client          0.4.1              pyh29332c3_0    conda-forge
# blast                     2.16.0               hc155240_3    bioconda
# brotli                    1.1.0                hd590300_1    conda-forge
# brotli-bin                1.1.0                hd590300_1    conda-forge
# brotli-python             1.1.0           py312h30efb56_1    conda-forge
# bwa                       0.7.18               he4a0461_1    bioconda
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.33.1               heb4867d_0    conda-forge
# ca-certificates           2025.1.31            hbcca054_0    conda-forge
# cachetools                5.5.1              pyhd8ed1ab_0    conda-forge
# cairo                     1.18.0               h3faef2a_0    conda-forge
# certifi                   2025.1.31          pyhd8ed1ab_0    conda-forge
# cffi                      1.17.1          py312h06ac9bb_0    conda-forge
# charset-normalizer        3.4.1              pyhd8ed1ab_0    conda-forge
# circos                    0.69.9               hdfd78af_0    bioconda
# click                     8.1.8              pyh707e725_0    conda-forge
# colorama                  0.4.6              pyhd8ed1ab_1    conda-forge
# comm                      0.2.2              pyhd8ed1ab_0    conda-forge
# contourpy                 1.3.0           py312h68727a3_0    conda-forge
# cryptography              44.0.1          py312hda17c39_0    conda-forge
# curl                      8.8.0                he654da7_1    conda-forge
# cycler                    0.12.1             pyhd8ed1ab_0    conda-forge
# debugpy                   1.8.5           py312hca68cad_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# diskcache                 5.6.3              pyhd8ed1ab_1    conda-forge
# entrez-direct             22.4                 he881be0_0    bioconda
# exceptiongroup            1.2.2              pyhd8ed1ab_0    conda-forge
# executing                 2.0.1              pyhd8ed1ab_0    conda-forge
# expat                     2.6.2                h59595ed_0    conda-forge
# filelock                  3.17.0             pyhd8ed1ab_0    conda-forge
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 h77eed37_2    conda-forge
# fontconfig                2.14.2               h14ed4e7_0    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# fonttools                 4.53.1          py312h41a817b_0    conda-forge
# freetype                  2.12.1               h267a509_2    conda-forge
# frozendict                2.4.6           py312h66e93f0_0    conda-forge
# frozenlist                1.5.0           py312h178313f_1    conda-forge
# genomepy                  0.16.1             pyh7e72e81_2    bioconda
# gettext                   0.22.5               he02047a_3    conda-forge
# gettext-tools             0.22.5               he02047a_3    conda-forge
# giflib                    5.2.2                hd590300_0    conda-forge
# glimmerhmm                3.0.4           pl5321hdbdd923_8    bioconda
# google-api-core           2.24.1             pyhd8ed1ab_0    conda-forge
# google-auth               2.38.0             pyhd8ed1ab_0    conda-forge
# google-cloud-core         2.4.2              pyhd8ed1ab_0    conda-forge
# google-cloud-storage      3.0.0              pyhd8ed1ab_0    conda-forge
# google-crc32c             1.1.2           py312hb42adb9_6    conda-forge
# google-resumable-media    2.7.2              pyhd8ed1ab_2    conda-forge
# googleapis-common-protos  1.68.0             pyhd8ed1ab_0    conda-forge
# graphite2                 1.3.13            h59595ed_1003    conda-forge
# grpcio                    1.67.1          py312h374181b_0    conda-forge
# h11                       0.14.0             pyhd8ed1ab_1    conda-forge
# h2                        4.1.0              pyhd8ed1ab_1    conda-forge
# harfbuzz                  8.5.0                hfac3d4d_0    conda-forge
# hpack                     4.1.0              pyhd8ed1ab_0    conda-forge
# htslib                    1.21                 h5efdd21_0    bioconda
# httpcore                  1.0.7              pyh29332c3_1    conda-forge
# httpx                     0.28.1             pyhd8ed1ab_0    conda-forge
# hyperframe                6.1.0              pyhd8ed1ab_0    conda-forge
# icu                       73.2                 h59595ed_0    conda-forge
# idna                      3.10               pyhd8ed1ab_1    conda-forge
# importlib-metadata        8.4.0              pyha770c72_0    conda-forge
# importlib_metadata        8.4.0                hd8ed1ab_0    conda-forge
# ipykernel                 6.29.5             pyh3099207_0    conda-forge
# ipython                   8.26.0             pyh707e725_0    conda-forge
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# joblib                    1.4.2              pyhd8ed1ab_0    conda-forge
# jupyter_client            8.6.2              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.2           py312h7900ff3_0    conda-forge
# k8                        1.2                  h6618dc6_3    bioconda
# kernel-headers_linux-64   3.10.0              he073ed8_18    conda-forge
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.5           py312h68727a3_2    conda-forge
# krb5                      1.21.3               h659f571_0    conda-forge
# lcms2                     2.16                 hb7c19ff_0    conda-forge
# ld_impl_linux-64          2.40                 hf3520f5_7    conda-forge
# lerc                      4.0.0                h27087fc_0    conda-forge
# libabseil                 20240722.0      cxx17_hbbce691_4    conda-forge
# libasprintf               0.22.5               he8f35ee_3    conda-forge
# libasprintf-devel         0.22.5               he8f35ee_3    conda-forge
# libblas                   3.9.0           23_linux64_openblas    conda-forge
# libbrotlicommon           1.1.0                hd590300_1    conda-forge
# libbrotlidec              1.1.0                hd590300_1    conda-forge
# libbrotlienc              1.1.0                hd590300_1    conda-forge
# libcblas                  3.9.0           23_linux64_openblas    conda-forge
# libcrc32c                 1.1.2                h9c3ff4c_0    conda-forge
# libcups                   2.3.3                h4637d8d_4    conda-forge
# libcurl                   8.8.0                hca28451_1    conda-forge
# libdeflate                1.20                 hd590300_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 hd590300_2    conda-forge
# libexpat                  2.6.2                h59595ed_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc                    14.1.0               h77fa898_1    conda-forge
# libgcc-ng                 14.1.0               h69a702a_1    conda-forge
# libgd                     2.3.3                h119a65a_9    conda-forge
# libgettextpo              0.22.5               he02047a_3    conda-forge
# libgettextpo-devel        0.22.5               he02047a_3    conda-forge
# libgfortran               14.1.0               h69a702a_1    conda-forge
# libgfortran-ng            14.1.0               h69a702a_1    conda-forge
# libgfortran5              14.1.0               hc5f4f2c_1    conda-forge
# libglib                   2.80.2               hf974151_0    conda-forge
# libgomp                   14.1.0               h77fa898_1    conda-forge
# libgrpc                   1.67.1               hc2c308b_0    conda-forge
# libiconv                  1.17                 hd590300_2    conda-forge
# libidn2                   2.3.7                hd590300_0    conda-forge
# libjpeg-turbo             3.0.0                hd590300_1    conda-forge
# liblapack                 3.9.0           23_linux64_openblas    conda-forge
# libnghttp2                1.58.0               h47da74e_1    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libopenblas               0.3.27          pthreads_hac2b453_1    conda-forge
# libopenssl-static         3.4.1                hb9d3cd8_0    conda-forge
# libpng                    1.6.43               h2797004_0    conda-forge
# libprotobuf               5.28.2               h5b01275_0    conda-forge
# libre2-11                 2024.07.02           hbbce691_2    conda-forge
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libsqlite                 3.46.0               hde9e2c9_0    conda-forge
# libssh2                   1.11.0               h0841786_0    conda-forge
# libstdcxx                 14.1.0               hc0a3c3a_1    conda-forge
# libstdcxx-ng              14.1.0               h4852527_1    conda-forge
# libtiff                   4.6.0                h1dd3fc0_3    conda-forge
# libunistring              0.9.10               h7f98852_0    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libwebp                   1.4.0                h2c329e2_0    conda-forge
# libwebp-base              1.4.0                hd590300_0    conda-forge
# libxcb                    1.15                 h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxml2                   2.12.7               hc051c1a_1    conda-forge
# libxslt                   1.1.39               h76b75d6_0    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# loguru                    0.7.2           py312h7900ff3_2    conda-forge
# lxml                      5.2.2           py312hb90d8a5_0    conda-forge
# matplotlib-base           3.9.2           py312h854627b_0    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_0    conda-forge
# miniasm                   0.3                  h577a1d6_5    bioconda
# minimap2                  2.28                 he4a0461_3    bioconda
# multidict                 6.1.0           py312h178313f_2    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mygene                    3.2.2              pyh5e36f6f_0    bioconda
# mysql-common              8.3.0                hf1915f5_4    conda-forge
# mysql-connector-c         6.1.11            h659d440_1008    conda-forge
# mysql-connector-python    8.3.0           py312hb06c811_0    conda-forge
# mysql-libs                8.3.0                hca2cd23_4    conda-forge
# ncbi-vdb                  3.1.1                h4ac6f70_1    bioconda
# ncurses                   6.5                  he02047a_1    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# norns                     0.1.6              pyh5e36f6f_0    bioconda
# nose                      1.3.7                   py_1006    conda-forge
# numpy                     2.1.0           py312h1103770_0    conda-forge
# openjdk                   22.0.1               hb622114_0    conda-forge
# openjpeg                  2.5.2                h488ebb8_0    conda-forge
# openssl                   3.4.1                h7b32b05_0    conda-forge
# packaging                 24.1               pyhd8ed1ab_0    conda-forge
# pandas                    2.2.3           py312hf9745cd_1    conda-forge
# parso                     0.8.4              pyhd8ed1ab_0    conda-forge
# pcre                      8.45                 h9c3ff4c_0    conda-forge
# pcre2                     10.43                hcad00b1_0    conda-forge
# perl                      5.32.1          7_hd590300_perl5    conda-forge
# perl-archive-tar          2.40            pl5321hdfd78af_0    bioconda
# perl-b-cow                0.007           pl5321hd590300_0    conda-forge
# perl-carp                 1.50            pl5321hd8ed1ab_0    conda-forge
# perl-clone                0.46            pl5321h166bdaf_0    conda-forge
# perl-common-sense         3.75            pl5321hd8ed1ab_0    conda-forge
# perl-compress-raw-bzip2   2.201           pl5321h166bdaf_0    conda-forge
# perl-compress-raw-zlib    2.202           pl5321h166bdaf_0    conda-forge
# perl-config-general       2.65            pl5321hdfd78af_0    bioconda
# perl-digest-perl-md5      1.9             pl5321hdfd78af_2    bioconda
# perl-encode               3.21            pl5321hd590300_0    conda-forge
# perl-exporter             5.74            pl5321hd8ed1ab_0    conda-forge
# perl-exporter-tiny        1.002002        pl5321hd8ed1ab_0    conda-forge
# perl-extutils-config      0.008           pl5321ha770c72_0    conda-forge
# perl-extutils-helpers     0.026           pl5321ha770c72_0    conda-forge
# perl-extutils-installpaths 0.012           pl5321ha770c72_0    conda-forge
# perl-extutils-makemaker   7.70            pl5321hd8ed1ab_0    conda-forge
# perl-extutils-pl2bat      0.005           pl5321ha770c72_0    conda-forge
# perl-font-ttf             1.06            pl5321hdfd78af_1    bioconda
# perl-gd                   2.56                          0    bioconda
# perl-inc-latest           0.500           pl5321ha770c72_0    conda-forge
# perl-io-compress          2.201           pl5321hdbdd923_2    bioconda
# perl-io-string            1.08            pl5321hdfd78af_4    bioconda
# perl-io-zlib              1.14            pl5321hdfd78af_0    bioconda
# perl-json                 4.10            pl5321hdfd78af_1    bioconda
# perl-json-xs              4.03            pl5321h4ac6f70_3    bioconda
# perl-list-moreutils       0.430           pl5321hdfd78af_0    bioconda
# perl-list-moreutils-xs    0.430           pl5321h031d066_2    bioconda
# perl-math-bezier          0.01            pl5321hdfd78af_2    bioconda
# perl-math-round           0.07            pl5321ha770c72_0    conda-forge
# perl-math-vecstat         0.08            pl5321hdfd78af_2    bioconda
# perl-module-build         0.4234          pl5321ha770c72_0    conda-forge
# perl-module-build-tiny    0.039           pl5321h166bdaf_0    conda-forge
# perl-module-implementation 0.09            pl5321ha770c72_0    conda-forge
# perl-module-runtime       0.016           pl5321hdfd78af_2    bioconda
# perl-number-format        1.76            pl5321hd8ed1ab_0    conda-forge
# perl-params-validate      1.31            pl5321h031d066_2    bioconda
# perl-parent               0.241           pl5321hd8ed1ab_0    conda-forge
# perl-pathtools            3.75            pl5321h166bdaf_0    conda-forge
# perl-readonly             2.05            pl5321ha770c72_0    conda-forge
# perl-regexp-common        2017060201      pl5321hd8ed1ab_0    conda-forge
# perl-scalar-list-utils    1.63            pl5321h166bdaf_0    conda-forge
# perl-set-intspan          1.19            pl5321hdfd78af_2    bioconda
# perl-statistics-basic     1.6611          pl5321hdfd78af_3    bioconda
# perl-storable             3.15            pl5321h166bdaf_0    conda-forge
# perl-svg                  2.87            pl5321hd8ed1ab_0    conda-forge
# perl-test-fatal           0.016           pl5321ha770c72_0    conda-forge
# perl-text-format          0.62            pl5321hdfd78af_0    bioconda
# perl-time-hires           1.9764          pl5321h031d066_4    bioconda
# perl-try-tiny             0.31            pl5321ha770c72_0    conda-forge
# perl-types-serialiser     1.01            pl5321hdfd78af_0    bioconda
# perl-xml-parser           2.44_01         pl5321hc3e0081_1003    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    10.3.0          py312hdcec9eb_0    conda-forge
# pip                       24.2               pyh8b19718_1    conda-forge
# pixman                    0.43.2               h59595ed_0    conda-forge
# platformdirs              4.2.2              pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.47             pyha770c72_0    conda-forge
# propcache                 0.2.1           py312h178313f_1    conda-forge
# proto-plus                1.26.0             pyhd8ed1ab_0    conda-forge
# protobuf                  5.28.2          py312h2ec8cdc_0    conda-forge
# psutil                    6.0.0           py312h9a8786e_0    conda-forge
# pthread-stubs             0.4               h36c2ea0_1001    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_0    conda-forge
# pyasn1                    0.6.1              pyhd8ed1ab_2    conda-forge
# pyasn1-modules            0.4.1              pyhd8ed1ab_1    conda-forge
# pycparser                 2.22               pyh29332c3_1    conda-forge
# pyfaidx                   0.8.1.3            pyhdfd78af_0    bioconda
# pygments                  2.18.0             pyhd8ed1ab_0    conda-forge
# pyld                      2.0.4              pyhd8ed1ab_1    conda-forge
# pyopenssl                 25.0.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.1.4              pyhd8ed1ab_0    conda-forge
# pysocks                   1.7.1              pyha55dd90_7    conda-forge
# python                    3.12.3          hab00c5b_0_cpython    conda-forge
# python-dateutil           2.9.0              pyhd8ed1ab_0    conda-forge
# python-dotenv             1.0.1              pyhd8ed1ab_1    conda-forge
# python-tzdata             2025.1             pyhd8ed1ab_0    conda-forge
# python_abi                3.12                    5_cp312    conda-forge
# pytz                      2024.1             pyhd8ed1ab_0    conda-forge
# pyu2f                     0.1.5              pyhd8ed1ab_1    conda-forge
# pyvcf3                    1.0.3              pyhdfd78af_0    bioconda
# pyyaml                    6.0.2           py312h178313f_2    conda-forge
# pyzmq                     26.2.0          py312hbf22597_0    conda-forge
# qhull                     2020.2               h434a139_5    conda-forge
# quast                     5.3.0           py312pl5321hdcc493e_1    bioconda
# racon                     1.5.0                hdcf5f25_4    bioconda
# re2                       2024.07.02           h9925aae_2    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# requests                  2.32.3             pyhd8ed1ab_1    conda-forge
# rpsbproc                  0.5.0                h6a68c12_1    bioconda
# rsa                       4.9                pyhd8ed1ab_1    conda-forge
# seqkit                    2.8.2                h9ee0642_1    bioconda
# setuptools                72.2.0             pyhd8ed1ab_0    conda-forge
# simplejson                3.19.3          py312h66e93f0_1    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sniffio                   1.3.1              pyhd8ed1ab_1    conda-forge
# spades                    4.0.0                h6dccd9a_3    bioconda
# sra-tools                 2.9.6                hf484d3e_0    bioconda
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# star                      2.7.11b              h5ca1c30_5    bioconda
# sysroot_linux-64          2.17                h0157908_18    conda-forge
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tornado                   6.4.1           py312h66e93f0_1    conda-forge
# tqdm                      4.67.1             pyhd8ed1ab_1    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_0    conda-forge
# typing-extensions         4.12.2               hd8ed1ab_0    conda-forge
# typing_extensions         4.12.2             pyha770c72_0    conda-forge
# tzdata                    2024a                h8827d51_1    conda-forge
# ucsc-bedtogenepred        469                  h9b8f530_0    bioconda
# ucsc-genepredtobed        469                  h9b8f530_0    bioconda
# ucsc-genepredtogtf        469                  h9b8f530_0    bioconda
# ucsc-gff3togenepred       469                  h9b8f530_0    bioconda
# ucsc-gtftogenepred        469                  h9b8f530_0    bioconda
# unicycler                 0.5.1           py312hc60241a_2    bioconda
# urllib3                   2.3.0              pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# wget                      1.21.4               hda4d442_0    conda-forge
# wheel                     0.44.0             pyhd8ed1ab_0    conda-forge
# xorg-fixesproto           5.0               h7f98852_1002    conda-forge
# xorg-inputproto           2.3.2             h7f98852_1002    conda-forge
# xorg-kbproto              1.0.7             h7f98852_1002    conda-forge
# xorg-libice               1.1.1                hd590300_0    conda-forge
# xorg-libsm                1.2.4                h7391055_0    conda-forge
# xorg-libx11               1.8.9                h8ee46fc_0    conda-forge
# xorg-libxau               1.0.11               hd590300_0    conda-forge
# xorg-libxdmcp             1.1.3                h7f98852_0    conda-forge
# xorg-libxext              1.3.4                h0b41bf4_2    conda-forge
# xorg-libxfixes            5.0.3             h7f98852_1004    conda-forge
# xorg-libxi                1.7.10               h4bc722e_1    conda-forge
# xorg-libxrender           0.9.11               hd590300_0    conda-forge
# xorg-libxt                1.3.0                hd590300_1    conda-forge
# xorg-libxtst              1.2.5                h4bc722e_0    conda-forge
# xorg-recordproto          1.14.2            h7f98852_1002    conda-forge
# xorg-renderproto          0.11.1            h7f98852_1002    conda-forge
# xorg-xextproto            7.3.0             h0b41bf4_1003    conda-forge
# xorg-xproto               7.0.31            h7f98852_1007    conda-forge
# xz                        5.2.6                h166bdaf_0    conda-forge
# yaml                      0.2.5                h7f98852_2    conda-forge
# yarl                      1.18.3          py312h178313f_1    conda-forge
# zeromq                    4.3.5                h75354e8_4    conda-forge
# zipp                      3.20.1             pyhd8ed1ab_0    conda-forge
# zlib                      1.3.1                hb9d3cd8_2    conda-forge
# zstandard                 0.23.0          py312hef9b889_1    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge
